# %% [markdown]
# <a href="https://colab.research.google.com/github/jhon-aparicio/DataSet/blob/main/PersonaUNetS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import sys
import json
import numpy as np
import time
from PIL import Image, ImageDraw
import skimage.draw
import random

# %%
# !git clone https://github.com/johnpaipa/semanticSegmentation.git
# Out:
# Cloning into 'semanticSegmentation'...
# remote: Enumerating objects: 126, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 126 (delta 0), reused 1 (delta 0), pack-reused 123
# Receiving objects: 100% (126/126), 73.51 MiB | 14.21 MiB/s, done.
# Resolving deltas: 100% (2/2), done.
# Updating files: 100% (109/109), done.

# %%
cd semanticSegmentation/
# Out:
# /content/semanticSegmentation

# %%
# !python setup.py install
# Out:
# WARNING:root:Fail load requirements file, so using default ones.
# /usr/local/lib/python3.8/dist-packages/setuptools/dist.py:697: UserWarning: Usage of dash-separated 'description-file' will not be supported in future versions. Please use the underscore name 'description_file' instead
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/setuptools/dist.py:697: UserWarning: Usage of dash-separated 'license-file' will not be supported in future versions. Please use the underscore name 'license_file' instead
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/setuptools/dist.py:697: UserWarning: Usage of dash-separated 'requirements-file' will not be supported in future versions. Please use the underscore name 'requirements_file' instead
#   warnings.warn(
# running install
# running bdist_egg
# running egg_info
# creating mask_rcnn.egg-info
# writing mask_rcnn.egg-info/PKG-INFO
# writing dependency_links to mask_rcnn.egg-info/dependency_links.txt
# writing top-level names to mask_rcnn.egg-info/top_level.txt
# writing manifest file 'mask_rcnn.egg-info/SOURCES.txt'
# reading manifest file 'mask_rcnn.egg-info/SOURCES.txt'
# reading manifest template 'MANIFEST.in'
# warning: no files found matching 'requirements.txt'
# adding license file 'LICENSE'
# writing manifest file 'mask_rcnn.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_py
# creating build
# creating build/lib
# creating build/lib/mrcnn
# copying mrcnn/model.py -> build/lib/mrcnn
# copying mrcnn/utils.py -> build/lib/mrcnn
# copying mrcnn/config.py -> build/lib/mrcnn
# copying mrcnn/parallel_model.py -> build/lib/mrcnn
# copying mrcnn/visualize.py -> build/lib/mrcnn
# copying mrcnn/__init__.py -> build/lib/mrcnn
# creating build/bdist.linux-x86_64
# creating build/bdist.linux-x86_64/egg
# creating build/bdist.linux-x86_64/egg/mrcnn
# copying build/lib/mrcnn/model.py -> build/bdist.linux-x86_64/egg/mrcnn
# copying build/lib/mrcnn/utils.py -> build/bdist.linux-x86_64/egg/mrcnn
# copying build/lib/mrcnn/config.py -> build/bdist.linux-x86_64/egg/mrcnn
# copying build/lib/mrcnn/parallel_model.py -> build/bdist.linux-x86_64/egg/mrcnn
# copying build/lib/mrcnn/visualize.py -> build/bdist.linux-x86_64/egg/mrcnn
# copying build/lib/mrcnn/__init__.py -> build/bdist.linux-x86_64/egg/mrcnn
# byte-compiling build/bdist.linux-x86_64/egg/mrcnn/model.py to model.cpython-38.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mrcnn/utils.py to utils.cpython-38.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mrcnn/config.py to config.cpython-38.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mrcnn/parallel_model.py to parallel_model.cpython-38.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mrcnn/visualize.py to visualize.cpython-38.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mrcnn/__init__.py to __init__.cpython-38.pyc
# creating build/bdist.linux-x86_64/egg/EGG-INFO
# copying mask_rcnn.egg-info/PKG-INFO -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying mask_rcnn.egg-info/SOURCES.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying mask_rcnn.egg-info/dependency_links.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying mask_rcnn.egg-info/top_level.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# zip_safe flag not set; analyzing archive contents...
# creating dist
# creating 'dist/mask_rcnn-2.1-py3.8.egg' and adding 'build/bdist.linux-x86_64/egg' to it
# removing 'build/bdist.linux-x86_64/egg' (and everything under it)
# Processing mask_rcnn-2.1-py3.8.egg
# Copying mask_rcnn-2.1-py3.8.egg to /usr/local/lib/python3.8/dist-packages
# Adding mask-rcnn 2.1 to easy-install.pth file
#
# Installed /usr/local/lib/python3.8/dist-packages/mask_rcnn-2.1-py3.8.egg
# Processing dependencies for mask-rcnn==2.1
# Finished processing dependencies for mask-rcnn==2.1

# %%
ROOT_DIR = '/content/semanticSegmentation'
assert os.path.exists(ROOT_DIR), 'ROOT_DIR does not exist'

sys.path.append(ROOT_DIR) 

from mrcnn import visualize
from mrcnn.config import Config
from mrcnn import model as modellib, utils

# %%
# Directory to save logs and trained model
MODEL_DIR = os.path.join(ROOT_DIR, "logs")

# Local path to trained weights file
COCO_MODEL_PATH = os.path.join(ROOT_DIR, "mask_rcnn_coco.h5")

# Download COCO trained weights from Releases if needed
if not os.path.exists(COCO_MODEL_PATH):
    utils.download_trained_weights(COCO_MODEL_PATH)
# Out:
# Downloading pretrained model to /content/semanticSegmentation/mask_rcnn_coco.h5 ...
# ... done downloading pretrained model!

# %%
class CascoConfig(Config):
    """Configuration for training on the helmet  dataset.
    """
    # Give the configuration a recognizable name
    NAME = "persona"

    # Train on 1 GPU and 1 image per GPU. Batch size is 1 (GPUs * images/GPU).
    GPU_COUNT = 1
    IMAGES_PER_GPU = 1

    # Number of classes (including background)
    NUM_CLASSES = 1 + 1  # background + 1 (casco)

    # All of our training images are 512x512
    IMAGE_MIN_DIM = 512
    IMAGE_MAX_DIM = 512

    # You can experiment with this number to see if it improves training
    STEPS_PER_EPOCH = 500

    # This is how often validation is run. If you are using too much hard drive space
    # on saved models (in the MODEL_DIR), try making this value larger.
    VALIDATION_STEPS = 5
    
    # Matterport originally used resnet101, but I downsized to fit it on my graphics card
    BACKBONE = 'resnet50'

    # To be honest, I haven't taken the time to figure out what these do
    RPN_ANCHOR_SCALES = (8, 16, 32, 64, 128)
    TRAIN_ROIS_PER_IMAGE = 32
    MAX_GT_INSTANCES = 50 
    POST_NMS_ROIS_INFERENCE = 500 
    POST_NMS_ROIS_TRAINING = 1000 
    
config = CascoConfig()
config.display()
# Out:
# Configurations:
# BACKBONE                       resnet50
# BACKBONE_STRIDES               [4, 8, 16, 32, 64]
# BATCH_SIZE                     1
# BBOX_STD_DEV                   [0.1 0.1 0.2 0.2]
# COMPUTE_BACKBONE_SHAPE         None
# DETECTION_MAX_INSTANCES        100
# DETECTION_MIN_CONFIDENCE       0.7
# DETECTION_NMS_THRESHOLD        0.3
# FPN_CLASSIF_FC_LAYERS_SIZE     1024
# GPU_COUNT                      1
# GRADIENT_CLIP_NORM             5.0
# IMAGES_PER_GPU                 1
# IMAGE_CHANNEL_COUNT            3
# IMAGE_MAX_DIM                  512
# IMAGE_META_SIZE                14
# IMAGE_MIN_DIM                  512
# IMAGE_MIN_SCALE                0
# IMAGE_RESIZE_MODE              square
# IMAGE_SHAPE                    [512 512   3]
# LEARNING_MOMENTUM              0.9
# LEARNING_RATE                  0.001
# LOSS_WEIGHTS                   {'rpn_class_loss': 1.0, 'rpn_bbox_loss': 1.0, 'mrcnn_class_loss': 1.0, 'mrcnn_bbox_loss': 1.0, 'mrcnn_mask_loss': 1.0}
# MASK_POOL_SIZE                 14
# MASK_SHAPE                     [28, 28]
# MAX_GT_INSTANCES               50
# MEAN_PIXEL                     [123.7 116.8 103.9]
# MINI_MASK_SHAPE                (56, 56)
# NAME                           persona
# NUM_CLASSES                    2
# POOL_SIZE                      7
# POST_NMS_ROIS_INFERENCE        500
# POST_NMS_ROIS_TRAINING         1000
# PRE_NMS_LIMIT                  6000
# ROI_POSITIVE_RATIO             0.33
# RPN_ANCHOR_RATIOS              [0.5, 1, 2]
# RPN_ANCHOR_SCALES              (8, 16, 32, 64, 128)
# RPN_ANCHOR_STRIDE              1
# RPN_BBOX_STD_DEV               [0.1 0.1 0.2 0.2]
# RPN_NMS_THRESHOLD              0.7
# RPN_TRAIN_ANCHORS_PER_IMAGE    256
# STEPS_PER_EPOCH                500
# TOP_DOWN_PYRAMID_SIZE          256
# TRAIN_BN                       False
# TRAIN_ROIS_PER_IMAGE           32
# USE_MINI_MASK                  True
# USE_RPN_ROIS                   True
# VALIDATION_STEPS               5
# WEIGHT_DECAY                   0.0001

# %%
class CascoDataset(utils.Dataset):

    def load_cascos(self, dataset_dir, subset):
        """Load a subset of the Casco dataset.
        dataset_dir: Root directory of the dataset.
        subset: Subset to load: train or val
        """
        # Add classes. We have only one class to add.
        self.add_class("persona", 1, "persona")

        # Train or validation dataset?
        assert subset in ["train", "val"]
        dataset_dir = os.path.join(dataset_dir, subset)

        # Load annotations
        # VGG Image Annotator (up to version 1.6) saves each image in the form:
        # { 'filename': '28503151_5b5b7ec140_b.jpg',
        #   'regions': {
        #       '0': {
        #           'region_attributes': {},
        #           'shape_attributes': {
        #               'all_points_x': [...],
        #               'all_points_y': [...],
        #               'name': 'polygon'}},
        #       ... more regions ...
        #   },
        #   'size': 100202
        # }
        # We mostly care about the x and y coordinates of each region
        # Note: In VIA 2.0, regions was changed from a dict to a list.
        annotations = json.load(open(os.path.join(dataset_dir, "via_region_data.json")))
        annotations = list(annotations.values())  # don't need the dict keys

        # The VIA tool saves images in the JSON even if they don't have any
        # annotations. Skip unannotated images.
        annotations = [a for a in annotations if a['regions']]

        # Add images
        for a in annotations:
            # Get the x, y coordinaets of points of the polygons that make up
            # the outline of each object instance. These are stores in the
            # shape_attributes (see json format above)
            # The if condition is needed to support VIA versions 1.x and 2.x.
            if type(a['regions']) is dict:
                polygons = [r['shape_attributes'] for r in a['regions'].values()]
            else:
                polygons = [r['shape_attributes'] for r in a['regions']] 

            # load_mask() needs the image size to convert polygons to masks.
            # Unfortunately, VIA doesn't include it in JSON, so we must read
            # the image. This is only managable since the dataset is tiny.
            image_path = os.path.join(dataset_dir, a['filename'])
            image = skimage.io.imread(image_path)
            height, width = image.shape[:2]

            self.add_image(
                "persona",
                image_id=a['filename'],  # use file name as a unique image id
                path=image_path,
                width=width, height=height,
                polygons=polygons)

    def load_mask(self, image_id):
        """Generate instance masks for an image.
       Returns:
        masks: A bool array of shape [height, width, instance count] with
            one mask per instance.
        class_ids: a 1D array of class IDs of the instance masks.
        """
        # If not a casco dataset image, delegate to parent class.
        image_info = self.image_info[image_id]
        if image_info["source"] != "persona":
            return super(self.__class__, self).load_mask(image_id)

        # Convert polygons to a bitmap mask of shape
        # [height, width, instance_count]
        info = self.image_info[image_id]
        mask = np.zeros([info["height"], info["width"], len(info["polygons"])],
                        dtype=np.uint8)
        for i, p in enumerate(info["polygons"]):
            # Get indexes of pixels inside the polygon and set them to 1
            rr, cc = skimage.draw.polygon(p['all_points_y'], p['all_points_x'])
            mask[rr, cc, i] = 1

        # Return mask, and array of class IDs of each instance. Since we have
        # one class ID only, we return an array of 1s
        return mask.astype(np.bool), np.ones([mask.shape[-1]], dtype=np.int32)

    def image_reference(self, image_id):
        """Return the path of the image."""
        info = self.image_info[image_id]
        if info["source"] == "persona":
            return info["path"]
        else:
            super(self.__class__, self).image_reference(image_id)

# %%
dataset_train = CascoDataset()
dataset_train.load_cascos("/content/semanticSegmentation/dataset/persona", "train")
dataset_train.prepare()

# Validation dataset
dataset_val = CascoDataset()
dataset_val.load_cascos("/content/semanticSegmentation/dataset/persona", "val")
dataset_val.prepare()

# %%
# Create model in training mode
model = modellib.MaskRCNN(mode="training", config=config,
                          model_dir=MODEL_DIR)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/tensorflow/python/autograph/pyct/static_analysis/liveness.py:83: Analyzer.lamba_check (from tensorflow.python.autograph.pyct.static_analysis.liveness) is deprecated and will be removed after 2023-09-23.
# Instructions for updating:
# Lambda fuctions will be no more assumed to be used in the statement where they are used, or at least in the same block. https://github.com/tensorflow/tensorflow/issues/56089

# %%
# Which weights to start with?
init_with = "coco"  # imagenet, coco, or last

if init_with == "imagenet":
    model.load_weights(model.get_imagenet_weights(), by_name=True)
elif init_with == "coco":
    # Load weights trained on MS COCO, but skip layers that
    # are different due to the different number of classes
    # See README for instructions to download the COCO weights
    model.load_weights(COCO_MODEL_PATH, by_name=True,
                       exclude=["mrcnn_class_logits", "mrcnn_bbox_fc", 
                                "mrcnn_bbox", "mrcnn_mask"])
elif init_with == "last":
    # Load the last model you trained and continue training
    model.load_weights(model.find_last(), by_name=True)

# %%
# Load and display random samples
dataset = dataset_train
image_ids = np.random.choice(dataset.image_ids, 4)
for image_id in image_ids:
    image = dataset.load_image(image_id)
    mask, class_ids = dataset.load_mask(image_id)
    visualize.display_top_masks(image, mask, class_ids, dataset.class_names)
# Out:
# <ipython-input-8-4d23ee05384c>:87: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   return mask.astype(np.bool), np.ones([mask.shape[-1]], dtype=np.int32)

# %%
from skimage.filters import gaussian
image_idSeg = dataset.image_ids
for image_id in image_idSeg:
    image = dataset.load_image(image_id)
    mask, class_ids = dataset.load_mask(image_id)
    mask_smooth = gaussian(mask, sigma=1.2)
    visualize.display_top_masks(image, mask_smooth, class_ids, dataset.class_names)
    image_name = dataset.image_info[image_id]['id']
    skimage.io.imsave(f'/content/semanticSegmentation/dataset/persona/segmentadas/{image_name}', mask_smooth[:, :, 0])
# Out:
# <ipython-input-8-4d23ee05384c>:87: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   return mask.astype(np.bool), np.ones([mask.shape[-1]], dtype=np.int32)
# WARNING:imageio:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# <ipython-input-13-4e675a0c8f8c>:9: UserWarning: /content/semanticSegmentation/dataset/persona/segmentadas/Hat_Front90_1.png is a low contrast image
#   skimage.io.imsave(f'/content/semanticSegmentation/dataset/persona/segmentadas/{image_name}', mask_smooth[:, :, 0])
# WARNING:imageio:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.

# %%
from mrcnn.model import log
# Load random image and mask.
image_id = random.choice(dataset.image_ids)
image = dataset.load_image(image_id)
mask, class_ids = dataset.load_mask(image_id)
# Compute Bounding box
bbox = utils.extract_bboxes(mask)

# Display image and additional stats
print("image_id ", image_id, dataset.image_reference(image_id))
log("image", image)
log("mask", mask)
log("class_ids", class_ids)
log("bbox", bbox)
# Display image and instances
visualize.display_instances(image, bbox, mask, class_ids, dataset.class_names)
# Out:
# <ipython-input-8-4d23ee05384c>:87: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   return mask.astype(np.bool), np.ones([mask.shape[-1]], dtype=np.int32)
# image_id  13 /content/semanticSegmentation/dataset/persona/train/Caps_Front_2.png
# image                    shape: (300, 300, 3)         min:    0.00000  max:  254.00000  uint8
# mask                     shape: (300, 300, 1)         min:    0.00000  max:    1.00000  bool
# class_ids                shape: (1,)                  min:    1.00000  max:    1.00000  int32
# bbox                     shape: (1, 4)                min:  119.00000  max:  200.00000  int32

# %%
###PYTORCH CON U-NET 
import numpy as np
import matplotlib.pyplot as plt
import os
import random
import torch
from torch import nn, optim
from torch.nn import functional as F
from torchvision import transforms as T
from torch.utils.data import DataLoader, Dataset, random_split
#
import PIL
from PIL import Image
#
# !pip install jupyterthemes
from jupyterthemes import jtplot
jtplot.style()
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: jupyterthemes in /usr/local/lib/python3.8/dist-packages (0.20.0)
# Requirement already satisfied: matplotlib>=1.4.3 in /usr/local/lib/python3.8/dist-packages (from jupyterthemes) (3.5.3)
# Requirement already satisfied: notebook>=5.6.0 in /usr/local/lib/python3.8/dist-packages (from jupyterthemes) (6.3.0)
# Requirement already satisfied: ipython>=5.4.1 in /usr/local/lib/python3.8/dist-packages (from jupyterthemes) (7.9.0)
# Requirement already satisfied: jupyter-core in /usr/local/lib/python3.8/dist-packages (from jupyterthemes) (5.2.0)
# Requirement already satisfied: lesscpy>=0.11.2 in /usr/local/lib/python3.8/dist-packages (from jupyterthemes) (0.15.1)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.8/dist-packages (from ipython>=5.4.1->jupyterthemes) (0.7.5)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.8/dist-packages (from ipython>=5.4.1->jupyterthemes) (4.8.0)
# Requirement already satisfied: jedi>=0.10 in /usr/local/lib/python3.8/dist-packages (from ipython>=5.4.1->jupyterthemes) (0.18.2)
# Requirement already satisfied: backcall in /usr/local/lib/python3.8/dist-packages (from ipython>=5.4.1->jupyterthemes) (0.2.0)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.8/dist-packages (from ipython>=5.4.1->jupyterthemes) (57.4.0)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.8/dist-packages (from ipython>=5.4.1->jupyterthemes) (5.7.1)
# Requirement already satisfied: decorator in /usr/local/lib/python3.8/dist-packages (from ipython>=5.4.1->jupyterthemes) (4.4.2)
# Requirement already satisfied: prompt-toolkit<2.1.0,>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from ipython>=5.4.1->jupyterthemes) (2.0.10)
# Requirement already satisfied: pygments in /usr/local/lib/python3.8/dist-packages (from ipython>=5.4.1->jupyterthemes) (2.6.1)
# Requirement already satisfied: ply in /usr/local/lib/python3.8/dist-packages (from lesscpy>=0.11.2->jupyterthemes) (3.11)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=1.4.3->jupyterthemes) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=1.4.3->jupyterthemes) (8.4.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=1.4.3->jupyterthemes) (3.0.9)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=1.4.3->jupyterthemes) (1.4.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=1.4.3->jupyterthemes) (1.22.4)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=1.4.3->jupyterthemes) (4.38.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=1.4.3->jupyterthemes) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=1.4.3->jupyterthemes) (23.0)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.8/dist-packages (from notebook>=5.6.0->jupyterthemes) (0.13.3)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.8/dist-packages (from notebook>=5.6.0->jupyterthemes) (21.3.0)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.8/dist-packages (from notebook>=5.6.0->jupyterthemes) (0.2.0)
# Requirement already satisfied: ipykernel in /usr/local/lib/python3.8/dist-packages (from notebook>=5.6.0->jupyterthemes) (5.3.4)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.8/dist-packages (from notebook>=5.6.0->jupyterthemes) (5.7.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.8/dist-packages (from notebook>=5.6.0->jupyterthemes) (3.1.2)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.8/dist-packages (from notebook>=5.6.0->jupyterthemes) (23.2.1)
# Requirement already satisfied: tornado>=6.1 in /usr/local/lib/python3.8/dist-packages (from notebook>=5.6.0->jupyterthemes) (6.2)
# Requirement already satisfied: jupyter-client>=5.3.4 in /usr/local/lib/python3.8/dist-packages (from notebook>=5.6.0->jupyterthemes) (6.1.12)
# Requirement already satisfied: Send2Trash>=1.5.0 in /usr/local/lib/python3.8/dist-packages (from notebook>=5.6.0->jupyterthemes) (1.8.0)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.8/dist-packages (from notebook>=5.6.0->jupyterthemes) (0.16.0)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.8/dist-packages (from notebook>=5.6.0->jupyterthemes) (6.5.4)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.8/dist-packages (from jupyter-core->jupyterthemes) (3.0.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.8/dist-packages (from jedi>=0.10->ipython>=5.4.1->jupyterthemes) (0.8.3)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.8/dist-packages (from prompt-toolkit<2.1.0,>=2.0.0->ipython>=5.4.1->jupyterthemes) (0.2.6)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.8/dist-packages (from prompt-toolkit<2.1.0,>=2.0.0->ipython>=5.4.1->jupyterthemes) (1.15.0)
# Requirement already satisfied: ptyprocess in /usr/local/lib/python3.8/dist-packages (from terminado>=0.8.3->notebook>=5.6.0->jupyterthemes) (0.7.0)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.8/dist-packages (from argon2-cffi->notebook>=5.6.0->jupyterthemes) (21.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.8/dist-packages (from jinja2->notebook>=5.6.0->jupyterthemes) (2.1.2)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.8/dist-packages (from nbconvert->notebook>=5.6.0->jupyterthemes) (0.4)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.8/dist-packages (from nbconvert->notebook>=5.6.0->jupyterthemes) (4.6.3)
# Requirement already satisfied: tinycss2 in /usr/local/lib/python3.8/dist-packages (from nbconvert->notebook>=5.6.0->jupyterthemes) (1.2.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.8/dist-packages (from nbconvert->notebook>=5.6.0->jupyterthemes) (1.5.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.8/dist-packages (from nbconvert->notebook>=5.6.0->jupyterthemes) (0.7.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.8/dist-packages (from nbconvert->notebook>=5.6.0->jupyterthemes) (0.8.4)
# Requirement already satisfied: lxml in /usr/local/lib/python3.8/dist-packages (from nbconvert->notebook>=5.6.0->jupyterthemes) (4.9.2)
# Requirement already satisfied: bleach in /usr/local/lib/python3.8/dist-packages (from nbconvert->notebook>=5.6.0->jupyterthemes) (6.0.0)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.8/dist-packages (from nbconvert->notebook>=5.6.0->jupyterthemes) (0.2.2)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.8/dist-packages (from nbconvert->notebook>=5.6.0->jupyterthemes) (0.7.2)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.8/dist-packages (from nbformat->notebook>=5.6.0->jupyterthemes) (2.16.3)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.8/dist-packages (from nbformat->notebook>=5.6.0->jupyterthemes) (4.3.3)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.8/dist-packages (from jsonschema>=2.6->nbformat->notebook>=5.6.0->jupyterthemes) (0.19.3)
# Requirement already satisfied: importlib-resources>=1.4.0 in /usr/local/lib/python3.8/dist-packages (from jsonschema>=2.6->nbformat->notebook>=5.6.0->jupyterthemes) (5.12.0)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.8/dist-packages (from jsonschema>=2.6->nbformat->notebook>=5.6.0->jupyterthemes) (22.2.0)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=5.6.0->jupyterthemes) (1.15.1)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.8/dist-packages (from bleach->nbconvert->notebook>=5.6.0->jupyterthemes) (0.5.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.8/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=5.6.0->jupyterthemes) (2.21)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.8/dist-packages (from importlib-resources>=1.4.0->jsonschema>=2.6->nbformat->notebook>=5.6.0->jupyterthemes) (3.15.0)

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
# Out:
# cuda

# %%
PATH = '/content/semanticSegmentation/dataset/persona/'
TRAIN_PATH = '/content/semanticSegmentation/dataset/persona/train2/'
TRAIN_MASKS_PATH = '/content/semanticSegmentation/dataset/persona/segmentadas/'
TEST_PATH = '/content/semanticSegmentation/dataset/persona/val2/'
TEST_MASK_PATH = '/content/semanticSegmentation/dataset/persona/valS/'

# %%
# creating our own Dataset
class Car_Dataset(Dataset):
    def __init__(self, data, masks=None, img_transforms=None, mask_transforms=None):
        '''
        data - train data path
        masks - train masks path
        '''
        self.train_data = data
        self.train_masks = masks
        
        self.img_transforms = img_transforms
        self.mask_transforms = mask_transforms
        
        self.images = sorted(os.listdir(self.train_data))
        self.masks = sorted(os.listdir(self.train_masks))
        
    def __len__(self):
        if self.train_masks is not None:
            assert len(self.images)==len(self.masks), 'not the same number of images and masks'
        return len(self.images)
        
    def __getitem__(self, idx):
        image_name = os.path.join(self.train_data, self.images[idx])
        img = Image.open(image_name)
        trans = T.ToTensor()
        if self.img_transforms is not None:
            img = self.img_transforms(img)
        else:
            img =trans(img)
            img = torch.narrow(img, 1, 0, 3)
        
        if self.train_masks is not None:
            mask_name = os.path.join(self.train_masks, self.masks[idx])
            mask = Image.open(mask_name)
            if self.mask_transforms is not None:
                mask = self.mask_transforms(mask)
            else:
                mask = trans(mask)
            
            mask_max = mask.max().item()
            mask /= mask_max
        else:
            
            return img
        
        return img, mask

# %%
transform_data = T.Compose([
                T.Resize([224, 224]),
                T.ToTensor()] )

# %%
full_dataset = Car_Dataset(TRAIN_PATH,
                           TRAIN_MASKS_PATH,
                           img_transforms=transform_data,
                           mask_transforms=transform_data)

# %%
BATCH_SIZE = 32
TRAIN_SIZE = int(len(full_dataset)*0.8)
VAL_SIZE = len(full_dataset) - TRAIN_SIZE

print(TRAIN_SIZE, VAL_SIZE)
# Out:
# 41 11

# %%
train_dataset, val_dataset = random_split(full_dataset, [TRAIN_SIZE, VAL_SIZE])
print(len(train_dataset), len(val_dataset))

train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
for batch_idx, (inputs, targets) in enumerate(train_loader):
    print(f'Batch {batch_idx}: inputs={inputs.shape}, targets={targets.shape}')
#train_loader[0] = torch.narrow(train_loader[0], 1, 0, 3)
val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=True)
# Out:
# 41 11
# Batch 0: inputs=torch.Size([32, 4, 224, 224]), targets=torch.Size([32, 1, 224, 224])
# Batch 1: inputs=torch.Size([9, 4, 224, 224]), targets=torch.Size([9, 1, 224, 224])

# %%
imgs, masks = next(iter(train_loader))
print(imgs.shape, masks.shape)
#imgs = torch.narrow(imgs, 1, 0, 3)
#print(imgs.shape)
for i, (x, y) in enumerate(train_loader):
    x = torch.narrow(x, 1, 0, 3)
    print(i, x.shape, y.shape)
    if i==9: break
# Out:
# torch.Size([32, 4, 224, 224]) torch.Size([32, 1, 224, 224])
# 0 torch.Size([32, 3, 224, 224]) torch.Size([32, 1, 224, 224])
# 1 torch.Size([9, 3, 224, 224]) torch.Size([9, 1, 224, 224])

# %%
imgs, masks = next(iter(train_loader))
def plot_mini_batch(imgs, masks):
    plt.figure(figsize=(20,10))
    for i in range(BATCH_SIZE):
        plt.subplot(4, 8, i+1)
        img=imgs[i,...].permute(1,2,0).numpy()
        mask = masks[i, ...].permute(1,2,0).numpy()
        plt.imshow(img)
        plt.imshow(mask, alpha=0.5)
        
        plt.axis('Off')
    plt.tight_layout()
    plt.show()

plot_mini_batch(imgs, masks)

# %%
def accuracy(model, loader):
    correct = 0
    intersection = 0
    denom = 0
    union = 0
    total = 0
    cost = 0.
    model = model.to(device=device)
    with torch.no_grad():
        for x, y in loader:
            x = x.to(device=device, dtype = torch.float32)
            x = torch.narrow(x, 1, 0, 3)
            y = y.to(device=device, dtype = torch.long).squeeze(1)
            scores = model(x)
            cost += (F.cross_entropy(scores, y)).item()
            # standard accuracy not optimal
            preds = torch.argmax(scores, dim=1)
            correct += (preds == y).sum()
            total += torch.numel(preds)
            #dice coefficient
            intersection += (preds*y).sum()
            denom += (preds + y).sum()
            dice = 2*intersection/(denom + 1e-8)
            #intersection over union
            union += (preds + y - preds*y).sum()
            iou = (intersection)/(union + 1e-8)
            
        return cost/len(loader), float(correct)/total, dice, iou

# %%
len(train_loader)
# Out:
# 2

# %%
def find_lr(model, optimiser, start_val = 1e-6, end_val = 1, beta = 0.99, loader = train_loader):
    n = len(loader) - 1
    factor = (end_val / start_val)**(1/n)
    lr = start_val
    optimiser.param_groups[0]['lr'] = lr #this allows you to update the learning rate
    avg_loss, loss, acc = 0., 0., 0.
    lowest_loss = 0.
    batch_num = 0
    losses = []
    log_lrs = []
    accuracies = []
    model = model.to(device=device)
    for i, (x, y) in enumerate(loader, start=1):
        x = x.to(device = device, dtype = torch.float32)
        x = torch.narrow(x, 1, 0, 3)
        y = y.to(device = device, dtype = torch.long).squeeze(1)
        optimiser.zero_grad()
        scores = model(x)
        cost = F.cross_entropy(input=scores, target=y)
        loss = beta*loss + (1-beta)*cost.item()
        #bias correction
        avg_loss = loss/(1 - beta**i)
        
        preds = torch.argmax(scores, dim=1)
        acc_ = (preds == y).sum()/torch.numel(scores)
#         acc = beta*acc + (1-beta)*acc_.item()
#         avg_acc = acc/(1 - beta**i)
        #if loss is massive stop
        if i > 1 and avg_loss > 4 * lowest_loss:
            print(f'from here{i, cost.item()}')
            return log_lrs, losses, accuracies
        if avg_loss < lowest_loss or i == 1:
            lowest_loss = avg_loss

        accuracies.append(acc_.item())
#         accuracies.append(avg_acc)
        losses.append(avg_loss)
        log_lrs.append(lr)
        #step
        cost.backward()
        optimiser.step()
        #update lr
        print(f'cost:{cost.item():.4f}, lr: {lr:.4f}, acc: {acc_.item():.4f}')
        lr *= factor
        optimiser.param_groups[0]['lr'] = lr
        
    return log_lrs, losses, accuracies

# %%
def evaluate(model, loader):
    model.eval()
    model.to(device=device)
    with torch.no_grad():
        true_positives = 0
        false_positives = 0
        false_negatives = 0
        total = 0
        cost = 0
        for x, y in loader:
            x = x.to(device=device, dtype=torch.float32)
            x = torch.narrow(x, 1, 0, 3)
            y = y.to(device=device, dtype=torch.long).squeeze(1)
            scores = model(x)
            cost += (F.cross_entropy(scores, y)).item()
            preds = torch.argmax(scores, dim=1)
            true_positives += ((preds == 1) & (y == 1)).sum().item()
            false_positives += ((preds == 1) & (y == 0)).sum().item()
            false_negatives += ((preds == 0) & (y == 1)).sum().item()
            total += torch.numel(preds)
        accuracy = true_positives / total
        recall = true_positives / (true_positives + false_negatives)
        precision = true_positives / (true_positives + false_positives)
        if (precision + recall) ==0:
            f1_score = 0
        else:
            f1_score = 2 * (precision * recall) / (precision + recall)
        true_negatives = total - true_positives - false_positives - false_negatives
        confusion_matrix = [[true_positives, false_positives], [false_negatives, true_negatives]]
        print("Confusion Matrix:")
        print(confusion_matrix)
        return cost / len(loader), accuracy, recall, precision, f1_score, confusion_matrix

# %%
def train(model, optimiser, scheduler = None, epochs = 5000, store_every = 25):
    model = model.to(device=device)
    for epoch in range(epochs):
        train_correct_num = 0
        train_total = 0
        train_cost_acum = 0.
        for mb, (x, y) in enumerate(train_loader, start=1):
            model.train()
            x = x.to(device=device, dtype=torch.float32)
            x = torch.narrow(x, 1, 0, 3)
            y = y.to(device=device, dtype=torch.long).squeeze(1)
            scores = model(x)
            cost = F.cross_entropy(input=scores, target=y)
            optimiser.zero_grad()
            cost.backward()
            optimiser.step()
            
            if scheduler: 
                scheduler.step()
                
            train_predictions = torch.argmax(scores, dim=1)
            train_correct_num += (train_predictions == y).sum()
            train_total += torch.numel(train_predictions)
            train_cost_acum += cost.item()
            if mb%store_every == 0:
                val_cost, val_acc, dice, iou = accuracy(model, val_loader)
                train_acc = float(train_correct_num)/train_total
                train_cost_every = float(train_cost_acum)/mb
                loss, accuracy2, recall, precision, f1_score, confusion_matrix = evaluate(model, val_loader)
                print(f'epoch: {epoch}, mb: {mb}, train cost: {train_cost_every:.4f}, val cost: {val_cost:.4f},'
                      f'train acc: {train_acc:.4f}, val acc: {val_acc:.4f},'
                      f'dice: {dice}, iou: {iou}')
            else:
                val_cost, val_acc, dice, iou = accuracy(model, val_loader)
                train_acc = float(train_correct_num)/train_total
                train_cost_every = float(train_cost_acum)/mb
                print(f'epoch: {epoch}, mb: {mb}, train cost: {train_cost_every:.4f}, val cost: {val_cost:.4f},'
                      f'train acc: {train_acc:.4f}, val acc: {val_acc:.4f},'
                      f'dice: {dice}, iou: {iou}')              

            
                    # Save data
                    #train_acc_history.append(train_acc)
                    #train_cost_history.append(train_cost_every)
        #train_acc = float(train_correct_num)/train_total
        #train_cost_every = float(train_cost_acum)/len(train_loader)
        # return train_acc_history ... etc

# %%
class Conv_3_k(nn.Module):
    def __init__(self, channels_in, channels_out):
        super().__init__()
        self.conv1 = nn.Conv2d(channels_in, channels_out, kernel_size=3, stride=1, padding=1)
    def forward(self, x):
        return self.conv1(x)

# %%
class Double_Conv(nn.Module):
    '''
    Double convolution block for U-Net
    '''
    def __init__(self, channels_in, channels_out):
        super().__init__()
        self.double_conv = nn.Sequential(
                           Conv_3_k(channels_in, channels_out),
                           nn.BatchNorm2d(channels_out),
                           nn.ReLU(),
            
                           Conv_3_k(channels_out, channels_out),
                           nn.BatchNorm2d(channels_out),
                           nn.ReLU(),
                            )
    def forward(self, x):
        return self.double_conv(x)
    
class Down_Conv(nn.Module):
    '''
    Down convolution part
    '''
    def __init__(self, channels_in, channels_out):
        super().__init__()
        self.encoder = nn.Sequential(
                        nn.MaxPool2d(2,2),
                        Double_Conv(channels_in, channels_out)
                        )
    def forward(self, x):
        return self.encoder(x)
    
class Up_Conv(nn.Module):
    '''
    Up convolution part
    '''
    def __init__(self,channels_in, channels_out):
        super().__init__()
        self.upsample_layer = nn.Sequential(
                        nn.Upsample(scale_factor=2, mode='bicubic'),
                        nn.Conv2d(channels_in, channels_in//2, kernel_size=1, stride=1)
                        )
        self.decoder = Double_Conv(channels_in, channels_out)
    
    def forward(self, x1, x2):
        '''
        x1 - upsampled volume
        x2 - volume from down sample to concatenate
        '''
        x1 = self.upsample_layer(x1)
        x = torch.cat([x2, x1],dim=1)
        return self.decoder(x)
    
class UNET(nn.Module):
    '''
    UNET model
    '''
    def __init__(self, channels_in, channels, num_classes):
        super().__init__()
        self.first_conv = Double_Conv(channels_in, channels) #64, 224, 224
        self.down_conv1 = Down_Conv(channels, 2*channels) # 128, 112, 112
        self.down_conv2 = Down_Conv(2*channels, 4*channels) # 256, 56, 56
        self.down_conv3 = Down_Conv(4*channels, 8*channels) # 512, 28, 28
        
        self.middle_conv = Down_Conv(8*channels, 16*channels) # 1024, 14, 14 
        
        self.up_conv1 = Up_Conv(16*channels, 8*channels)
        self.up_conv2 = Up_Conv(8*channels, 4*channels)
        self.up_conv3 = Up_Conv(4*channels, 2*channels)
        self.up_conv4 = Up_Conv(2*channels, channels)
        
        self.last_conv = nn.Conv2d(channels, num_classes, kernel_size=1, stride=1)
        
    def forward(self, x):
        x1 = self.first_conv(x)
        x2 = self.down_conv1(x1)
        x3 = self.down_conv2(x2)
        x4 = self.down_conv3(x3)
        
        x5 = self.middle_conv(x4)
        
        u1 = self.up_conv1(x5, x4)
        u2 = self.up_conv2(u1, x3)
        u3 = self.up_conv3(u2, x2)
        u4 = self.up_conv4(u3, x1)
        
        return self.last_conv(u4)

# %%
def test():
    x = torch.randn((32, 3, 224, 224))
    model = UNET(3, 64, 2)
    return model(x)

preds = test()

print(preds.shape)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-66-0a456c2b5499> in <module>
#       4     return model(x)
#       5
# ----> 6 preds = test()
#       7
#       8 print(preds.shape)
#
# <ipython-input-66-0a456c2b5499> in test()
#       2     x = torch.randn((32, 3, 224, 224))
#       3     model = UNET(3, 64, 2)
# ----> 4     return model(x)
#       5
#       6 preds = test()
#
# /usr/local/lib/python3.8/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1192         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194             return forward_call(*input, **kwargs)
#    1195         # Do not call functions when jit is used
#    1196         full_backward_hooks, non_full_backward_hooks = [], []
#
# <ipython-input-65-9ad808c6bbad> in forward(self, x)
#      74         x1 = self.first_conv(x)
#      75         x2 = self.down_conv1(x1)
# ---> 76         x3 = self.down_conv2(x2)
#      77         x4 = self.down_conv3(x3)
#      78
#
# /usr/local/lib/python3.8/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1192         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194             return forward_call(*input, **kwargs)
#    1195         # Do not call functions when jit is used
#    1196         full_backward_hooks, non_full_backward_hooks = [], []
#
# <ipython-input-65-9ad808c6bbad> in forward(self, x)
#      28                         )
#      29     def forward(self, x):
# ---> 30         return self.encoder(x)
#      31
#      32 class Up_Conv(nn.Module):
#
# /usr/local/lib/python3.8/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1192         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194             return forward_call(*input, **kwargs)
#    1195         # Do not call functions when jit is used
#    1196         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.8/dist-packages/torch/nn/modules/container.py in forward(self, input)
#     202     def forward(self, input):
#     203         for module in self:
# --> 204             input = module(input)
#     205         return input
#     206
#
# /usr/local/lib/python3.8/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1192         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194             return forward_call(*input, **kwargs)
#    1195         # Do not call functions when jit is used
#    1196         full_backward_hooks, non_full_backward_hooks = [], []
#
# <ipython-input-65-9ad808c6bbad> in forward(self, x)
#      15                             )
#      16     def forward(self, x):
# ---> 17         return self.double_conv(x)
#      18
#      19 class Down_Conv(nn.Module):
#
# /usr/local/lib/python3.8/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1192         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194             return forward_call(*input, **kwargs)
#    1195         # Do not call functions when jit is used
#    1196         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.8/dist-packages/torch/nn/modules/container.py in forward(self, input)
#     202     def forward(self, input):
#     203         for module in self:
# --> 204             input = module(input)
#     205         return input
#     206
#
# /usr/local/lib/python3.8/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1192         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194             return forward_call(*input, **kwargs)
#    1195         # Do not call functions when jit is used
#    1196         full_backward_hooks, non_full_backward_hooks = [], []
#
# <ipython-input-64-2d8a856501f9> in forward(self, x)
#       4         self.conv1 = nn.Conv2d(channels_in, channels_out, kernel_size=3, stride=1, padding=1)
#       5     def forward(self, x):
# ----> 6         return self.conv1(x)
#
# /usr/local/lib/python3.8/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1192         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194             return forward_call(*input, **kwargs)
#    1195         # Do not call functions when jit is used
#    1196         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.8/dist-packages/torch/nn/modules/conv.py in forward(self, input)
#     461
#     462     def forward(self, input: Tensor) -> Tensor:
# --> 463         return self._conv_forward(input, self.weight, self.bias)
#     464
#     465 class Conv3d(_ConvNd):
#
# /usr/local/lib/python3.8/dist-packages/torch/nn/modules/conv.py in _conv_forward(self, input, weight, bias)
#     457                             weight, bias, self.stride,
#     458                             _pair(0), self.dilation, self.groups)
# --> 459         return F.conv2d(input, weight, bias, self.stride,
#     460                         self.padding, self.dilation, self.groups)
#     461
#
# KeyboardInterrupt:

# %%
# define the model and look for learning rate
torch.manual_seed(42)
model = UNET(3, 4, 2)
optimiser_unet = torch.optim.SGD(model.parameters(),
                                 lr=0.01, momentum=0.95,
                                 weight_decay=1e-4)

lg_lr, losses, accuracies = find_lr(model, optimiser_unet, start_val=1e-6, end_val=10)
# Out:
# cost:0.8988, lr: 0.0000, acc: 0.0645
# cost:0.8971, lr: 10.0000, acc: 0.0697

# %%
# plot loss vs learning rate
f1, ax1 = plt.subplots(figsize=(20,10))
ax1.plot(lg_lr, losses)
ax1.set_xscale('log')
plt.show()

# %%
# define the model and train with scheduler
torch.manual_seed(42)
model = UNET(3, 4, 2)
epochs = 10000
optimiser_unet = torch.optim.SGD(model.parameters(),
                                 lr=0.01, momentum=0.95,
                                 weight_decay=1e1)
scheduler = torch.optim.lr_scheduler.OneCycleLR(optimiser_unet, 
                                                max_lr = 1e-1,
                                                steps_per_epoch=len(train_loader),
                                                epochs=epochs, pct_start=0.43, div_factor=10, final_div_factor=1000,
                                                three_phase=True)

# %%
train(model, optimiser_unet, scheduler, epochs)
loss, accuracy2, recall, precision, f1_score, confusion_matrix = evaluate(model, val_loader)
print("Loss: {:.4f}".format(loss))
print("Accuracy: {:.4f}".format(accuracy2))
print("Recall: {:.4f}".format(recall))
print("Precision: {:.4f}".format(precision))
print("F1 Score: {:.4f}".format(f1_score))
#print("Confusion Matrix: {:.4f}".format(confusion_matrix))
# Out:
# Se han truncado las últimas 5000 líneas del flujo de salida.
# epoch: 3083, mb: 1, train cost: 0.6474, val cost: 0.6474,train acc: 0.9962, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3083, mb: 2, train cost: 0.6474, val cost: 0.6474,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3084, mb: 1, train cost: 0.6474, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3084, mb: 2, train cost: 0.6474, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3085, mb: 1, train cost: 0.6475, val cost: 0.6475,train acc: 0.9960, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3085, mb: 2, train cost: 0.6475, val cost: 0.6474,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3086, mb: 1, train cost: 0.6474, val cost: 0.6474,train acc: 0.9960, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3086, mb: 2, train cost: 0.6474, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3087, mb: 1, train cost: 0.6474, val cost: 0.6475,train acc: 0.9961, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3087, mb: 2, train cost: 0.6474, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3088, mb: 1, train cost: 0.6475, val cost: 0.6475,train acc: 0.9960, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3088, mb: 2, train cost: 0.6475, val cost: 0.6474,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3089, mb: 1, train cost: 0.6474, val cost: 0.6474,train acc: 0.9960, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3089, mb: 2, train cost: 0.6474, val cost: 0.6474,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3090, mb: 1, train cost: 0.6474, val cost: 0.6475,train acc: 0.9960, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3090, mb: 2, train cost: 0.6474, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3091, mb: 1, train cost: 0.6475, val cost: 0.6475,train acc: 0.9961, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3091, mb: 2, train cost: 0.6475, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3092, mb: 1, train cost: 0.6475, val cost: 0.6475,train acc: 0.9958, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3092, mb: 2, train cost: 0.6474, val cost: 0.6474,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3093, mb: 1, train cost: 0.6473, val cost: 0.6474,train acc: 0.9961, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3093, mb: 2, train cost: 0.6474, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3094, mb: 1, train cost: 0.6474, val cost: 0.6476,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3094, mb: 2, train cost: 0.6475, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3095, mb: 1, train cost: 0.6474, val cost: 0.6474,train acc: 0.9961, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3095, mb: 2, train cost: 0.6474, val cost: 0.6474,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3096, mb: 1, train cost: 0.6474, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3096, mb: 2, train cost: 0.6474, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3097, mb: 1, train cost: 0.6474, val cost: 0.6475,train acc: 0.9963, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3097, mb: 2, train cost: 0.6475, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3098, mb: 1, train cost: 0.6475, val cost: 0.6475,train acc: 0.9961, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3098, mb: 2, train cost: 0.6475, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3099, mb: 1, train cost: 0.6474, val cost: 0.6475,train acc: 0.9960, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3099, mb: 2, train cost: 0.6474, val cost: 0.6474,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3100, mb: 1, train cost: 0.6474, val cost: 0.6475,train acc: 0.9958, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3100, mb: 2, train cost: 0.6474, val cost: 0.6474,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3101, mb: 1, train cost: 0.6474, val cost: 0.6475,train acc: 0.9958, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3101, mb: 2, train cost: 0.6474, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3102, mb: 1, train cost: 0.6474, val cost: 0.6475,train acc: 0.9958, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3102, mb: 2, train cost: 0.6474, val cost: 0.6474,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3103, mb: 1, train cost: 0.6474, val cost: 0.6474,train acc: 0.9960, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3103, mb: 2, train cost: 0.6474, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3104, mb: 1, train cost: 0.6474, val cost: 0.6475,train acc: 0.9957, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3104, mb: 2, train cost: 0.6474, val cost: 0.6474,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3105, mb: 1, train cost: 0.6474, val cost: 0.6474,train acc: 0.9960, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3105, mb: 2, train cost: 0.6474, val cost: 0.6474,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3106, mb: 1, train cost: 0.6473, val cost: 0.6475,train acc: 0.9962, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3106, mb: 2, train cost: 0.6474, val cost: 0.6476,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3107, mb: 1, train cost: 0.6475, val cost: 0.6476,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3107, mb: 2, train cost: 0.6475, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3108, mb: 1, train cost: 0.6474, val cost: 0.6474,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3108, mb: 2, train cost: 0.6474, val cost: 0.6474,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3109, mb: 1, train cost: 0.6473, val cost: 0.6475,train acc: 0.9957, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3109, mb: 2, train cost: 0.6473, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3110, mb: 1, train cost: 0.6474, val cost: 0.6475,train acc: 0.9960, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3110, mb: 2, train cost: 0.6474, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3111, mb: 1, train cost: 0.6474, val cost: 0.6474,train acc: 0.9961, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3111, mb: 2, train cost: 0.6474, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3112, mb: 1, train cost: 0.6474, val cost: 0.6475,train acc: 0.9960, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3112, mb: 2, train cost: 0.6474, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3113, mb: 1, train cost: 0.6474, val cost: 0.6475,train acc: 0.9960, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3113, mb: 2, train cost: 0.6474, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3114, mb: 1, train cost: 0.6474, val cost: 0.6474,train acc: 0.9960, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3114, mb: 2, train cost: 0.6474, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3115, mb: 1, train cost: 0.6474, val cost: 0.6475,train acc: 0.9958, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3115, mb: 2, train cost: 0.6474, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3116, mb: 1, train cost: 0.6474, val cost: 0.6474,train acc: 0.9960, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3116, mb: 2, train cost: 0.6474, val cost: 0.6474,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3117, mb: 1, train cost: 0.6474, val cost: 0.6475,train acc: 0.9960, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3117, mb: 2, train cost: 0.6474, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3118, mb: 1, train cost: 0.6475, val cost: 0.6475,train acc: 0.9956, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3118, mb: 2, train cost: 0.6474, val cost: 0.6474,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3119, mb: 1, train cost: 0.6474, val cost: 0.6474,train acc: 0.9957, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3119, mb: 2, train cost: 0.6473, val cost: 0.6474,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3120, mb: 1, train cost: 0.6473, val cost: 0.6474,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3120, mb: 2, train cost: 0.6473, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3121, mb: 1, train cost: 0.6475, val cost: 0.6476,train acc: 0.9957, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3121, mb: 2, train cost: 0.6475, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3122, mb: 1, train cost: 0.6474, val cost: 0.6474,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3122, mb: 2, train cost: 0.6473, val cost: 0.6474,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3123, mb: 1, train cost: 0.6473, val cost: 0.6474,train acc: 0.9962, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3123, mb: 2, train cost: 0.6474, val cost: 0.6476,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3124, mb: 1, train cost: 0.6475, val cost: 0.6476,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3124, mb: 2, train cost: 0.6475, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3125, mb: 1, train cost: 0.6474, val cost: 0.6473,train acc: 0.9962, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3125, mb: 2, train cost: 0.6474, val cost: 0.6474,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3126, mb: 1, train cost: 0.6473, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3126, mb: 2, train cost: 0.6474, val cost: 0.6476,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3127, mb: 1, train cost: 0.6475, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3127, mb: 2, train cost: 0.6475, val cost: 0.6474,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3128, mb: 1, train cost: 0.6474, val cost: 0.6474,train acc: 0.9962, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3128, mb: 2, train cost: 0.6474, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3129, mb: 1, train cost: 0.6474, val cost: 0.6475,train acc: 0.9961, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3129, mb: 2, train cost: 0.6475, val cost: 0.6476,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3130, mb: 1, train cost: 0.6475, val cost: 0.6475,train acc: 0.9962, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3130, mb: 2, train cost: 0.6475, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3131, mb: 1, train cost: 0.6474, val cost: 0.6474,train acc: 0.9958, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3131, mb: 2, train cost: 0.6474, val cost: 0.6474,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3132, mb: 1, train cost: 0.6474, val cost: 0.6474,train acc: 0.9960, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3132, mb: 2, train cost: 0.6474, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3133, mb: 1, train cost: 0.6474, val cost: 0.6475,train acc: 0.9960, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3133, mb: 2, train cost: 0.6475, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3134, mb: 1, train cost: 0.6475, val cost: 0.6475,train acc: 0.9957, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3134, mb: 2, train cost: 0.6474, val cost: 0.6474,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3135, mb: 1, train cost: 0.6473, val cost: 0.6473,train acc: 0.9963, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3135, mb: 2, train cost: 0.6474, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3136, mb: 1, train cost: 0.6475, val cost: 0.6476,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3136, mb: 2, train cost: 0.6475, val cost: 0.6476,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3137, mb: 1, train cost: 0.6475, val cost: 0.6474,train acc: 0.9962, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3137, mb: 2, train cost: 0.6474, val cost: 0.6474,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3138, mb: 1, train cost: 0.6473, val cost: 0.6474,train acc: 0.9961, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3138, mb: 2, train cost: 0.6474, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3139, mb: 1, train cost: 0.6475, val cost: 0.6476,train acc: 0.9960, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3139, mb: 2, train cost: 0.6475, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3140, mb: 1, train cost: 0.6475, val cost: 0.6474,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3140, mb: 2, train cost: 0.6474, val cost: 0.6474,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3141, mb: 1, train cost: 0.6473, val cost: 0.6474,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3141, mb: 2, train cost: 0.6473, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3142, mb: 1, train cost: 0.6474, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3142, mb: 2, train cost: 0.6474, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3143, mb: 1, train cost: 0.6474, val cost: 0.6474,train acc: 0.9960, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3143, mb: 2, train cost: 0.6474, val cost: 0.6474,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3144, mb: 1, train cost: 0.6474, val cost: 0.6474,train acc: 0.9961, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3144, mb: 2, train cost: 0.6474, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3145, mb: 1, train cost: 0.6475, val cost: 0.6475,train acc: 0.9958, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3145, mb: 2, train cost: 0.6475, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3146, mb: 1, train cost: 0.6474, val cost: 0.6474,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3146, mb: 2, train cost: 0.6474, val cost: 0.6474,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3147, mb: 1, train cost: 0.6473, val cost: 0.6474,train acc: 0.9961, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3147, mb: 2, train cost: 0.6474, val cost: 0.6476,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3148, mb: 1, train cost: 0.6475, val cost: 0.6476,train acc: 0.9961, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3148, mb: 2, train cost: 0.6475, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3149, mb: 1, train cost: 0.6475, val cost: 0.6474,train acc: 0.9961, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3149, mb: 2, train cost: 0.6474, val cost: 0.6474,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3150, mb: 1, train cost: 0.6473, val cost: 0.6474,train acc: 0.9962, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3150, mb: 2, train cost: 0.6474, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3151, mb: 1, train cost: 0.6475, val cost: 0.6476,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3151, mb: 2, train cost: 0.6475, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3152, mb: 1, train cost: 0.6474, val cost: 0.6474,train acc: 0.9960, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3152, mb: 2, train cost: 0.6474, val cost: 0.6474,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3153, mb: 1, train cost: 0.6473, val cost: 0.6474,train acc: 0.9960, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3153, mb: 2, train cost: 0.6474, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3154, mb: 1, train cost: 0.6475, val cost: 0.6476,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3154, mb: 2, train cost: 0.6475, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3155, mb: 1, train cost: 0.6474, val cost: 0.6474,train acc: 0.9961, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3155, mb: 2, train cost: 0.6474, val cost: 0.6474,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3156, mb: 1, train cost: 0.6473, val cost: 0.6475,train acc: 0.9962, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3156, mb: 2, train cost: 0.6474, val cost: 0.6476,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3157, mb: 1, train cost: 0.6475, val cost: 0.6476,train acc: 0.9961, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3157, mb: 2, train cost: 0.6475, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3158, mb: 1, train cost: 0.6474, val cost: 0.6474,train acc: 0.9963, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3158, mb: 2, train cost: 0.6474, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3159, mb: 1, train cost: 0.6474, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3159, mb: 2, train cost: 0.6474, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3160, mb: 1, train cost: 0.6475, val cost: 0.6475,train acc: 0.9958, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3160, mb: 2, train cost: 0.6474, val cost: 0.6474,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3161, mb: 1, train cost: 0.6473, val cost: 0.6474,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3161, mb: 2, train cost: 0.6473, val cost: 0.6474,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3162, mb: 1, train cost: 0.6474, val cost: 0.6475,train acc: 0.9960, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3162, mb: 2, train cost: 0.6474, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3163, mb: 1, train cost: 0.6475, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3163, mb: 2, train cost: 0.6475, val cost: 0.6474,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3164, mb: 1, train cost: 0.6474, val cost: 0.6474,train acc: 0.9957, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3164, mb: 2, train cost: 0.6473, val cost: 0.6474,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3165, mb: 1, train cost: 0.6473, val cost: 0.6475,train acc: 0.9958, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3165, mb: 2, train cost: 0.6473, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3166, mb: 1, train cost: 0.6474, val cost: 0.6475,train acc: 0.9958, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3166, mb: 2, train cost: 0.6474, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3167, mb: 1, train cost: 0.6474, val cost: 0.6474,train acc: 0.9958, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3167, mb: 2, train cost: 0.6474, val cost: 0.6474,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3168, mb: 1, train cost: 0.6474, val cost: 0.6474,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3168, mb: 2, train cost: 0.6474, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3169, mb: 1, train cost: 0.6474, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3169, mb: 2, train cost: 0.6474, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3170, mb: 1, train cost: 0.6474, val cost: 0.6475,train acc: 0.9958, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3170, mb: 2, train cost: 0.6474, val cost: 0.6474,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3171, mb: 1, train cost: 0.6474, val cost: 0.6474,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3171, mb: 2, train cost: 0.6474, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3172, mb: 1, train cost: 0.6474, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3172, mb: 2, train cost: 0.6474, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3173, mb: 1, train cost: 0.6474, val cost: 0.6474,train acc: 0.9960, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3173, mb: 2, train cost: 0.6474, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3174, mb: 1, train cost: 0.6474, val cost: 0.6475,train acc: 0.9960, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3174, mb: 2, train cost: 0.6474, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3175, mb: 1, train cost: 0.6474, val cost: 0.6475,train acc: 0.9962, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3175, mb: 2, train cost: 0.6474, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3176, mb: 1, train cost: 0.6474, val cost: 0.6475,train acc: 0.9962, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3176, mb: 2, train cost: 0.6475, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3177, mb: 1, train cost: 0.6475, val cost: 0.6475,train acc: 0.9960, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3177, mb: 2, train cost: 0.6475, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3178, mb: 1, train cost: 0.6474, val cost: 0.6474,train acc: 0.9961, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3178, mb: 2, train cost: 0.6474, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3179, mb: 1, train cost: 0.6474, val cost: 0.6475,train acc: 0.9960, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3179, mb: 2, train cost: 0.6474, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3180, mb: 1, train cost: 0.6474, val cost: 0.6475,train acc: 0.9962, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3180, mb: 2, train cost: 0.6475, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3181, mb: 1, train cost: 0.6475, val cost: 0.6475,train acc: 0.9958, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3181, mb: 2, train cost: 0.6474, val cost: 0.6474,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3182, mb: 1, train cost: 0.6474, val cost: 0.6474,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3182, mb: 2, train cost: 0.6474, val cost: 0.6474,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3183, mb: 1, train cost: 0.6474, val cost: 0.6475,train acc: 0.9958, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3183, mb: 2, train cost: 0.6474, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3184, mb: 1, train cost: 0.6474, val cost: 0.6475,train acc: 0.9958, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3184, mb: 2, train cost: 0.6474, val cost: 0.6474,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3185, mb: 1, train cost: 0.6474, val cost: 0.6474,train acc: 0.9961, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3185, mb: 2, train cost: 0.6474, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3186, mb: 1, train cost: 0.6474, val cost: 0.6475,train acc: 0.9958, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3186, mb: 2, train cost: 0.6474, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3187, mb: 1, train cost: 0.6474, val cost: 0.6474,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3187, mb: 2, train cost: 0.6474, val cost: 0.6474,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3188, mb: 1, train cost: 0.6473, val cost: 0.6474,train acc: 0.9962, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3188, mb: 2, train cost: 0.6474, val cost: 0.6476,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3189, mb: 1, train cost: 0.6475, val cost: 0.6476,train acc: 0.9962, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3189, mb: 2, train cost: 0.6475, val cost: 0.6476,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3190, mb: 1, train cost: 0.6475, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3190, mb: 2, train cost: 0.6474, val cost: 0.6474,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3191, mb: 1, train cost: 0.6473, val cost: 0.6474,train acc: 0.9960, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3191, mb: 2, train cost: 0.6473, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3192, mb: 1, train cost: 0.6474, val cost: 0.6476,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3192, mb: 2, train cost: 0.6475, val cost: 0.6476,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3193, mb: 1, train cost: 0.6475, val cost: 0.6475,train acc: 0.9960, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3193, mb: 2, train cost: 0.6475, val cost: 0.6474,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3194, mb: 1, train cost: 0.6473, val cost: 0.6474,train acc: 0.9961, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3194, mb: 2, train cost: 0.6474, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3195, mb: 1, train cost: 0.6475, val cost: 0.6476,train acc: 0.9957, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3195, mb: 2, train cost: 0.6474, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3196, mb: 1, train cost: 0.6474, val cost: 0.6474,train acc: 0.9960, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3196, mb: 2, train cost: 0.6474, val cost: 0.6474,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3197, mb: 1, train cost: 0.6473, val cost: 0.6475,train acc: 0.9958, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3197, mb: 2, train cost: 0.6474, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3198, mb: 1, train cost: 0.6474, val cost: 0.6475,train acc: 0.9960, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3198, mb: 2, train cost: 0.6474, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3199, mb: 1, train cost: 0.6474, val cost: 0.6475,train acc: 0.9960, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3199, mb: 2, train cost: 0.6474, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3200, mb: 1, train cost: 0.6474, val cost: 0.6475,train acc: 0.9961, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3200, mb: 2, train cost: 0.6474, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3201, mb: 1, train cost: 0.6474, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3201, mb: 2, train cost: 0.6474, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3202, mb: 1, train cost: 0.6474, val cost: 0.6475,train acc: 0.9958, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3202, mb: 2, train cost: 0.6474, val cost: 0.6474,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3203, mb: 1, train cost: 0.6474, val cost: 0.6474,train acc: 0.9958, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3203, mb: 2, train cost: 0.6473, val cost: 0.6474,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3204, mb: 1, train cost: 0.6474, val cost: 0.6475,train acc: 0.9960, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3204, mb: 2, train cost: 0.6474, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3205, mb: 1, train cost: 0.6474, val cost: 0.6475,train acc: 0.9962, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3205, mb: 2, train cost: 0.6475, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3206, mb: 1, train cost: 0.6475, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3206, mb: 2, train cost: 0.6474, val cost: 0.6474,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3207, mb: 1, train cost: 0.6474, val cost: 0.6474,train acc: 0.9960, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3207, mb: 2, train cost: 0.6474, val cost: 0.6474,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3208, mb: 1, train cost: 0.6474, val cost: 0.6475,train acc: 0.9962, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3208, mb: 2, train cost: 0.6474, val cost: 0.6476,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3209, mb: 1, train cost: 0.6475, val cost: 0.6476,train acc: 0.9960, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3209, mb: 2, train cost: 0.6475, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3210, mb: 1, train cost: 0.6474, val cost: 0.6474,train acc: 0.9960, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3210, mb: 2, train cost: 0.6474, val cost: 0.6474,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3211, mb: 1, train cost: 0.6473, val cost: 0.6475,train acc: 0.9960, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3211, mb: 2, train cost: 0.6474, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3212, mb: 1, train cost: 0.6475, val cost: 0.6475,train acc: 0.9960, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3212, mb: 2, train cost: 0.6475, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3213, mb: 1, train cost: 0.6474, val cost: 0.6474,train acc: 0.9958, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3213, mb: 2, train cost: 0.6474, val cost: 0.6474,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3214, mb: 1, train cost: 0.6473, val cost: 0.6474,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3214, mb: 2, train cost: 0.6473, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3215, mb: 1, train cost: 0.6474, val cost: 0.6475,train acc: 0.9960, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3215, mb: 2, train cost: 0.6475, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3216, mb: 1, train cost: 0.6475, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3216, mb: 2, train cost: 0.6474, val cost: 0.6474,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3217, mb: 1, train cost: 0.6473, val cost: 0.6474,train acc: 0.9960, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3217, mb: 2, train cost: 0.6473, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3218, mb: 1, train cost: 0.6474, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3218, mb: 2, train cost: 0.6474, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3219, mb: 1, train cost: 0.6475, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3219, mb: 2, train cost: 0.6474, val cost: 0.6474,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3220, mb: 1, train cost: 0.6474, val cost: 0.6474,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3220, mb: 2, train cost: 0.6473, val cost: 0.6474,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3221, mb: 1, train cost: 0.6474, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3221, mb: 2, train cost: 0.6474, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3222, mb: 1, train cost: 0.6474, val cost: 0.6475,train acc: 0.9960, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3222, mb: 2, train cost: 0.6474, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3223, mb: 1, train cost: 0.6474, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3223, mb: 2, train cost: 0.6474, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3224, mb: 1, train cost: 0.6474, val cost: 0.6475,train acc: 0.9961, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3224, mb: 2, train cost: 0.6474, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3225, mb: 1, train cost: 0.6475, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3225, mb: 2, train cost: 0.6474, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3226, mb: 1, train cost: 0.6474, val cost: 0.6474,train acc: 0.9957, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3226, mb: 2, train cost: 0.6474, val cost: 0.6474,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3227, mb: 1, train cost: 0.6473, val cost: 0.6474,train acc: 0.9958, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3227, mb: 2, train cost: 0.6473, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3228, mb: 1, train cost: 0.6474, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3228, mb: 2, train cost: 0.6474, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3229, mb: 1, train cost: 0.6474, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3229, mb: 2, train cost: 0.6474, val cost: 0.6474,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3230, mb: 1, train cost: 0.6474, val cost: 0.6474,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3230, mb: 2, train cost: 0.6474, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3231, mb: 1, train cost: 0.6474, val cost: 0.6475,train acc: 0.9961, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3231, mb: 2, train cost: 0.6474, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3232, mb: 1, train cost: 0.6475, val cost: 0.6475,train acc: 0.9958, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3232, mb: 2, train cost: 0.6474, val cost: 0.6474,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3233, mb: 1, train cost: 0.6474, val cost: 0.6474,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3233, mb: 2, train cost: 0.6474, val cost: 0.6474,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3234, mb: 1, train cost: 0.6474, val cost: 0.6475,train acc: 0.9960, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3234, mb: 2, train cost: 0.6474, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3235, mb: 1, train cost: 0.6475, val cost: 0.6475,train acc: 0.9958, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3235, mb: 2, train cost: 0.6475, val cost: 0.6474,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3236, mb: 1, train cost: 0.6474, val cost: 0.6474,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3236, mb: 2, train cost: 0.6473, val cost: 0.6474,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3237, mb: 1, train cost: 0.6473, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3237, mb: 2, train cost: 0.6474, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3238, mb: 1, train cost: 0.6475, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3238, mb: 2, train cost: 0.6475, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3239, mb: 1, train cost: 0.6474, val cost: 0.6474,train acc: 0.9958, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3239, mb: 2, train cost: 0.6474, val cost: 0.6474,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3240, mb: 1, train cost: 0.6473, val cost: 0.6474,train acc: 0.9958, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3240, mb: 2, train cost: 0.6473, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3241, mb: 1, train cost: 0.6474, val cost: 0.6475,train acc: 0.9958, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3241, mb: 2, train cost: 0.6474, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3242, mb: 1, train cost: 0.6474, val cost: 0.6474,train acc: 0.9961, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3242, mb: 2, train cost: 0.6474, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3243, mb: 1, train cost: 0.6474, val cost: 0.6475,train acc: 0.9962, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3243, mb: 2, train cost: 0.6475, val cost: 0.6476,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3244, mb: 1, train cost: 0.6475, val cost: 0.6476,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3244, mb: 2, train cost: 0.6475, val cost: 0.6474,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3245, mb: 1, train cost: 0.6474, val cost: 0.6474,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3245, mb: 2, train cost: 0.6473, val cost: 0.6474,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3246, mb: 1, train cost: 0.6473, val cost: 0.6475,train acc: 0.9960, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3246, mb: 2, train cost: 0.6474, val cost: 0.6476,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3247, mb: 1, train cost: 0.6475, val cost: 0.6475,train acc: 0.9961, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3247, mb: 2, train cost: 0.6475, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3248, mb: 1, train cost: 0.6474, val cost: 0.6474,train acc: 0.9961, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3248, mb: 2, train cost: 0.6474, val cost: 0.6474,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3249, mb: 1, train cost: 0.6474, val cost: 0.6474,train acc: 0.9961, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3249, mb: 2, train cost: 0.6474, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3250, mb: 1, train cost: 0.6475, val cost: 0.6476,train acc: 0.9957, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3250, mb: 2, train cost: 0.6475, val cost: 0.6474,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3251, mb: 1, train cost: 0.6474, val cost: 0.6473,train acc: 0.9960, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3251, mb: 2, train cost: 0.6473, val cost: 0.6474,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3252, mb: 1, train cost: 0.6473, val cost: 0.6475,train acc: 0.9961, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3252, mb: 2, train cost: 0.6474, val cost: 0.6476,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3253, mb: 1, train cost: 0.6475, val cost: 0.6475,train acc: 0.9962, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3253, mb: 2, train cost: 0.6475, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3254, mb: 1, train cost: 0.6474, val cost: 0.6475,train acc: 0.9960, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3254, mb: 2, train cost: 0.6474, val cost: 0.6474,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3255, mb: 1, train cost: 0.6474, val cost: 0.6474,train acc: 0.9960, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3255, mb: 2, train cost: 0.6474, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3256, mb: 1, train cost: 0.6474, val cost: 0.6475,train acc: 0.9960, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3256, mb: 2, train cost: 0.6475, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3257, mb: 1, train cost: 0.6475, val cost: 0.6475,train acc: 0.9958, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3257, mb: 2, train cost: 0.6474, val cost: 0.6474,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3258, mb: 1, train cost: 0.6473, val cost: 0.6474,train acc: 0.9961, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3258, mb: 2, train cost: 0.6473, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3259, mb: 1, train cost: 0.6474, val cost: 0.6476,train acc: 0.9960, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3259, mb: 2, train cost: 0.6475, val cost: 0.6476,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3260, mb: 1, train cost: 0.6475, val cost: 0.6475,train acc: 0.9958, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3260, mb: 2, train cost: 0.6475, val cost: 0.6474,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3261, mb: 1, train cost: 0.6473, val cost: 0.6473,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3261, mb: 2, train cost: 0.6473, val cost: 0.6474,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3262, mb: 1, train cost: 0.6474, val cost: 0.6476,train acc: 0.9960, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3262, mb: 2, train cost: 0.6474, val cost: 0.6476,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3263, mb: 1, train cost: 0.6475, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3263, mb: 2, train cost: 0.6475, val cost: 0.6474,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3264, mb: 1, train cost: 0.6473, val cost: 0.6474,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3264, mb: 2, train cost: 0.6473, val cost: 0.6474,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3265, mb: 1, train cost: 0.6474, val cost: 0.6475,train acc: 0.9958, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3265, mb: 2, train cost: 0.6474, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3266, mb: 1, train cost: 0.6475, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3266, mb: 2, train cost: 0.6474, val cost: 0.6474,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3267, mb: 1, train cost: 0.6473, val cost: 0.6474,train acc: 0.9961, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3267, mb: 2, train cost: 0.6474, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3268, mb: 1, train cost: 0.6474, val cost: 0.6476,train acc: 0.9960, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3268, mb: 2, train cost: 0.6475, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3269, mb: 1, train cost: 0.6475, val cost: 0.6475,train acc: 0.9960, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3269, mb: 2, train cost: 0.6474, val cost: 0.6474,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3270, mb: 1, train cost: 0.6473, val cost: 0.6474,train acc: 0.9960, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3270, mb: 2, train cost: 0.6474, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3271, mb: 1, train cost: 0.6474, val cost: 0.6476,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3271, mb: 2, train cost: 0.6475, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3272, mb: 1, train cost: 0.6474, val cost: 0.6474,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3272, mb: 2, train cost: 0.6474, val cost: 0.6474,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3273, mb: 1, train cost: 0.6473, val cost: 0.6474,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3273, mb: 2, train cost: 0.6473, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3274, mb: 1, train cost: 0.6474, val cost: 0.6475,train acc: 0.9960, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3274, mb: 2, train cost: 0.6474, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3275, mb: 1, train cost: 0.6475, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3275, mb: 2, train cost: 0.6474, val cost: 0.6474,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3276, mb: 1, train cost: 0.6474, val cost: 0.6474,train acc: 0.9960, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3276, mb: 2, train cost: 0.6474, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3277, mb: 1, train cost: 0.6474, val cost: 0.6475,train acc: 0.9961, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3277, mb: 2, train cost: 0.6474, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3278, mb: 1, train cost: 0.6475, val cost: 0.6475,train acc: 0.9961, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3278, mb: 2, train cost: 0.6475, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3279, mb: 1, train cost: 0.6474, val cost: 0.6474,train acc: 0.9962, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3279, mb: 2, train cost: 0.6474, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3280, mb: 1, train cost: 0.6474, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3280, mb: 2, train cost: 0.6474, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3281, mb: 1, train cost: 0.6474, val cost: 0.6475,train acc: 0.9958, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3281, mb: 2, train cost: 0.6474, val cost: 0.6474,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3282, mb: 1, train cost: 0.6473, val cost: 0.6474,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3282, mb: 2, train cost: 0.6473, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3283, mb: 1, train cost: 0.6474, val cost: 0.6475,train acc: 0.9961, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3283, mb: 2, train cost: 0.6474, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3284, mb: 1, train cost: 0.6475, val cost: 0.6475,train acc: 0.9958, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3284, mb: 2, train cost: 0.6475, val cost: 0.6474,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3285, mb: 1, train cost: 0.6474, val cost: 0.6474,train acc: 0.9958, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3285, mb: 2, train cost: 0.6473, val cost: 0.6474,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3286, mb: 1, train cost: 0.6473, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3286, mb: 2, train cost: 0.6474, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3287, mb: 1, train cost: 0.6475, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3287, mb: 2, train cost: 0.6475, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3288, mb: 1, train cost: 0.6474, val cost: 0.6474,train acc: 0.9961, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3288, mb: 2, train cost: 0.6474, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3289, mb: 1, train cost: 0.6474, val cost: 0.6475,train acc: 0.9961, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3289, mb: 2, train cost: 0.6474, val cost: 0.6476,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3290, mb: 1, train cost: 0.6475, val cost: 0.6476,train acc: 0.9956, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3290, mb: 2, train cost: 0.6475, val cost: 0.6474,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3291, mb: 1, train cost: 0.6473, val cost: 0.6473,train acc: 0.9961, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3291, mb: 2, train cost: 0.6473, val cost: 0.6474,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3292, mb: 1, train cost: 0.6474, val cost: 0.6476,train acc: 0.9960, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3292, mb: 2, train cost: 0.6474, val cost: 0.6476,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3293, mb: 1, train cost: 0.6476, val cost: 0.6475,train acc: 0.9958, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3293, mb: 2, train cost: 0.6475, val cost: 0.6473,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3294, mb: 1, train cost: 0.6473, val cost: 0.6473,train acc: 0.9960, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3294, mb: 2, train cost: 0.6473, val cost: 0.6474,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3295, mb: 1, train cost: 0.6474, val cost: 0.6476,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3295, mb: 2, train cost: 0.6474, val cost: 0.6476,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3296, mb: 1, train cost: 0.6475, val cost: 0.6475,train acc: 0.9960, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 3296, mb: 2, train cost: 0.6475, val cost: 0.6474,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# ...
# epoch: 5512, mb: 1, train cost: 0.6475, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 5512, mb: 2, train cost: 0.6475, val cost: 0.6474,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 5513, mb: 1, train cost: 0.6474, val cost: 0.6474,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 5513, mb: 2, train cost: 0.6474, val cost: 0.6474,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 5514, mb: 1, train cost: 0.6473, val cost: 0.6475,train acc: 0.9960, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 5514, mb: 2, train cost: 0.6474, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 5515, mb: 1, train cost: 0.6475, val cost: 0.6475,train acc: 0.9960, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 5515, mb: 2, train cost: 0.6475, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 5516, mb: 1, train cost: 0.6474, val cost: 0.6474,train acc: 0.9958, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 5516, mb: 2, train cost: 0.6474, val cost: 0.6474,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 5517, mb: 1, train cost: 0.6473, val cost: 0.6474,train acc: 0.9961, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 5517, mb: 2, train cost: 0.6474, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 5518, mb: 1, train cost: 0.6474, val cost: 0.6475,train acc: 0.9961, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 5518, mb: 2, train cost: 0.6475, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 5519, mb: 1, train cost: 0.6475, val cost: 0.6475,train acc: 0.9961, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 5519, mb: 2, train cost: 0.6475, val cost: 0.6474,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 5520, mb: 1, train cost: 0.6474, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 5520, mb: 2, train cost: 0.6474, val cost: 0.6474,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 5521, mb: 1, train cost: 0.6474, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 5521, mb: 2, train cost: 0.6474, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 5522, mb: 1, train cost: 0.6474, val cost: 0.6475,train acc: 0.9960, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 5522, mb: 2, train cost: 0.6474, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 5523, mb: 1, train cost: 0.6474, val cost: 0.6475,train acc: 0.9960, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 5523, mb: 2, train cost: 0.6474, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 5524, mb: 1, train cost: 0.6474, val cost: 0.6475,train acc: 0.9960, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 5524, mb: 2, train cost: 0.6474, val cost: 0.6474,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 5525, mb: 1, train cost: 0.6474, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 5525, mb: 2, train cost: 0.6474, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 5526, mb: 1, train cost: 0.6474, val cost: 0.6474,train acc: 0.9961, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 5526, mb: 2, train cost: 0.6474, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 5527, mb: 1, train cost: 0.6474, val cost: 0.6475,train acc: 0.9961, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 5527, mb: 2, train cost: 0.6475, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 5528, mb: 1, train cost: 0.6475, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 5528, mb: 2, train cost: 0.6474, val cost: 0.6474,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 5529, mb: 1, train cost: 0.6474, val cost: 0.6474,train acc: 0.9962, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 5529, mb: 2, train cost: 0.6474, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 5530, mb: 1, train cost: 0.6475, val cost: 0.6476,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 5530, mb: 2, train cost: 0.6475, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 5531, mb: 1, train cost: 0.6475, val cost: 0.6474,train acc: 0.9958, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 5531, mb: 2, train cost: 0.6474, val cost: 0.6474,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 5532, mb: 1, train cost: 0.6473, val cost: 0.6474,train acc: 0.9962, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 5532, mb: 2, train cost: 0.6474, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 5533, mb: 1, train cost: 0.6475, val cost: 0.6476,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 5533, mb: 2, train cost: 0.6475, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 5534, mb: 1, train cost: 0.6475, val cost: 0.6474,train acc: 0.9962, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 5534, mb: 2, train cost: 0.6474, val cost: 0.6474,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 5535, mb: 1, train cost: 0.6473, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 5535, mb: 2, train cost: 0.6474, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 5536, mb: 1, train cost: 0.6475, val cost: 0.6475,train acc: 0.9957, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 5536, mb: 2, train cost: 0.6474, val cost: 0.6474,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 5537, mb: 1, train cost: 0.6474, val cost: 0.6474,train acc: 0.9961, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 5537, mb: 2, train cost: 0.6474, val cost: 0.6474,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 5538, mb: 1, train cost: 0.6474, val cost: 0.6475,train acc: 0.9961, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 5538, mb: 2, train cost: 0.6474, val cost: 0.6476,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 5539, mb: 1, train cost: 0.6475, val cost: 0.6475,train acc: 0.9961, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 5539, mb: 2, train cost: 0.6475, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 5540, mb: 1, train cost: 0.6474, val cost: 0.6474,train acc: 0.9960, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 5540, mb: 2, train cost: 0.6474, val cost: 0.6474,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 5541, mb: 1, train cost: 0.6474, val cost: 0.6475,train acc: 0.9960, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 5541, mb: 2, train cost: 0.6474, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 5542, mb: 1, train cost: 0.6474, val cost: 0.6475,train acc: 0.9960, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 5542, mb: 2, train cost: 0.6475, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 5543, mb: 1, train cost: 0.6474, val cost: 0.6475,train acc: 0.9960, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 5543, mb: 2, train cost: 0.6474, val cost: 0.6474,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 5544, mb: 1, train cost: 0.6473, val cost: 0.6474,train acc: 0.9964, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 5544, mb: 2, train cost: 0.6474, val cost: 0.6476,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 5545, mb: 1, train cost: 0.6475, val cost: 0.6476,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 5545, mb: 2, train cost: 0.6475, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 5546, mb: 1, train cost: 0.6474, val cost: 0.6474,train acc: 0.9962, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 5546, mb: 2, train cost: 0.6474, val cost: 0.6474,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 5547, mb: 1, train cost: 0.6473, val cost: 0.6475,train acc: 0.9960, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 5547, mb: 2, train cost: 0.6474, val cost: 0.6476,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 5548, mb: 1, train cost: 0.6475, val cost: 0.6475,train acc: 0.9961, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 5548, mb: 2, train cost: 0.6475, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 5549, mb: 1, train cost: 0.6474, val cost: 0.6474,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 5549, mb: 2, train cost: 0.6474, val cost: 0.6474,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 5550, mb: 1, train cost: 0.6474, val cost: 0.6474,train acc: 0.9958, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 5550, mb: 2, train cost: 0.6473, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 5551, mb: 1, train cost: 0.6474, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 5551, mb: 2, train cost: 0.6474, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 5552, mb: 1, train cost: 0.6474, val cost: 0.6475,train acc: 0.9960, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 5552, mb: 2, train cost: 0.6474, val cost: 0.6474,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 5553, mb: 1, train cost: 0.6474, val cost: 0.6475,train acc: 0.9958, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 5553, mb: 2, train cost: 0.6474, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 5554, mb: 1, train cost: 0.6474, val cost: 0.6475,train acc: 0.9960, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 5554, mb: 2, train cost: 0.6474, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 5555, mb: 1, train cost: 0.6474, val cost: 0.6475,train acc: 0.9960, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 5555, mb: 2, train cost: 0.6474, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 5556, mb: 1, train cost: 0.6474, val cost: 0.6475,train acc: 0.9960, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 5556, mb: 2, train cost: 0.6474, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 5557, mb: 1, train cost: 0.6474, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 5557, mb: 2, train cost: 0.6474, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 5558, mb: 1, train cost: 0.6474, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 5558, mb: 2, train cost: 0.6474, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 5559, mb: 1, train cost: 0.6474, val cost: 0.6475,train acc: 0.9962, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 5559, mb: 2, train cost: 0.6474, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 5560, mb: 1, train cost: 0.6475, val cost: 0.6475,train acc: 0.9960, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 5560, mb: 2, train cost: 0.6475, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 5561, mb: 1, train cost: 0.6474, val cost: 0.6474,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 5561, mb: 2, train cost: 0.6474, val cost: 0.6474,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 5562, mb: 1, train cost: 0.6474, val cost: 0.6474,train acc: 0.9958, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 5562, mb: 2, train cost: 0.6473, val cost: 0.6474,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 5563, mb: 1, train cost: 0.6474, val cost: 0.6474,train acc: 0.9962, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 5563, mb: 2, train cost: 0.6474, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 5564, mb: 1, train cost: 0.6475, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 5564, mb: 2, train cost: 0.6475, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 5565, mb: 1, train cost: 0.6474, val cost: 0.6474,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 5565, mb: 2, train cost: 0.6474, val cost: 0.6474,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 5566, mb: 1, train cost: 0.6473, val cost: 0.6474,train acc: 0.9958, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 5566, mb: 2, train cost: 0.6473, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 5567, mb: 1, train cost: 0.6474, val cost: 0.6475,train acc: 0.9961, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 5567, mb: 2, train cost: 0.6474, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 5568, mb: 1, train cost: 0.6475, val cost: 0.6475,train acc: 0.9958, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 5568, mb: 2, train cost: 0.6475, val cost: 0.6474,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 5569, mb: 1, train cost: 0.6474, val cost: 0.6474,train acc: 0.9960, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 5569, mb: 2, train cost: 0.6473, val cost: 0.6474,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 5570, mb: 1, train cost: 0.6474, val cost: 0.6475,train acc: 0.9958, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 5570, mb: 2, train cost: 0.6474, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 5571, mb: 1, train cost: 0.6474, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 5571, mb: 2, train cost: 0.6474, val cost: 0.6474,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 5572, mb: 1, train cost: 0.6474, val cost: 0.6474,train acc: 0.9962, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 5572, mb: 2, train cost: 0.6474, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 5573, mb: 1, train cost: 0.6475, val cost: 0.6476,train acc: 0.9958, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 5573, mb: 2, train cost: 0.6475, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 5574, mb: 1, train cost: 0.6474, val cost: 0.6474,train acc: 0.9961, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 5574, mb: 2, train cost: 0.6474, val cost: 0.6474,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 5575, mb: 1, train cost: 0.6474, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 5575, mb: 2, train cost: 0.6474, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 5576, mb: 1, train cost: 0.6475, val cost: 0.6475,train acc: 0.9961, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 5576, mb: 2, train cost: 0.6475, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 5577, mb: 1, train cost: 0.6474, val cost: 0.6475,train acc: 0.9960, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 5577, mb: 2, train cost: 0.6474, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 5578, mb: 1, train cost: 0.6474, val cost: 0.6475,train acc: 0.9960, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 5578, mb: 2, train cost: 0.6474, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 5579, mb: 1, train cost: 0.6474, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 5579, mb: 2, train cost: 0.6474, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 5580, mb: 1, train cost: 0.6474, val cost: 0.6474,train acc: 0.9960, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 5580, mb: 2, train cost: 0.6474, val cost: 0.6474,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 5581, mb: 1, train cost: 0.6474, val cost: 0.6475,train acc: 0.9957, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 5581, mb: 2, train cost: 0.6474, val cost: 0.6474,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 5582, mb: 1, train cost: 0.6474, val cost: 0.6474,train acc: 0.9962, val acc: 0.9953,dice: 0.0, iou: 0.0
# epoch: 5582, mb: 2, train cost: 0.6474, val cost: 0.6475,train acc: 0.9959, val acc: 0.9953,dice: 0.0, iou: 0.0

# %%
print("Confusion Matrix:")
print(confusion_matrix)
# Out:
# Confusion Matrix:
# [[1802, 351], [418, 549365]]

# %%
imgs_val, masks_val = next(iter(val_loader))
imgs_val = imgs_val.to(device, dtype=torch.float32)
imgs_val = torch.narrow(imgs_val, 1, 0, 3)
model = model.to(device)
with torch.no_grad():
    scores = model(imgs_val)
    preds = torch.argmax(scores, dim=1).float()

imgs_val = imgs_val.cpu()
preds = preds.cpu()
print(preds.shape)
plot_mini_batch(imgs_val, preds.unsqueeze(1))
# Out:
# torch.Size([11, 224, 224])
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-71-f839fdb9eb26> in <module>
#      10 preds = preds.cpu()
#      11 print(preds.shape)
# ---> 12 plot_mini_batch(imgs_val, preds.unsqueeze(1))
#
# <ipython-input-59-7ee0a7218a14> in plot_mini_batch(imgs, masks)
#       4     for i in range(BATCH_SIZE):
#       5         plt.subplot(4, 8, i+1)
# ----> 6         img=imgs[i,...].permute(1,2,0).numpy()
#       7         mask = masks[i, ...].permute(1,2,0).numpy()
#       8         plt.imshow(img)
#
# IndexError: index 11 is out of bounds for dimension 0 with size 11

# %%
test_set = Car_Dataset(TEST_PATH, img_transforms=transform_data)
test_loader = DataLoader(test_set, batch_size=BATCH_SIZE, shuffle=True)

# %%
imgs_test = next(iter(test_loader))
imgs_test = imgs_test.to(device, dtype=torch.float32)
imgs_test = torch.narrow(imgs_val, 1, 0, 3)
model = model.to(device)
with torch.no_grad():
    scores = model(imgs_test)
    preds = torch.argmax(scores, dim=1).float()

imgs_test = imgs_test.cpu()
preds = preds.cpu()
print(preds.shape)
plot_mini_batch(imgs_test, preds.unsqueeze(1))
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-42-0da95da3f6cc> in <module>
#       4 model = model.to(device)
#       5 with torch.no_grad():
# ----> 6     scores = model(imgs_test)
#       7     preds = torch.argmax(scores, dim=1).float()
#       8
#
# /usr/local/lib/python3.8/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1192         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194             return forward_call(*input, **kwargs)
#    1195         # Do not call functions when jit is used
#    1196         full_backward_hooks, non_full_backward_hooks = [], []
#
# <ipython-input-27-9ad808c6bbad> in forward(self, x)
#      72
#      73     def forward(self, x):
# ---> 74         x1 = self.first_conv(x)
#      75         x2 = self.down_conv1(x1)
#      76         x3 = self.down_conv2(x2)
#
# /usr/local/lib/python3.8/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1192         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194             return forward_call(*input, **kwargs)
#    1195         # Do not call functions when jit is used
#    1196         full_backward_hooks, non_full_backward_hooks = [], []
#
# <ipython-input-27-9ad808c6bbad> in forward(self, x)
#      15                             )
#      16     def forward(self, x):
# ---> 17         return self.double_conv(x)
#      18
#      19 class Down_Conv(nn.Module):
#
# /usr/local/lib/python3.8/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1192         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194             return forward_call(*input, **kwargs)
#    1195         # Do not call functions when jit is used
#    1196         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.8/dist-packages/torch/nn/modules/container.py in forward(self, input)
#     202     def forward(self, input):
#     203         for module in self:
# --> 204             input = module(input)
#     205         return input
#     206
#
# /usr/local/lib/python3.8/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1192         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194             return forward_call(*input, **kwargs)
#    1195         # Do not call functions when jit is used
#    1196         full_backward_hooks, non_full_backward_hooks = [], []
#
# <ipython-input-26-2d8a856501f9> in forward(self, x)
#       4         self.conv1 = nn.Conv2d(channels_in, channels_out, kernel_size=3, stride=1, padding=1)
#       5     def forward(self, x):
# ----> 6         return self.conv1(x)
#
# /usr/local/lib/python3.8/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1192         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194             return forward_call(*input, **kwargs)
#    1195         # Do not call functions when jit is used
#    1196         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.8/dist-packages/torch/nn/modules/conv.py in forward(self, input)
#     461
#     462     def forward(self, input: Tensor) -> Tensor:
# --> 463         return self._conv_forward(input, self.weight, self.bias)
#     464
#     465 class Conv3d(_ConvNd):
#
# /usr/local/lib/python3.8/dist-packages/torch/nn/modules/conv.py in _conv_forward(self, input, weight, bias)
#     457                             weight, bias, self.stride,
#     458                             _pair(0), self.dilation, self.groups)
# --> 459         return F.conv2d(input, weight, bias, self.stride,
#     460                         self.padding, self.dilation, self.groups)
#     461
#
# RuntimeError: Input type (torch.FloatTensor) and weight type (torch.cuda.FloatTensor) should be the same or input should be a MKLDNN tensor and weight is a dense tensor
