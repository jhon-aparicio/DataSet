# %% [markdown]
# <a href="https://colab.research.google.com/github/jhon-aparicio/DataSet/blob/main/PersonaUNetS3.0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import sys
import json
import numpy as np
import time
from PIL import Image, ImageDraw
import skimage.draw
import random

# %%
# !git clone https://github.com/johnpaipa/semanticSegmentation.git
# Out:
# Cloning into 'semanticSegmentation'...
# remote: Enumerating objects: 126, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 126 (delta 0), reused 1 (delta 0), pack-reused 123
# Receiving objects: 100% (126/126), 73.51 MiB | 13.11 MiB/s, done.
# Resolving deltas: 100% (2/2), done.

# %%
cd semanticSegmentation/
# Out:
# /content/semanticSegmentation

# %%
# !python setup.py install
# Out:
# WARNING:root:Fail load requirements file, so using default ones.
# /usr/local/lib/python3.9/dist-packages/setuptools/dist.py:697: UserWarning: Usage of dash-separated 'description-file' will not be supported in future versions. Please use the underscore name 'description_file' instead
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/setuptools/dist.py:697: UserWarning: Usage of dash-separated 'license-file' will not be supported in future versions. Please use the underscore name 'license_file' instead
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/setuptools/dist.py:697: UserWarning: Usage of dash-separated 'requirements-file' will not be supported in future versions. Please use the underscore name 'requirements_file' instead
#   warnings.warn(
# running install
# running bdist_egg
# running egg_info
# creating mask_rcnn.egg-info
# writing mask_rcnn.egg-info/PKG-INFO
# writing dependency_links to mask_rcnn.egg-info/dependency_links.txt
# writing top-level names to mask_rcnn.egg-info/top_level.txt
# writing manifest file 'mask_rcnn.egg-info/SOURCES.txt'
# reading manifest file 'mask_rcnn.egg-info/SOURCES.txt'
# reading manifest template 'MANIFEST.in'
# warning: no files found matching 'requirements.txt'
# adding license file 'LICENSE'
# writing manifest file 'mask_rcnn.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_py
# creating build
# creating build/lib
# creating build/lib/mrcnn
# copying mrcnn/visualize.py -> build/lib/mrcnn
# copying mrcnn/config.py -> build/lib/mrcnn
# copying mrcnn/model.py -> build/lib/mrcnn
# copying mrcnn/__init__.py -> build/lib/mrcnn
# copying mrcnn/parallel_model.py -> build/lib/mrcnn
# copying mrcnn/utils.py -> build/lib/mrcnn
# creating build/bdist.linux-x86_64
# creating build/bdist.linux-x86_64/egg
# creating build/bdist.linux-x86_64/egg/mrcnn
# copying build/lib/mrcnn/visualize.py -> build/bdist.linux-x86_64/egg/mrcnn
# copying build/lib/mrcnn/config.py -> build/bdist.linux-x86_64/egg/mrcnn
# copying build/lib/mrcnn/model.py -> build/bdist.linux-x86_64/egg/mrcnn
# copying build/lib/mrcnn/__init__.py -> build/bdist.linux-x86_64/egg/mrcnn
# copying build/lib/mrcnn/parallel_model.py -> build/bdist.linux-x86_64/egg/mrcnn
# copying build/lib/mrcnn/utils.py -> build/bdist.linux-x86_64/egg/mrcnn
# byte-compiling build/bdist.linux-x86_64/egg/mrcnn/visualize.py to visualize.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mrcnn/config.py to config.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mrcnn/model.py to model.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mrcnn/__init__.py to __init__.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mrcnn/parallel_model.py to parallel_model.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mrcnn/utils.py to utils.cpython-39.pyc
# creating build/bdist.linux-x86_64/egg/EGG-INFO
# copying mask_rcnn.egg-info/PKG-INFO -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying mask_rcnn.egg-info/SOURCES.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying mask_rcnn.egg-info/dependency_links.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying mask_rcnn.egg-info/top_level.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# zip_safe flag not set; analyzing archive contents...
# creating dist
# creating 'dist/mask_rcnn-2.1-py3.9.egg' and adding 'build/bdist.linux-x86_64/egg' to it
# removing 'build/bdist.linux-x86_64/egg' (and everything under it)
# Processing mask_rcnn-2.1-py3.9.egg
# Copying mask_rcnn-2.1-py3.9.egg to /usr/local/lib/python3.9/dist-packages
# Adding mask-rcnn 2.1 to easy-install.pth file
#
# Installed /usr/local/lib/python3.9/dist-packages/mask_rcnn-2.1-py3.9.egg
# Processing dependencies for mask-rcnn==2.1
# Finished processing dependencies for mask-rcnn==2.1

# %%
ROOT_DIR = '/content/semanticSegmentation'
assert os.path.exists(ROOT_DIR), 'ROOT_DIR does not exist'

sys.path.append(ROOT_DIR) 

from mrcnn import visualize
from mrcnn.config import Config
from mrcnn import model as modellib, utils

# %%
# Directory to save logs and trained model
MODEL_DIR = os.path.join(ROOT_DIR, "logs")

# Local path to trained weights file
COCO_MODEL_PATH = os.path.join(ROOT_DIR, "mask_rcnn_coco.h5")

# Download COCO trained weights from Releases if needed
if not os.path.exists(COCO_MODEL_PATH):
    utils.download_trained_weights(COCO_MODEL_PATH)
# Out:
# Downloading pretrained model to /content/semanticSegmentation/mask_rcnn_coco.h5 ...
# ... done downloading pretrained model!

# %%
class CascoConfig(Config):
    """Configuration for training on the helmet  dataset.
    """
    # Give the configuration a recognizable name
    NAME = "persona"

    # Train on 1 GPU and 1 image per GPU. Batch size is 1 (GPUs * images/GPU).
    GPU_COUNT = 1
    IMAGES_PER_GPU = 1

    # Number of classes (including background)
    NUM_CLASSES = 1 + 1  # background + 1 (casco)

    # All of our training images are 512x512
    IMAGE_MIN_DIM = 512
    IMAGE_MAX_DIM = 512

    # You can experiment with this number to see if it improves training
    STEPS_PER_EPOCH = 500

    # This is how often validation is run. If you are using too much hard drive space
    # on saved models (in the MODEL_DIR), try making this value larger.
    VALIDATION_STEPS = 5
    
    # Matterport originally used resnet101, but I downsized to fit it on my graphics card
    BACKBONE = 'resnet50'

    # To be honest, I haven't taken the time to figure out what these do
    RPN_ANCHOR_SCALES = (8, 16, 32, 64, 128)
    TRAIN_ROIS_PER_IMAGE = 32
    MAX_GT_INSTANCES = 50 
    POST_NMS_ROIS_INFERENCE = 500 
    POST_NMS_ROIS_TRAINING = 1000 
    
config = CascoConfig()
config.display()
# Out:
# Configurations:
# BACKBONE                       resnet50
# BACKBONE_STRIDES               [4, 8, 16, 32, 64]
# BATCH_SIZE                     1
# BBOX_STD_DEV                   [0.1 0.1 0.2 0.2]
# COMPUTE_BACKBONE_SHAPE         None
# DETECTION_MAX_INSTANCES        100
# DETECTION_MIN_CONFIDENCE       0.7
# DETECTION_NMS_THRESHOLD        0.3
# FPN_CLASSIF_FC_LAYERS_SIZE     1024
# GPU_COUNT                      1
# GRADIENT_CLIP_NORM             5.0
# IMAGES_PER_GPU                 1
# IMAGE_CHANNEL_COUNT            3
# IMAGE_MAX_DIM                  512
# IMAGE_META_SIZE                14
# IMAGE_MIN_DIM                  512
# IMAGE_MIN_SCALE                0
# IMAGE_RESIZE_MODE              square
# IMAGE_SHAPE                    [512 512   3]
# LEARNING_MOMENTUM              0.9
# LEARNING_RATE                  0.001
# LOSS_WEIGHTS                   {'rpn_class_loss': 1.0, 'rpn_bbox_loss': 1.0, 'mrcnn_class_loss': 1.0, 'mrcnn_bbox_loss': 1.0, 'mrcnn_mask_loss': 1.0}
# MASK_POOL_SIZE                 14
# MASK_SHAPE                     [28, 28]
# MAX_GT_INSTANCES               50
# MEAN_PIXEL                     [123.7 116.8 103.9]
# MINI_MASK_SHAPE                (56, 56)
# NAME                           persona
# NUM_CLASSES                    2
# POOL_SIZE                      7
# POST_NMS_ROIS_INFERENCE        500
# POST_NMS_ROIS_TRAINING         1000
# PRE_NMS_LIMIT                  6000
# ROI_POSITIVE_RATIO             0.33
# RPN_ANCHOR_RATIOS              [0.5, 1, 2]
# RPN_ANCHOR_SCALES              (8, 16, 32, 64, 128)
# RPN_ANCHOR_STRIDE              1
# RPN_BBOX_STD_DEV               [0.1 0.1 0.2 0.2]
# RPN_NMS_THRESHOLD              0.7
# RPN_TRAIN_ANCHORS_PER_IMAGE    256
# STEPS_PER_EPOCH                500
# TOP_DOWN_PYRAMID_SIZE          256
# TRAIN_BN                       False
# TRAIN_ROIS_PER_IMAGE           32
# USE_MINI_MASK                  True
# USE_RPN_ROIS                   True
# VALIDATION_STEPS               5
# WEIGHT_DECAY                   0.0001

# %%
class CascoDataset(utils.Dataset):

    def load_cascos(self, dataset_dir, subset):
        """Load a subset of the Casco dataset.
        dataset_dir: Root directory of the dataset.
        subset: Subset to load: train or val
        """
        # Add classes. We have only one class to add.
        self.add_class("persona", 1, "persona")

        # Train or validation dataset?
        assert subset in ["train", "val"]
        dataset_dir = os.path.join(dataset_dir, subset)

        # Load annotations
        # VGG Image Annotator (up to version 1.6) saves each image in the form:
        # { 'filename': '28503151_5b5b7ec140_b.jpg',
        #   'regions': {
        #       '0': {
        #           'region_attributes': {},
        #           'shape_attributes': {
        #               'all_points_x': [...],
        #               'all_points_y': [...],
        #               'name': 'polygon'}},
        #       ... more regions ...
        #   },
        #   'size': 100202
        # }
        # We mostly care about the x and y coordinates of each region
        # Note: In VIA 2.0, regions was changed from a dict to a list.
        annotations = json.load(open(os.path.join(dataset_dir, "via_region_data.json")))
        annotations = list(annotations.values())  # don't need the dict keys

        # The VIA tool saves images in the JSON even if they don't have any
        # annotations. Skip unannotated images.
        annotations = [a for a in annotations if a['regions']]

        # Add images
        for a in annotations:
            # Get the x, y coordinaets of points of the polygons that make up
            # the outline of each object instance. These are stores in the
            # shape_attributes (see json format above)
            # The if condition is needed to support VIA versions 1.x and 2.x.
            if type(a['regions']) is dict:
                polygons = [r['shape_attributes'] for r in a['regions'].values()]
            else:
                polygons = [r['shape_attributes'] for r in a['regions']] 

            # load_mask() needs the image size to convert polygons to masks.
            # Unfortunately, VIA doesn't include it in JSON, so we must read
            # the image. This is only managable since the dataset is tiny.
            image_path = os.path.join(dataset_dir, a['filename'])
            image = skimage.io.imread(image_path)
            height, width = image.shape[:2]

            self.add_image(
                "persona",
                image_id=a['filename'],  # use file name as a unique image id
                path=image_path,
                width=width, height=height,
                polygons=polygons)

    def load_mask(self, image_id):
        """Generate instance masks for an image.
       Returns:
        masks: A bool array of shape [height, width, instance count] with
            one mask per instance.
        class_ids: a 1D array of class IDs of the instance masks.
        """
        # If not a casco dataset image, delegate to parent class.
        image_info = self.image_info[image_id]
        if image_info["source"] != "persona":
            return super(self.__class__, self).load_mask(image_id)

        # Convert polygons to a bitmap mask of shape
        # [height, width, instance_count]
        info = self.image_info[image_id]
        mask = np.zeros([info["height"], info["width"], len(info["polygons"])],
                        dtype=np.uint8)
        for i, p in enumerate(info["polygons"]):
            # Get indexes of pixels inside the polygon and set them to 1
            rr, cc = skimage.draw.polygon(p['all_points_y'], p['all_points_x'])
            mask[rr, cc, i] = 1

        # Return mask, and array of class IDs of each instance. Since we have
        # one class ID only, we return an array of 1s
        return mask.astype(np.bool), np.ones([mask.shape[-1]], dtype=np.int32)

    def image_reference(self, image_id):
        """Return the path of the image."""
        info = self.image_info[image_id]
        if info["source"] == "persona":
            return info["path"]
        else:
            super(self.__class__, self).image_reference(image_id)

# %%
dataset_train = CascoDataset()
dataset_train.load_cascos("/content/semanticSegmentation/dataset/persona", "train")
dataset_train.prepare()

# Validation dataset
dataset_val = CascoDataset()
dataset_val.load_cascos("/content/semanticSegmentation/dataset/persona", "val")
dataset_val.prepare()

# %%
# Create model in training mode
model = modellib.MaskRCNN(mode="training", config=config,
                          model_dir=MODEL_DIR)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.9/dist-packages/tensorflow/python/autograph/pyct/static_analysis/liveness.py:83: Analyzer.lamba_check (from tensorflow.python.autograph.pyct.static_analysis.liveness) is deprecated and will be removed after 2023-09-23.
# Instructions for updating:
# Lambda fuctions will be no more assumed to be used in the statement where they are used, or at least in the same block. https://github.com/tensorflow/tensorflow/issues/56089

# %%
# Which weights to start with?
init_with = "coco"  # imagenet, coco, or last

if init_with == "imagenet":
    model.load_weights(model.get_imagenet_weights(), by_name=True)
elif init_with == "coco":
    # Load weights trained on MS COCO, but skip layers that
    # are different due to the different number of classes
    # See README for instructions to download the COCO weights
    model.load_weights(COCO_MODEL_PATH, by_name=True,
                       exclude=["mrcnn_class_logits", "mrcnn_bbox_fc", 
                                "mrcnn_bbox", "mrcnn_mask"])
elif init_with == "last":
    # Load the last model you trained and continue training
    model.load_weights(model.find_last(), by_name=True)

# %%
# Load and display random samples
dataset = dataset_train
image_ids = np.random.choice(dataset.image_ids, 4)
for image_id in image_ids:
    image = dataset.load_image(image_id)
    mask, class_ids = dataset.load_mask(image_id)
    visualize.display_top_masks(image, mask, class_ids, dataset.class_names)
# Out:
# <ipython-input-8-4d23ee05384c>:87: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   return mask.astype(np.bool), np.ones([mask.shape[-1]], dtype=np.int32)

# %%
from skimage.filters import gaussian
image_idSeg = dataset.image_ids
for image_id in image_idSeg:
    image = dataset.load_image(image_id)
    mask, class_ids = dataset.load_mask(image_id)
    mask_smooth = gaussian(mask, sigma=1.2)
    visualize.display_top_masks(image, mask_smooth, class_ids, dataset.class_names)
    image_name = dataset.image_info[image_id]['id']
    skimage.io.imsave(f'/content/semanticSegmentation/dataset/persona/segmentadas/{image_name}', mask_smooth[:, :, 0])
# Out:
# <ipython-input-8-4d23ee05384c>:87: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   return mask.astype(np.bool), np.ones([mask.shape[-1]], dtype=np.int32)
# WARNING:imageio:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# <ipython-input-13-4e675a0c8f8c>:9: UserWarning: /content/semanticSegmentation/dataset/persona/segmentadas/Hat_Front90_1.png is a low contrast image
#   skimage.io.imsave(f'/content/semanticSegmentation/dataset/persona/segmentadas/{image_name}', mask_smooth[:, :, 0])
# WARNING:imageio:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.

# %%
from mrcnn.model import log
# Load random image and mask.
image_id = random.choice(dataset.image_ids)
image = dataset.load_image(image_id)
mask, class_ids = dataset.load_mask(image_id)
# Compute Bounding box
bbox = utils.extract_bboxes(mask)

# Display image and additional stats
print("image_id ", image_id, dataset.image_reference(image_id))
log("image", image)
log("mask", mask)
log("class_ids", class_ids)
log("bbox", bbox)
# Display image and instances
visualize.display_instances(image, bbox, mask, class_ids, dataset.class_names)
# Out:
# <ipython-input-8-4d23ee05384c>:87: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   return mask.astype(np.bool), np.ones([mask.shape[-1]], dtype=np.int32)
# image_id  29 /content/semanticSegmentation/dataset/persona/train/Hat_Front_2.png
# image                    shape: (300, 300, 3)         min:    0.00000  max:  255.00000  uint8
# mask                     shape: (300, 300, 1)         min:    0.00000  max:    1.00000  bool
# class_ids                shape: (1,)                  min:    1.00000  max:    1.00000  int32
# bbox                     shape: (1, 4)                min:  127.00000  max:  209.00000  int32

# %%
###PYTORCH CON U-NET 
import numpy as np
import matplotlib.pyplot as plt
import os
import random
import torch
from torch import nn, optim
from torch.nn import functional as F
from torchvision import transforms as T
from torch.utils.data import DataLoader, Dataset, random_split
#
import PIL
from PIL import Image
#
# !pip install jupyterthemes
from jupyterthemes import jtplot
jtplot.style()
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting jupyterthemes
#   Downloading jupyterthemes-0.20.0-py2.py3-none-any.whl (7.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 92.6 MB/s eta 0:00:00
# Requirement already satisfied: notebook>=5.6.0 in /usr/local/lib/python3.9/dist-packages (from jupyterthemes) (6.3.0)
# Collecting lesscpy>=0.11.2
#   Downloading lesscpy-0.15.1-py2.py3-none-any.whl (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.7/46.7 KB 7.0 MB/s eta 0:00:00
# Requirement already satisfied: ipython>=5.4.1 in /usr/local/lib/python3.9/dist-packages (from jupyterthemes) (7.9.0)
# Requirement already satisfied: jupyter-core in /usr/local/lib/python3.9/dist-packages (from jupyterthemes) (5.2.0)
# Requirement already satisfied: matplotlib>=1.4.3 in /usr/local/lib/python3.9/dist-packages (from jupyterthemes) (3.5.3)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.9/dist-packages (from ipython>=5.4.1->jupyterthemes) (4.8.0)
# Requirement already satisfied: prompt-toolkit<2.1.0,>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from ipython>=5.4.1->jupyterthemes) (2.0.10)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.9/dist-packages (from ipython>=5.4.1->jupyterthemes) (57.4.0)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.9/dist-packages (from ipython>=5.4.1->jupyterthemes) (5.7.1)
# Collecting jedi>=0.10
#   Downloading jedi-0.18.2-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 46.8 MB/s eta 0:00:00
# Requirement already satisfied: decorator in /usr/local/lib/python3.9/dist-packages (from ipython>=5.4.1->jupyterthemes) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.9/dist-packages (from ipython>=5.4.1->jupyterthemes) (0.7.5)
# Requirement already satisfied: pygments in /usr/local/lib/python3.9/dist-packages (from ipython>=5.4.1->jupyterthemes) (2.6.1)
# Requirement already satisfied: backcall in /usr/local/lib/python3.9/dist-packages (from ipython>=5.4.1->jupyterthemes) (0.2.0)
# Collecting ply
#   Downloading ply-3.11-py2.py3-none-any.whl (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.6/49.6 KB 7.5 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=1.4.3->jupyterthemes) (23.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=1.4.3->jupyterthemes) (3.0.9)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=1.4.3->jupyterthemes) (1.22.4)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=1.4.3->jupyterthemes) (8.4.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=1.4.3->jupyterthemes) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=1.4.3->jupyterthemes) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=1.4.3->jupyterthemes) (4.39.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=1.4.3->jupyterthemes) (1.4.4)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.9/dist-packages (from notebook>=5.6.0->jupyterthemes) (0.17.1)
# Requirement already satisfied: tornado>=6.1 in /usr/local/lib/python3.9/dist-packages (from notebook>=5.6.0->jupyterthemes) (6.2)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.9/dist-packages (from notebook>=5.6.0->jupyterthemes) (21.3.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.9/dist-packages (from notebook>=5.6.0->jupyterthemes) (3.1.2)
# Requirement already satisfied: jupyter-client>=5.3.4 in /usr/local/lib/python3.9/dist-packages (from notebook>=5.6.0->jupyterthemes) (6.1.12)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.9/dist-packages (from notebook>=5.6.0->jupyterthemes) (0.16.0)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.9/dist-packages (from notebook>=5.6.0->jupyterthemes) (5.7.3)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.9/dist-packages (from notebook>=5.6.0->jupyterthemes) (6.5.4)
# Requirement already satisfied: Send2Trash>=1.5.0 in /usr/local/lib/python3.9/dist-packages (from notebook>=5.6.0->jupyterthemes) (1.8.0)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.9/dist-packages (from notebook>=5.6.0->jupyterthemes) (0.2.0)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.9/dist-packages (from notebook>=5.6.0->jupyterthemes) (23.2.1)
# Requirement already satisfied: ipykernel in /usr/local/lib/python3.9/dist-packages (from notebook>=5.6.0->jupyterthemes) (5.3.4)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.9/dist-packages (from jupyter-core->jupyterthemes) (3.1.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.9/dist-packages (from jedi>=0.10->ipython>=5.4.1->jupyterthemes) (0.8.3)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.9/dist-packages (from prompt-toolkit<2.1.0,>=2.0.0->ipython>=5.4.1->jupyterthemes) (0.2.6)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.9/dist-packages (from prompt-toolkit<2.1.0,>=2.0.0->ipython>=5.4.1->jupyterthemes) (1.15.0)
# Requirement already satisfied: ptyprocess in /usr/local/lib/python3.9/dist-packages (from terminado>=0.8.3->notebook>=5.6.0->jupyterthemes) (0.7.0)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.9/dist-packages (from argon2-cffi->notebook>=5.6.0->jupyterthemes) (21.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.9/dist-packages (from jinja2->notebook>=5.6.0->jupyterthemes) (2.1.2)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook>=5.6.0->jupyterthemes) (0.2.2)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook>=5.6.0->jupyterthemes) (0.7.2)
# Requirement already satisfied: bleach in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook>=5.6.0->jupyterthemes) (6.0.0)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook>=5.6.0->jupyterthemes) (0.4)
# Requirement already satisfied: lxml in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook>=5.6.0->jupyterthemes) (4.9.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook>=5.6.0->jupyterthemes) (1.5.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook>=5.6.0->jupyterthemes) (4.6.3)
# Requirement already satisfied: tinycss2 in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook>=5.6.0->jupyterthemes) (1.2.1)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook>=5.6.0->jupyterthemes) (0.7.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook>=5.6.0->jupyterthemes) (0.8.4)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.9/dist-packages (from nbformat->notebook>=5.6.0->jupyterthemes) (2.16.3)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.9/dist-packages (from nbformat->notebook>=5.6.0->jupyterthemes) (4.3.3)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.9/dist-packages (from jsonschema>=2.6->nbformat->notebook>=5.6.0->jupyterthemes) (0.19.3)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.9/dist-packages (from jsonschema>=2.6->nbformat->notebook>=5.6.0->jupyterthemes) (22.2.0)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=5.6.0->jupyterthemes) (1.15.1)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.9/dist-packages (from bleach->nbconvert->notebook>=5.6.0->jupyterthemes) (0.5.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.9/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=5.6.0->jupyterthemes) (2.21)
# Installing collected packages: ply, lesscpy, jedi, jupyterthemes
# Successfully installed jedi-0.18.2 jupyterthemes-0.20.0 lesscpy-0.15.1 ply-3.11

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
# Out:
# cuda

# %%
PATH = '/content/semanticSegmentation/dataset/persona/'
TRAIN_PATH = '/content/semanticSegmentation/dataset/persona/train2/'
TRAIN_MASKS_PATH = '/content/semanticSegmentation/dataset/persona/segmentadas/'
TEST_PATH = '/content/semanticSegmentation/dataset/persona/val2/'
TEST_MASK_PATH = '/content/semanticSegmentation/dataset/persona/valS/'

# %%
# creating our own Dataset
class Car_Dataset(Dataset):
    def __init__(self, data, masks=None, img_transforms=None, mask_transforms=None):
        '''
        data - train data path
        masks - train masks path
        '''
        self.train_data = data
        self.train_masks = masks
        
        self.img_transforms = img_transforms
        self.mask_transforms = mask_transforms
        
        self.images = sorted(os.listdir(self.train_data))
        self.masks = sorted(os.listdir(self.train_masks))
        
    def __len__(self):
        if self.train_masks is not None:
            assert len(self.images)==len(self.masks), 'not the same number of images and masks'
        return len(self.images)
        
    def __getitem__(self, idx):
        image_name = os.path.join(self.train_data, self.images[idx])
        img = Image.open(image_name)
        trans = T.ToTensor()
        if self.img_transforms is not None:
            img = self.img_transforms(img)
        else:
            img =trans(img)
            img = torch.narrow(img, 1, 0, 3)
        
        if self.train_masks is not None:
            mask_name = os.path.join(self.train_masks, self.masks[idx])
            mask = Image.open(mask_name)
            if self.mask_transforms is not None:
                mask = self.mask_transforms(mask)
            else:
                mask = trans(mask)
            
            mask_max = mask.max().item()
            mask /= mask_max
        else:
            
            return img
        
        return img, mask

# %%
transform_data = T.Compose([
                T.Resize([224, 224]),
                T.ToTensor()] )

# %%
full_dataset = Car_Dataset(TRAIN_PATH,
                           TRAIN_MASKS_PATH,
                           img_transforms=transform_data,
                           mask_transforms=transform_data)

# %%
BATCH_SIZE = 4
TRAIN_SIZE = int(len(full_dataset)*0.8)
VAL_SIZE = len(full_dataset) - TRAIN_SIZE

print(TRAIN_SIZE, VAL_SIZE)
# Out:
# 41 11

# %%
train_dataset, val_dataset = random_split(full_dataset, [TRAIN_SIZE, VAL_SIZE])
print(len(train_dataset), len(val_dataset))

train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
for batch_idx, (inputs, targets) in enumerate(train_loader):
    print(f'Batch {batch_idx}: inputs={inputs.shape}, targets={targets.shape}')
#train_loader[0] = torch.narrow(train_loader[0], 1, 0, 3)
val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=True)
# Out:
# 41 11
# Batch 0: inputs=torch.Size([4, 4, 224, 224]), targets=torch.Size([4, 1, 224, 224])
# Batch 1: inputs=torch.Size([4, 4, 224, 224]), targets=torch.Size([4, 1, 224, 224])
# Batch 2: inputs=torch.Size([4, 4, 224, 224]), targets=torch.Size([4, 1, 224, 224])
# Batch 3: inputs=torch.Size([4, 4, 224, 224]), targets=torch.Size([4, 1, 224, 224])
# Batch 4: inputs=torch.Size([4, 4, 224, 224]), targets=torch.Size([4, 1, 224, 224])
# Batch 5: inputs=torch.Size([4, 4, 224, 224]), targets=torch.Size([4, 1, 224, 224])
# Batch 6: inputs=torch.Size([4, 4, 224, 224]), targets=torch.Size([4, 1, 224, 224])
# Batch 7: inputs=torch.Size([4, 4, 224, 224]), targets=torch.Size([4, 1, 224, 224])
# Batch 8: inputs=torch.Size([4, 4, 224, 224]), targets=torch.Size([4, 1, 224, 224])
# Batch 9: inputs=torch.Size([4, 4, 224, 224]), targets=torch.Size([4, 1, 224, 224])
# Batch 10: inputs=torch.Size([1, 4, 224, 224]), targets=torch.Size([1, 1, 224, 224])

# %%
imgs, masks = next(iter(train_loader))
print(imgs.shape, masks.shape)
#imgs = torch.narrow(imgs, 1, 0, 3)
#print(imgs.shape)
for i, (x, y) in enumerate(train_loader):
    x = torch.narrow(x, 1, 0, 3)
    print(i, x.shape, y.shape)
    if i==9: break
# Out:
# torch.Size([4, 4, 224, 224]) torch.Size([4, 1, 224, 224])
# 0 torch.Size([4, 3, 224, 224]) torch.Size([4, 1, 224, 224])
# 1 torch.Size([4, 3, 224, 224]) torch.Size([4, 1, 224, 224])
# 2 torch.Size([4, 3, 224, 224]) torch.Size([4, 1, 224, 224])
# 3 torch.Size([4, 3, 224, 224]) torch.Size([4, 1, 224, 224])
# 4 torch.Size([4, 3, 224, 224]) torch.Size([4, 1, 224, 224])
# 5 torch.Size([4, 3, 224, 224]) torch.Size([4, 1, 224, 224])
# 6 torch.Size([4, 3, 224, 224]) torch.Size([4, 1, 224, 224])
# 7 torch.Size([4, 3, 224, 224]) torch.Size([4, 1, 224, 224])
# 8 torch.Size([4, 3, 224, 224]) torch.Size([4, 1, 224, 224])
# 9 torch.Size([4, 3, 224, 224]) torch.Size([4, 1, 224, 224])

# %%
imgs, masks = next(iter(train_loader))
def plot_mini_batch(imgs, masks):
    plt.figure(figsize=(20,10))
    for i in range(BATCH_SIZE):
        plt.subplot(4, 8, i+1)
        img=imgs[i,...].permute(1,2,0).numpy()
        mask = masks[i, ...].permute(1,2,0).numpy()
        plt.imshow(img)
        plt.imshow(mask, alpha=0.5)
        
        plt.axis('Off')
    plt.tight_layout()
    plt.show()

plot_mini_batch(imgs, masks)

# %%
def accuracy(model, loader):
    correct = 0
    intersection = 0
    denom = 0
    union = 0
    total = 0
    cost = 0.
    model = model.to(device=device)
    with torch.no_grad():
        for x, y in loader:
            x = x.to(device=device, dtype = torch.float32)
            x = torch.narrow(x, 1, 0, 3)
            y = y.to(device=device, dtype = torch.long).squeeze(1)
            scores = model(x)
            cost += (F.cross_entropy(scores, y)).item()
            # standard accuracy not optimal
            preds = torch.argmax(scores, dim=1)
            correct += (preds == y).sum()
            total += torch.numel(preds)
            #dice coefficient
            intersection += (preds*y).sum()
            denom += (preds + y).sum()
            dice = 2*intersection/(denom + 1e-8)
            #intersection over union
            union += (preds + y - preds*y).sum()
            iou = (intersection)/(union + 1e-8)
            
        return cost/len(loader), float(correct)/total, dice, iou

# %%
len(train_loader)
# Out:
# 11

# %%
def find_lr(model, optimiser, start_val = 1e-6, end_val = 1, beta = 0.99, loader = train_loader):
    n = len(loader) - 1
    factor = (end_val / start_val)**(1/n)
    lr = start_val
    optimiser.param_groups[0]['lr'] = lr #this allows you to update the learning rate
    avg_loss, loss, acc = 0., 0., 0.
    lowest_loss = 0.
    batch_num = 0
    losses = []
    log_lrs = []
    accuracies = []
    model = model.to(device=device)
    for i, (x, y) in enumerate(loader, start=1):
        x = x.to(device = device, dtype = torch.float32)
        x = torch.narrow(x, 1, 0, 3)
        y = y.to(device = device, dtype = torch.long).squeeze(1)
        optimiser.zero_grad()
        scores = model(x)
        cost = F.cross_entropy(input=scores, target=y)
        loss = beta*loss + (1-beta)*cost.item()
        #bias correction
        avg_loss = loss/(1 - beta**i)
        
        preds = torch.argmax(scores, dim=1)
        acc_ = (preds == y).sum()/torch.numel(scores)
#         acc = beta*acc + (1-beta)*acc_.item()
#         avg_acc = acc/(1 - beta**i)
        #if loss is massive stop
        if i > 1 and avg_loss > 4 * lowest_loss:
            print(f'from here{i, cost.item()}')
            return log_lrs, losses, accuracies
        if avg_loss < lowest_loss or i == 1:
            lowest_loss = avg_loss

        accuracies.append(acc_.item())
#         accuracies.append(avg_acc)
        losses.append(avg_loss)
        log_lrs.append(lr)
        #step
        cost.backward()
        optimiser.step()
        #update lr
        print(f'cost:{cost.item():.4f}, lr: {lr:.4f}, acc: {acc_.item():.4f}')
        lr *= factor
        optimiser.param_groups[0]['lr'] = lr
        
    return log_lrs, losses, accuracies

# %%
def evaluate(model, loader):
    model.eval()
    model.to(device=device)
    with torch.no_grad():
        true_positives = 0
        false_positives = 0
        false_negatives = 0
        total = 0
        cost = 0
        for x, y in loader:
            x = x.to(device=device, dtype=torch.float32)
            x = torch.narrow(x, 1, 0, 3)
            y = y.to(device=device, dtype=torch.long).squeeze(1)
            scores = model(x)
            cost += (F.cross_entropy(scores, y)).item()
            preds = torch.argmax(scores, dim=1)
            true_positives += ((preds == 1) & (y == 1)).sum().item()
            false_positives += ((preds == 1) & (y == 0)).sum().item()
            false_negatives += ((preds == 0) & (y == 1)).sum().item()
            total += torch.numel(preds)
        accuracy = true_positives / total
        recall = true_positives / (true_positives + false_negatives)
        precision = true_positives / (true_positives + false_positives)
        if (precision + recall) ==0:
            f1_score = 0
        else:
            f1_score = 2 * (precision * recall) / (precision + recall)
        true_negatives = total - true_positives - false_positives - false_negatives
        confusion_matrix = [[true_positives, false_positives], [false_negatives, true_negatives]]
        print("Confusion Matrix:")
        print(confusion_matrix)
        return cost / len(loader), accuracy, recall, precision, f1_score, confusion_matrix

# %%
import torch
from sklearn.metrics import confusion_matrix
def lift(model, loader):
    thresholds = torch.arange(0, 1.01, 0.01)
    # Paso 2-5: Calcular TPR y FPR para cada umbral de predicción
    tprs = []
    fprs = []
    for threshold in thresholds:
        true_positives = 0
        false_positives = 0
        false_negatives = 0
        true_negatives = 0
        total = 0
        for x, y in loader:
            x = x.to(device=device, dtype=torch.float32)
            x = torch.narrow(x, 1, 0, 3)
            y = y.to(device=device, dtype=torch.long).squeeze(1)
            scores = model(x)
            preds = torch.where(scores[:, 1] > threshold, torch.tensor(1).to(device=device), torch.tensor(0).to(device=device))
            true_positives += ((preds == 1) & (y == 1)).sum().item()
            false_positives += ((preds == 1) & (y == 0)).sum().item()
            false_negatives += ((preds == 0) & (y == 1)).sum().item()
            true_negatives += ((preds == 0) & (y == 0)).sum().item()
            total += torch.numel(preds)
        tpr = true_positives / (true_positives + false_negatives)
        fpr = false_positives / (false_positives + true_negatives)
        tprs.append(tpr)
        fprs.append(fpr)
    return fprs, tprs

# %%
def train(model, optimiser, scheduler = None, epochs = 5000, store_every = 25):
    model = model.to(device=device)
    for epoch in range(epochs):
        train_correct_num = 0
        train_total = 0
        train_cost_acum = 0.
        for mb, (x, y) in enumerate(train_loader, start=1):
            model.train()
            x = x.to(device=device, dtype=torch.float32)
            x = torch.narrow(x, 1, 0, 3)
            y = y.to(device=device, dtype=torch.long).squeeze(1)
            scores = model(x)
            cost = F.cross_entropy(input=scores, target=y)
            optimiser.zero_grad()
            cost.backward()
            optimiser.step()
            
            if scheduler: 
                scheduler.step()
                
            train_predictions = torch.argmax(scores, dim=1)
            train_correct_num += (train_predictions == y).sum()
            train_total += torch.numel(train_predictions)
            train_cost_acum += cost.item()
            if mb%store_every == 0:
                val_cost, val_acc, dice, iou = accuracy(model, val_loader)
                train_acc = float(train_correct_num)/train_total
                train_cost_every = float(train_cost_acum)/mb
                loss, accuracy2, recall, precision, f1_score, confusion_matrix = evaluate(model, val_loader)
                print(f'epoch: {epoch}, mb: {mb}, train cost: {train_cost_every:.4f}, val cost: {val_cost:.4f},'
                      f'train acc: {train_acc:.4f}, val acc: {val_acc:.4f},'
                      f'dice: {dice}, iou: {iou}')
            else:
                val_cost, val_acc, dice, iou = accuracy(model, val_loader)
                train_acc = float(train_correct_num)/train_total
                train_cost_every = float(train_cost_acum)/mb
                print(f'epoch: {epoch}, mb: {mb}, train cost: {train_cost_every:.4f}, val cost: {val_cost:.4f},'
                      f'train acc: {train_acc:.4f}, val acc: {val_acc:.4f},'
                      f'dice: {dice}, iou: {iou}')              

            
                    # Save data
                    #train_acc_history.append(train_acc)
                    #train_cost_history.append(train_cost_every)
        #train_acc = float(train_correct_num)/train_total
        #train_cost_every = float(train_cost_acum)/len(train_loader)
        # return train_acc_history ... etc

# %%
class Conv_3_k(nn.Module):
    def __init__(self, channels_in, channels_out):
        super().__init__()
        self.conv1 = nn.Conv2d(channels_in, channels_out, kernel_size=3, stride=1, padding=1)
    def forward(self, x):
        return self.conv1(x)

# %%
class Double_Conv(nn.Module):
    '''
    Double convolution block for U-Net
    '''
    def __init__(self, channels_in, channels_out):
        super().__init__()
        self.double_conv = nn.Sequential(
                           Conv_3_k(channels_in, channels_out),
                           nn.BatchNorm2d(channels_out),
                           nn.ReLU(),
            
                           Conv_3_k(channels_out, channels_out),
                           nn.BatchNorm2d(channels_out),
                           nn.ReLU(),
                            )
    def forward(self, x):
        return self.double_conv(x)
    
class Down_Conv(nn.Module):
    '''
    Down convolution part
    '''
    def __init__(self, channels_in, channels_out):
        super().__init__()
        self.encoder = nn.Sequential(
                        nn.MaxPool2d(2,2),
                        Double_Conv(channels_in, channels_out)
                        )
    def forward(self, x):
        return self.encoder(x)
    
class Up_Conv(nn.Module):
    '''
    Up convolution part
    '''
    def __init__(self,channels_in, channels_out):
        super().__init__()
        self.upsample_layer = nn.Sequential(
                        nn.Upsample(scale_factor=2, mode='bicubic'),
                        nn.Conv2d(channels_in, channels_in//2, kernel_size=1, stride=1)
                        )
        self.decoder = Double_Conv(channels_in, channels_out)
    
    def forward(self, x1, x2):
        '''
        x1 - upsampled volume
        x2 - volume from down sample to concatenate
        '''
        x1 = self.upsample_layer(x1)
        x = torch.cat([x2, x1],dim=1)
        return self.decoder(x)
    
class UNET(nn.Module):
    '''
    UNET model
    '''
    def __init__(self, channels_in, channels, num_classes):
        super().__init__()
        self.first_conv = Double_Conv(channels_in, channels) #64, 224, 224
        self.down_conv1 = Down_Conv(channels, 2*channels) # 128, 112, 112
        self.down_conv2 = Down_Conv(2*channels, 4*channels) # 256, 56, 56
        self.down_conv3 = Down_Conv(4*channels, 8*channels) # 512, 28, 28
        
        self.middle_conv = Down_Conv(8*channels, 16*channels) # 1024, 14, 14 
        
        self.up_conv1 = Up_Conv(16*channels, 8*channels)
        self.up_conv2 = Up_Conv(8*channels, 4*channels)
        self.up_conv3 = Up_Conv(4*channels, 2*channels)
        self.up_conv4 = Up_Conv(2*channels, channels)
        
        self.last_conv = nn.Conv2d(channels, num_classes, kernel_size=1, stride=1)
        
    def forward(self, x):
        x1 = self.first_conv(x)
        x2 = self.down_conv1(x1)
        x3 = self.down_conv2(x2)
        x4 = self.down_conv3(x3)
        
        x5 = self.middle_conv(x4)
        
        u1 = self.up_conv1(x5, x4)
        u2 = self.up_conv2(u1, x3)
        u3 = self.up_conv3(u2, x2)
        u4 = self.up_conv4(u3, x1)
        
        return self.last_conv(u4)

# %%
def test():
    x = torch.randn((32, 3, 224, 224))
    model = UNET(3, 64, 2)
    return model(x)

preds = test()

print(preds.shape)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-66-0a456c2b5499> in <module>
#       4     return model(x)
#       5
# ----> 6 preds = test()
#       7
#       8 print(preds.shape)
#
# <ipython-input-66-0a456c2b5499> in test()
#       2     x = torch.randn((32, 3, 224, 224))
#       3     model = UNET(3, 64, 2)
# ----> 4     return model(x)
#       5
#       6 preds = test()
#
# /usr/local/lib/python3.8/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1192         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194             return forward_call(*input, **kwargs)
#    1195         # Do not call functions when jit is used
#    1196         full_backward_hooks, non_full_backward_hooks = [], []
#
# <ipython-input-65-9ad808c6bbad> in forward(self, x)
#      74         x1 = self.first_conv(x)
#      75         x2 = self.down_conv1(x1)
# ---> 76         x3 = self.down_conv2(x2)
#      77         x4 = self.down_conv3(x3)
#      78
#
# /usr/local/lib/python3.8/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1192         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194             return forward_call(*input, **kwargs)
#    1195         # Do not call functions when jit is used
#    1196         full_backward_hooks, non_full_backward_hooks = [], []
#
# <ipython-input-65-9ad808c6bbad> in forward(self, x)
#      28                         )
#      29     def forward(self, x):
# ---> 30         return self.encoder(x)
#      31
#      32 class Up_Conv(nn.Module):
#
# /usr/local/lib/python3.8/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1192         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194             return forward_call(*input, **kwargs)
#    1195         # Do not call functions when jit is used
#    1196         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.8/dist-packages/torch/nn/modules/container.py in forward(self, input)
#     202     def forward(self, input):
#     203         for module in self:
# --> 204             input = module(input)
#     205         return input
#     206
#
# /usr/local/lib/python3.8/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1192         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194             return forward_call(*input, **kwargs)
#    1195         # Do not call functions when jit is used
#    1196         full_backward_hooks, non_full_backward_hooks = [], []
#
# <ipython-input-65-9ad808c6bbad> in forward(self, x)
#      15                             )
#      16     def forward(self, x):
# ---> 17         return self.double_conv(x)
#      18
#      19 class Down_Conv(nn.Module):
#
# /usr/local/lib/python3.8/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1192         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194             return forward_call(*input, **kwargs)
#    1195         # Do not call functions when jit is used
#    1196         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.8/dist-packages/torch/nn/modules/container.py in forward(self, input)
#     202     def forward(self, input):
#     203         for module in self:
# --> 204             input = module(input)
#     205         return input
#     206
#
# /usr/local/lib/python3.8/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1192         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194             return forward_call(*input, **kwargs)
#    1195         # Do not call functions when jit is used
#    1196         full_backward_hooks, non_full_backward_hooks = [], []
#
# <ipython-input-64-2d8a856501f9> in forward(self, x)
#       4         self.conv1 = nn.Conv2d(channels_in, channels_out, kernel_size=3, stride=1, padding=1)
#       5     def forward(self, x):
# ----> 6         return self.conv1(x)
#
# /usr/local/lib/python3.8/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1192         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194             return forward_call(*input, **kwargs)
#    1195         # Do not call functions when jit is used
#    1196         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.8/dist-packages/torch/nn/modules/conv.py in forward(self, input)
#     461
#     462     def forward(self, input: Tensor) -> Tensor:
# --> 463         return self._conv_forward(input, self.weight, self.bias)
#     464
#     465 class Conv3d(_ConvNd):
#
# /usr/local/lib/python3.8/dist-packages/torch/nn/modules/conv.py in _conv_forward(self, input, weight, bias)
#     457                             weight, bias, self.stride,
#     458                             _pair(0), self.dilation, self.groups)
# --> 459         return F.conv2d(input, weight, bias, self.stride,
#     460                         self.padding, self.dilation, self.groups)
#     461
#
# KeyboardInterrupt:

# %%
# define the model and look for learning rate
torch.manual_seed(42)
model = UNET(3, 4, 2)
optimiser_unet = torch.optim.SGD(model.parameters(),
                                 lr=0.01, momentum=0.95,
                                 weight_decay=1e-4)

lg_lr, losses, accuracies = find_lr(model, optimiser_unet, start_val=1e-6, end_val=10)
# Out:
# cost:0.9002, lr: 0.0000, acc: 0.0593
# cost:0.8920, lr: 0.0000, acc: 0.0729
# cost:0.9002, lr: 0.0000, acc: 0.0629
# cost:0.8960, lr: 0.0001, acc: 0.0683
# cost:0.8929, lr: 0.0006, acc: 0.0727
# cost:0.8830, lr: 0.0032, acc: 0.0820
# cost:0.8516, lr: 0.0158, acc: 0.1015
# cost:0.7246, lr: 0.0794, acc: 0.1898
# cost:0.3097, lr: 0.3981, acc: 0.4975
# cost:0.0252, lr: 1.9953, acc: 0.4983
# cost:0.3340, lr: 10.0000, acc: 0.4974

# %%
# plot loss vs learning rate
f1, ax1 = plt.subplots(figsize=(20,10))
ax1.plot(lg_lr, losses)
ax1.set_xscale('log')
plt.show()

# %%
# define the model and train with scheduler
torch.manual_seed(42)
model = UNET(3, 4, 2)
epochs = 750
optimiser_unet = torch.optim.SGD(model.parameters(),
                                 lr=0.01, momentum=0.95,
                                 weight_decay=1e-4)
scheduler = torch.optim.lr_scheduler.OneCycleLR(optimiser_unet, 
                                                max_lr = 1e-1,
                                                steps_per_epoch=len(train_loader),
                                                epochs=epochs, pct_start=0.43, div_factor=10, final_div_factor=1000,
                                                three_phase=True)

# %%
train(model, optimiser_unet, scheduler, epochs)
loss, accuracy2, recall, precision, f1_score, confusion_matrix = evaluate(model, val_loader)
print("Loss: {:.4f}".format(loss))
print("Accuracy: {:.4f}".format(accuracy2))
print("Recall: {:.4f}".format(recall))
print("Precision: {:.4f}".format(precision))
print("F1 Score: {:.4f}".format(f1_score))
#print("Confusion Matrix: {:.4f}".format(confusion_matrix))
# Out:
# Se han truncado las últimas 5000 líneas del flujo de salida.
# epoch: 295, mb: 3, train cost: 0.0007, val cost: 0.0062,train acc: 0.9998, val acc: 0.9985,dice: 0.8145036697387695, iou: 0.6870570778846741
# epoch: 295, mb: 4, train cost: 0.0008, val cost: 0.0064,train acc: 0.9998, val acc: 0.9984,dice: 0.8147509098052979, iou: 0.6874090433120728
# epoch: 295, mb: 5, train cost: 0.0008, val cost: 0.0063,train acc: 0.9997, val acc: 0.9984,dice: 0.811416506767273, iou: 0.6826751828193665
# epoch: 295, mb: 6, train cost: 0.0009, val cost: 0.0060,train acc: 0.9997, val acc: 0.9984,dice: 0.8110678791999817, iou: 0.6821818351745605
# epoch: 295, mb: 7, train cost: 0.0009, val cost: 0.0060,train acc: 0.9997, val acc: 0.9985,dice: 0.8090555667877197, iou: 0.6793394684791565
# epoch: 295, mb: 8, train cost: 0.0009, val cost: 0.0060,train acc: 0.9997, val acc: 0.9985,dice: 0.8128735423088074, iou: 0.6847404837608337
# epoch: 295, mb: 9, train cost: 0.0009, val cost: 0.0063,train acc: 0.9997, val acc: 0.9984,dice: 0.811037540435791, iou: 0.6821388602256775
# epoch: 295, mb: 10, train cost: 0.0009, val cost: 0.0060,train acc: 0.9997, val acc: 0.9984,dice: 0.811699390411377, iou: 0.6830758452415466
# epoch: 295, mb: 11, train cost: 0.0009, val cost: 0.0059,train acc: 0.9997, val acc: 0.9985,dice: 0.8173575401306152, iou: 0.691128134727478
# epoch: 296, mb: 1, train cost: 0.0008, val cost: 0.0058,train acc: 0.9997, val acc: 0.9985,dice: 0.8177187442779541, iou: 0.6916447877883911
# epoch: 296, mb: 2, train cost: 0.0007, val cost: 0.0058,train acc: 0.9997, val acc: 0.9985,dice: 0.8106862902641296, iou: 0.6816421151161194
# epoch: 296, mb: 3, train cost: 0.0009, val cost: 0.0059,train acc: 0.9997, val acc: 0.9985,dice: 0.8148312568664551, iou: 0.6875234246253967
# epoch: 296, mb: 4, train cost: 0.0009, val cost: 0.0062,train acc: 0.9997, val acc: 0.9984,dice: 0.8121893405914307, iou: 0.6837700009346008
# epoch: 296, mb: 5, train cost: 0.0009, val cost: 0.0062,train acc: 0.9997, val acc: 0.9984,dice: 0.8079071640968323, iou: 0.6777216792106628
# epoch: 296, mb: 6, train cost: 0.0009, val cost: 0.0063,train acc: 0.9997, val acc: 0.9984,dice: 0.8123494386672974, iou: 0.6839970350265503
# epoch: 296, mb: 7, train cost: 0.0009, val cost: 0.0063,train acc: 0.9997, val acc: 0.9985,dice: 0.8090542554855347, iou: 0.6793376207351685
# epoch: 296, mb: 8, train cost: 0.0009, val cost: 0.0060,train acc: 0.9997, val acc: 0.9984,dice: 0.8102270364761353, iou: 0.6809929609298706
# epoch: 296, mb: 9, train cost: 0.0009, val cost: 0.0060,train acc: 0.9997, val acc: 0.9984,dice: 0.8111522793769836, iou: 0.6823012232780457
# epoch: 296, mb: 10, train cost: 0.0009, val cost: 0.0064,train acc: 0.9997, val acc: 0.9985,dice: 0.8103370666503906, iou: 0.6811484694480896
# epoch: 296, mb: 11, train cost: 0.0009, val cost: 0.0060,train acc: 0.9997, val acc: 0.9985,dice: 0.8126286864280701, iou: 0.684393048286438
# epoch: 297, mb: 1, train cost: 0.0011, val cost: 0.0058,train acc: 0.9996, val acc: 0.9985,dice: 0.8157604932785034, iou: 0.6888476014137268
# epoch: 297, mb: 2, train cost: 0.0010, val cost: 0.0062,train acc: 0.9997, val acc: 0.9984,dice: 0.8140531182289124, iou: 0.6864162087440491
# epoch: 297, mb: 3, train cost: 0.0009, val cost: 0.0057,train acc: 0.9997, val acc: 0.9985,dice: 0.8171854615211487, iou: 0.69088214635849
# epoch: 297, mb: 4, train cost: 0.0009, val cost: 0.0058,train acc: 0.9997, val acc: 0.9985,dice: 0.8172140717506409, iou: 0.6909230351448059
# epoch: 297, mb: 5, train cost: 0.0009, val cost: 0.0058,train acc: 0.9997, val acc: 0.9985,dice: 0.8159272074699402, iou: 0.6890853047370911
# epoch: 297, mb: 6, train cost: 0.0009, val cost: 0.0058,train acc: 0.9997, val acc: 0.9985,dice: 0.8166334629058838, iou: 0.690093457698822
# epoch: 297, mb: 7, train cost: 0.0009, val cost: 0.0059,train acc: 0.9997, val acc: 0.9984,dice: 0.8171355724334717, iou: 0.6908107995986938
# epoch: 297, mb: 8, train cost: 0.0009, val cost: 0.0061,train acc: 0.9997, val acc: 0.9984,dice: 0.8113863468170166, iou: 0.682632565498352
# epoch: 297, mb: 9, train cost: 0.0009, val cost: 0.0060,train acc: 0.9997, val acc: 0.9985,dice: 0.8118767738342285, iou: 0.6833271384239197
# epoch: 297, mb: 10, train cost: 0.0009, val cost: 0.0065,train acc: 0.9997, val acc: 0.9985,dice: 0.8049062490463257, iou: 0.673508882522583
# epoch: 297, mb: 11, train cost: 0.0008, val cost: 0.0066,train acc: 0.9997, val acc: 0.9985,dice: 0.8000936508178711, iou: 0.6667967438697815
# epoch: 298, mb: 1, train cost: 0.0013, val cost: 0.0061,train acc: 0.9996, val acc: 0.9984,dice: 0.8088074922561646, iou: 0.6789897680282593
# epoch: 298, mb: 2, train cost: 0.0010, val cost: 0.0067,train acc: 0.9996, val acc: 0.9982,dice: 0.7994198203086853, iou: 0.6658612489700317
# epoch: 298, mb: 3, train cost: 0.0011, val cost: 0.0063,train acc: 0.9996, val acc: 0.9983,dice: 0.8050955533981323, iou: 0.673774003982544
# epoch: 298, mb: 4, train cost: 0.0011, val cost: 0.0065,train acc: 0.9996, val acc: 0.9984,dice: 0.8044363856315613, iou: 0.6728512048721313
# epoch: 298, mb: 5, train cost: 0.0010, val cost: 0.0062,train acc: 0.9996, val acc: 0.9984,dice: 0.7981630563735962, iou: 0.6641192436218262
# epoch: 298, mb: 6, train cost: 0.0010, val cost: 0.0061,train acc: 0.9997, val acc: 0.9984,dice: 0.7996361255645752, iou: 0.6661614179611206
# epoch: 298, mb: 7, train cost: 0.0011, val cost: 0.0061,train acc: 0.9996, val acc: 0.9984,dice: 0.8115880489349365, iou: 0.682918131351471
# epoch: 298, mb: 8, train cost: 0.0011, val cost: 0.0066,train acc: 0.9996, val acc: 0.9983,dice: 0.8052213191986084, iou: 0.6739501357078552
# epoch: 298, mb: 9, train cost: 0.0011, val cost: 0.0062,train acc: 0.9996, val acc: 0.9983,dice: 0.8058592677116394, iou: 0.67484450340271
# epoch: 298, mb: 10, train cost: 0.0011, val cost: 0.0057,train acc: 0.9996, val acc: 0.9985,dice: 0.816117525100708, iou: 0.6893569231033325
# epoch: 298, mb: 11, train cost: 0.0011, val cost: 0.0066,train acc: 0.9996, val acc: 0.9986,dice: 0.8029739856719971, iou: 0.6708074808120728
# epoch: 299, mb: 1, train cost: 0.0024, val cost: 0.0056,train acc: 0.9991, val acc: 0.9985,dice: 0.8180038928985596, iou: 0.692052960395813
# epoch: 299, mb: 2, train cost: 0.0017, val cost: 0.0062,train acc: 0.9994, val acc: 0.9983,dice: 0.8108327984809875, iou: 0.6818493008613586
# epoch: 299, mb: 3, train cost: 0.0017, val cost: 0.0060,train acc: 0.9994, val acc: 0.9983,dice: 0.8053800463676453, iou: 0.6741726398468018
# epoch: 299, mb: 4, train cost: 0.0016, val cost: 0.0057,train acc: 0.9995, val acc: 0.9984,dice: 0.8134726285934448, iou: 0.6855911016464233
# epoch: 299, mb: 5, train cost: 0.0015, val cost: 0.0054,train acc: 0.9995, val acc: 0.9985,dice: 0.8131917715072632, iou: 0.6851922273635864
# epoch: 299, mb: 6, train cost: 0.0014, val cost: 0.0056,train acc: 0.9995, val acc: 0.9985,dice: 0.8113683462142944, iou: 0.6826069951057434
# epoch: 299, mb: 7, train cost: 0.0013, val cost: 0.0056,train acc: 0.9995, val acc: 0.9985,dice: 0.8136968016624451, iou: 0.685909628868103
# epoch: 299, mb: 8, train cost: 0.0013, val cost: 0.0058,train acc: 0.9995, val acc: 0.9985,dice: 0.8164695501327515, iou: 0.6898593902587891
# epoch: 299, mb: 9, train cost: 0.0012, val cost: 0.0058,train acc: 0.9996, val acc: 0.9984,dice: 0.8103929758071899, iou: 0.681227445602417
# epoch: 299, mb: 10, train cost: 0.0012, val cost: 0.0060,train acc: 0.9996, val acc: 0.9985,dice: 0.8135519027709961, iou: 0.6857037544250488
# epoch: 299, mb: 11, train cost: 0.0011, val cost: 0.0061,train acc: 0.9996, val acc: 0.9984,dice: 0.8068360686302185, iou: 0.6762155890464783
# epoch: 300, mb: 1, train cost: 0.0009, val cost: 0.0059,train acc: 0.9997, val acc: 0.9985,dice: 0.8089836835861206, iou: 0.6792380809783936
# epoch: 300, mb: 2, train cost: 0.0009, val cost: 0.0059,train acc: 0.9997, val acc: 0.9985,dice: 0.8085585832595825, iou: 0.6786389350891113
# epoch: 300, mb: 3, train cost: 0.0010, val cost: 0.0060,train acc: 0.9996, val acc: 0.9984,dice: 0.8063889741897583, iou: 0.6755877137184143
# epoch: 300, mb: 4, train cost: 0.0010, val cost: 0.0061,train acc: 0.9996, val acc: 0.9983,dice: 0.8022379875183105, iou: 0.6697807908058167
# epoch: 300, mb: 5, train cost: 0.0010, val cost: 0.0059,train acc: 0.9996, val acc: 0.9984,dice: 0.8051326870918274, iou: 0.6738259792327881
# epoch: 300, mb: 6, train cost: 0.0010, val cost: 0.0061,train acc: 0.9996, val acc: 0.9984,dice: 0.8068481087684631, iou: 0.6762325167655945
# epoch: 300, mb: 7, train cost: 0.0010, val cost: 0.0058,train acc: 0.9996, val acc: 0.9985,dice: 0.81569504737854, iou: 0.6887542605400085
# epoch: 300, mb: 8, train cost: 0.0010, val cost: 0.0058,train acc: 0.9996, val acc: 0.9985,dice: 0.8148648738861084, iou: 0.6875712871551514
# epoch: 300, mb: 9, train cost: 0.0009, val cost: 0.0057,train acc: 0.9997, val acc: 0.9985,dice: 0.81146639585495, iou: 0.6827458143234253
# epoch: 300, mb: 10, train cost: 0.0009, val cost: 0.0058,train acc: 0.9997, val acc: 0.9984,dice: 0.8105556964874268, iou: 0.6814574599266052
# epoch: 300, mb: 11, train cost: 0.0009, val cost: 0.0061,train acc: 0.9997, val acc: 0.9984,dice: 0.81210857629776, iou: 0.6836555600166321
# epoch: 301, mb: 1, train cost: 0.0011, val cost: 0.0060,train acc: 0.9996, val acc: 0.9984,dice: 0.8096261024475098, iou: 0.6801444292068481
# epoch: 301, mb: 2, train cost: 0.0009, val cost: 0.0058,train acc: 0.9997, val acc: 0.9985,dice: 0.8123748302459717, iou: 0.6840329766273499
# epoch: 301, mb: 3, train cost: 0.0009, val cost: 0.0060,train acc: 0.9997, val acc: 0.9985,dice: 0.803708016872406, iou: 0.6718326210975647
# epoch: 301, mb: 4, train cost: 0.0010, val cost: 0.0059,train acc: 0.9996, val acc: 0.9984,dice: 0.8116258978843689, iou: 0.6829716563224792
# epoch: 301, mb: 5, train cost: 0.0010, val cost: 0.0062,train acc: 0.9996, val acc: 0.9984,dice: 0.8102692365646362, iou: 0.6810526251792908
# epoch: 301, mb: 6, train cost: 0.0010, val cost: 0.0064,train acc: 0.9996, val acc: 0.9983,dice: 0.8065190315246582, iou: 0.6757702827453613
# epoch: 301, mb: 7, train cost: 0.0010, val cost: 0.0062,train acc: 0.9996, val acc: 0.9984,dice: 0.8059765100479126, iou: 0.6750089526176453
# epoch: 301, mb: 8, train cost: 0.0010, val cost: 0.0063,train acc: 0.9996, val acc: 0.9985,dice: 0.8132798671722412, iou: 0.68531733751297
# epoch: 301, mb: 9, train cost: 0.0010, val cost: 0.0062,train acc: 0.9997, val acc: 0.9985,dice: 0.8027777671813965, iou: 0.6705336570739746
# epoch: 301, mb: 10, train cost: 0.0010, val cost: 0.0063,train acc: 0.9997, val acc: 0.9985,dice: 0.8036085963249207, iou: 0.671693742275238
# epoch: 301, mb: 11, train cost: 0.0009, val cost: 0.0065,train acc: 0.9997, val acc: 0.9985,dice: 0.8139176368713379, iou: 0.686223566532135
# epoch: 302, mb: 1, train cost: 0.0007, val cost: 0.0062,train acc: 0.9998, val acc: 0.9984,dice: 0.8076019883155823, iou: 0.6772922873497009
# epoch: 302, mb: 2, train cost: 0.0008, val cost: 0.0063,train acc: 0.9997, val acc: 0.9984,dice: 0.8084000945091248, iou: 0.6784157156944275
# epoch: 302, mb: 3, train cost: 0.0008, val cost: 0.0062,train acc: 0.9997, val acc: 0.9985,dice: 0.8098214268684387, iou: 0.6804201006889343
# epoch: 302, mb: 4, train cost: 0.0009, val cost: 0.0061,train acc: 0.9997, val acc: 0.9985,dice: 0.8105924725532532, iou: 0.6815094351768494
# epoch: 302, mb: 5, train cost: 0.0009, val cost: 0.0066,train acc: 0.9997, val acc: 0.9984,dice: 0.8036672472953796, iou: 0.6717756986618042
# epoch: 302, mb: 6, train cost: 0.0009, val cost: 0.0061,train acc: 0.9997, val acc: 0.9984,dice: 0.8045162558555603, iou: 0.6729629635810852
# epoch: 302, mb: 7, train cost: 0.0009, val cost: 0.0059,train acc: 0.9997, val acc: 0.9984,dice: 0.8064798712730408, iou: 0.6757153272628784
# epoch: 302, mb: 8, train cost: 0.0009, val cost: 0.0060,train acc: 0.9997, val acc: 0.9985,dice: 0.8143765330314636, iou: 0.6868761777877808
# epoch: 302, mb: 9, train cost: 0.0009, val cost: 0.0059,train acc: 0.9997, val acc: 0.9985,dice: 0.816069483757019, iou: 0.689288318157196
# epoch: 302, mb: 10, train cost: 0.0009, val cost: 0.0057,train acc: 0.9997, val acc: 0.9985,dice: 0.8165602087974548, iou: 0.6899888515472412
# epoch: 302, mb: 11, train cost: 0.0009, val cost: 0.0058,train acc: 0.9997, val acc: 0.9985,dice: 0.8119903206825256, iou: 0.6834879517555237
# epoch: 303, mb: 1, train cost: 0.0007, val cost: 0.0060,train acc: 0.9998, val acc: 0.9985,dice: 0.8086060285568237, iou: 0.6787058115005493
# epoch: 303, mb: 2, train cost: 0.0008, val cost: 0.0061,train acc: 0.9997, val acc: 0.9985,dice: 0.8076398372650146, iou: 0.6773455142974854
# epoch: 303, mb: 3, train cost: 0.0008, val cost: 0.0058,train acc: 0.9997, val acc: 0.9985,dice: 0.8143872022628784, iou: 0.6868913769721985
# epoch: 303, mb: 4, train cost: 0.0009, val cost: 0.0057,train acc: 0.9997, val acc: 0.9985,dice: 0.8161634206771851, iou: 0.6894223690032959
# epoch: 303, mb: 5, train cost: 0.0008, val cost: 0.0056,train acc: 0.9997, val acc: 0.9985,dice: 0.8214829564094543, iou: 0.6970479488372803
# epoch: 303, mb: 6, train cost: 0.0008, val cost: 0.0058,train acc: 0.9997, val acc: 0.9985,dice: 0.815398097038269, iou: 0.688330888748169
# epoch: 303, mb: 7, train cost: 0.0008, val cost: 0.0057,train acc: 0.9997, val acc: 0.9984,dice: 0.8125408291816711, iou: 0.6842684149742126
# epoch: 303, mb: 8, train cost: 0.0008, val cost: 0.0058,train acc: 0.9997, val acc: 0.9985,dice: 0.816308856010437, iou: 0.6896299123764038
# epoch: 303, mb: 9, train cost: 0.0008, val cost: 0.0060,train acc: 0.9997, val acc: 0.9984,dice: 0.8131584525108337, iou: 0.6851449012756348
# epoch: 303, mb: 10, train cost: 0.0008, val cost: 0.0063,train acc: 0.9997, val acc: 0.9985,dice: 0.8123077154159546, iou: 0.6839378476142883
# epoch: 303, mb: 11, train cost: 0.0008, val cost: 0.0063,train acc: 0.9997, val acc: 0.9985,dice: 0.8138901591300964, iou: 0.6861844658851624
# epoch: 304, mb: 1, train cost: 0.0007, val cost: 0.0059,train acc: 0.9998, val acc: 0.9985,dice: 0.8134210109710693, iou: 0.6855177879333496
# epoch: 304, mb: 2, train cost: 0.0007, val cost: 0.0063,train acc: 0.9997, val acc: 0.9985,dice: 0.8163539171218872, iou: 0.6896942257881165
# epoch: 304, mb: 3, train cost: 0.0008, val cost: 0.0063,train acc: 0.9997, val acc: 0.9985,dice: 0.8139223456382751, iou: 0.6862302422523499
# epoch: 304, mb: 4, train cost: 0.0008, val cost: 0.0060,train acc: 0.9997, val acc: 0.9984,dice: 0.8101709485054016, iou: 0.6809138059616089
# epoch: 304, mb: 5, train cost: 0.0007, val cost: 0.0061,train acc: 0.9998, val acc: 0.9985,dice: 0.8149913549423218, iou: 0.6877513527870178
# epoch: 304, mb: 6, train cost: 0.0008, val cost: 0.0063,train acc: 0.9998, val acc: 0.9985,dice: 0.8116453289985657, iou: 0.6829992532730103
# epoch: 304, mb: 7, train cost: 0.0008, val cost: 0.0060,train acc: 0.9997, val acc: 0.9985,dice: 0.8119964003562927, iou: 0.6834965944290161
# epoch: 304, mb: 8, train cost: 0.0007, val cost: 0.0063,train acc: 0.9998, val acc: 0.9984,dice: 0.8030372858047485, iou: 0.6708958148956299
# epoch: 304, mb: 9, train cost: 0.0008, val cost: 0.0063,train acc: 0.9997, val acc: 0.9985,dice: 0.8152245879173279, iou: 0.6880836486816406
# epoch: 304, mb: 10, train cost: 0.0008, val cost: 0.0063,train acc: 0.9997, val acc: 0.9984,dice: 0.8141971230506897, iou: 0.6866210103034973
# epoch: 304, mb: 11, train cost: 0.0008, val cost: 0.0060,train acc: 0.9997, val acc: 0.9984,dice: 0.8149100542068481, iou: 0.687635600566864
# epoch: 305, mb: 1, train cost: 0.0009, val cost: 0.0060,train acc: 0.9996, val acc: 0.9984,dice: 0.8127316236495972, iou: 0.6845391392707825
# epoch: 305, mb: 2, train cost: 0.0009, val cost: 0.0059,train acc: 0.9997, val acc: 0.9985,dice: 0.812826931476593, iou: 0.6846743226051331
# epoch: 305, mb: 3, train cost: 0.0010, val cost: 0.0063,train acc: 0.9996, val acc: 0.9985,dice: 0.8144420385360718, iou: 0.6869693398475647
# epoch: 305, mb: 4, train cost: 0.0009, val cost: 0.0059,train acc: 0.9997, val acc: 0.9984,dice: 0.81186842918396, iou: 0.6833152174949646
# epoch: 305, mb: 5, train cost: 0.0009, val cost: 0.0063,train acc: 0.9997, val acc: 0.9984,dice: 0.8124727606773376, iou: 0.6841718554496765
# epoch: 305, mb: 6, train cost: 0.0009, val cost: 0.0061,train acc: 0.9997, val acc: 0.9985,dice: 0.8129146099090576, iou: 0.6847988367080688
# epoch: 305, mb: 7, train cost: 0.0008, val cost: 0.0062,train acc: 0.9997, val acc: 0.9985,dice: 0.8130483627319336, iou: 0.6849886178970337
# epoch: 305, mb: 8, train cost: 0.0008, val cost: 0.0064,train acc: 0.9997, val acc: 0.9985,dice: 0.8135667443275452, iou: 0.6857248544692993
# epoch: 305, mb: 9, train cost: 0.0008, val cost: 0.0062,train acc: 0.9997, val acc: 0.9985,dice: 0.8166301846504211, iou: 0.6900887489318848
# epoch: 305, mb: 10, train cost: 0.0008, val cost: 0.0062,train acc: 0.9997, val acc: 0.9985,dice: 0.8164347410202026, iou: 0.6898096203804016
# epoch: 305, mb: 11, train cost: 0.0008, val cost: 0.0064,train acc: 0.9997, val acc: 0.9985,dice: 0.8117325901985168, iou: 0.6831228733062744
# epoch: 306, mb: 1, train cost: 0.0007, val cost: 0.0064,train acc: 0.9998, val acc: 0.9985,dice: 0.8065032958984375, iou: 0.6757482886314392
# epoch: 306, mb: 2, train cost: 0.0007, val cost: 0.0066,train acc: 0.9998, val acc: 0.9984,dice: 0.8010657429695129, iou: 0.6681481599807739
# epoch: 306, mb: 3, train cost: 0.0008, val cost: 0.0064,train acc: 0.9997, val acc: 0.9984,dice: 0.80601567029953, iou: 0.6750639081001282
# epoch: 306, mb: 4, train cost: 0.0007, val cost: 0.0064,train acc: 0.9997, val acc: 0.9984,dice: 0.8069339394569397, iou: 0.6763530969619751
# epoch: 306, mb: 5, train cost: 0.0008, val cost: 0.0064,train acc: 0.9997, val acc: 0.9984,dice: 0.8065789341926575, iou: 0.6758544445037842
# epoch: 306, mb: 6, train cost: 0.0008, val cost: 0.0063,train acc: 0.9997, val acc: 0.9984,dice: 0.8075539469718933, iou: 0.6772247552871704
# epoch: 306, mb: 7, train cost: 0.0008, val cost: 0.0061,train acc: 0.9997, val acc: 0.9985,dice: 0.8108952641487122, iou: 0.6819376349449158
# epoch: 306, mb: 8, train cost: 0.0008, val cost: 0.0061,train acc: 0.9997, val acc: 0.9984,dice: 0.813096284866333, iou: 0.6850566267967224
# epoch: 306, mb: 9, train cost: 0.0008, val cost: 0.0062,train acc: 0.9997, val acc: 0.9984,dice: 0.8086472749710083, iou: 0.6787639260292053
# epoch: 306, mb: 10, train cost: 0.0008, val cost: 0.0065,train acc: 0.9997, val acc: 0.9984,dice: 0.8134199380874634, iou: 0.6855162382125854
# epoch: 306, mb: 11, train cost: 0.0008, val cost: 0.0064,train acc: 0.9997, val acc: 0.9984,dice: 0.8118162155151367, iou: 0.6832412481307983
# epoch: 307, mb: 1, train cost: 0.0008, val cost: 0.0062,train acc: 0.9997, val acc: 0.9985,dice: 0.8102748990058899, iou: 0.6810606122016907
# epoch: 307, mb: 2, train cost: 0.0008, val cost: 0.0062,train acc: 0.9997, val acc: 0.9985,dice: 0.8076311349868774, iou: 0.6773333549499512
# epoch: 307, mb: 3, train cost: 0.0008, val cost: 0.0067,train acc: 0.9997, val acc: 0.9984,dice: 0.8085859417915344, iou: 0.6786775588989258
# epoch: 307, mb: 4, train cost: 0.0007, val cost: 0.0064,train acc: 0.9998, val acc: 0.9984,dice: 0.8046773672103882, iou: 0.6731883883476257
# epoch: 307, mb: 5, train cost: 0.0007, val cost: 0.0063,train acc: 0.9998, val acc: 0.9984,dice: 0.8071690797805786, iou: 0.6766835451126099
# epoch: 307, mb: 6, train cost: 0.0007, val cost: 0.0066,train acc: 0.9998, val acc: 0.9985,dice: 0.8110741972923279, iou: 0.6821907758712769
# epoch: 307, mb: 7, train cost: 0.0007, val cost: 0.0062,train acc: 0.9998, val acc: 0.9984,dice: 0.8079856634140015, iou: 0.6778321266174316
# epoch: 307, mb: 8, train cost: 0.0007, val cost: 0.0064,train acc: 0.9997, val acc: 0.9985,dice: 0.8127192854881287, iou: 0.6845216155052185
# epoch: 307, mb: 9, train cost: 0.0007, val cost: 0.0065,train acc: 0.9997, val acc: 0.9984,dice: 0.8090810775756836, iou: 0.6793754696846008
# epoch: 307, mb: 10, train cost: 0.0007, val cost: 0.0062,train acc: 0.9998, val acc: 0.9984,dice: 0.8107755780220032, iou: 0.6817683577537537
# epoch: 307, mb: 11, train cost: 0.0007, val cost: 0.0064,train acc: 0.9998, val acc: 0.9984,dice: 0.8060238361358643, iou: 0.6750752925872803
# epoch: 308, mb: 1, train cost: 0.0008, val cost: 0.0062,train acc: 0.9997, val acc: 0.9985,dice: 0.8101610541343689, iou: 0.6808997392654419
# epoch: 308, mb: 2, train cost: 0.0008, val cost: 0.0060,train acc: 0.9997, val acc: 0.9985,dice: 0.8128035068511963, iou: 0.6846411228179932
# epoch: 308, mb: 3, train cost: 0.0008, val cost: 0.0061,train acc: 0.9997, val acc: 0.9985,dice: 0.816361665725708, iou: 0.6897053718566895
# epoch: 308, mb: 4, train cost: 0.0008, val cost: 0.0060,train acc: 0.9997, val acc: 0.9984,dice: 0.8138527870178223, iou: 0.6861313581466675
# epoch: 308, mb: 5, train cost: 0.0008, val cost: 0.0061,train acc: 0.9997, val acc: 0.9985,dice: 0.8159999847412109, iou: 0.6891891956329346
# epoch: 308, mb: 6, train cost: 0.0008, val cost: 0.0062,train acc: 0.9997, val acc: 0.9985,dice: 0.812514066696167, iou: 0.6842305064201355
# epoch: 308, mb: 7, train cost: 0.0008, val cost: 0.0063,train acc: 0.9997, val acc: 0.9985,dice: 0.8075523376464844, iou: 0.6772224307060242
# epoch: 308, mb: 8, train cost: 0.0008, val cost: 0.0063,train acc: 0.9997, val acc: 0.9985,dice: 0.8089585900306702, iou: 0.6792027354240417
# epoch: 308, mb: 9, train cost: 0.0008, val cost: 0.0062,train acc: 0.9997, val acc: 0.9984,dice: 0.8099867701530457, iou: 0.6806535720825195
# epoch: 308, mb: 10, train cost: 0.0007, val cost: 0.0066,train acc: 0.9998, val acc: 0.9984,dice: 0.8107399940490723, iou: 0.6817180514335632
# epoch: 308, mb: 11, train cost: 0.0007, val cost: 0.0064,train acc: 0.9998, val acc: 0.9984,dice: 0.8071397542953491, iou: 0.6766423583030701
# epoch: 309, mb: 1, train cost: 0.0006, val cost: 0.0065,train acc: 0.9999, val acc: 0.9984,dice: 0.8065359592437744, iou: 0.6757940649986267
# epoch: 309, mb: 2, train cost: 0.0008, val cost: 0.0063,train acc: 0.9998, val acc: 0.9984,dice: 0.809116780757904, iou: 0.679425835609436
# epoch: 309, mb: 3, train cost: 0.0007, val cost: 0.0066,train acc: 0.9998, val acc: 0.9985,dice: 0.807128369808197, iou: 0.6766263246536255
# epoch: 309, mb: 4, train cost: 0.0007, val cost: 0.0064,train acc: 0.9998, val acc: 0.9984,dice: 0.807528555393219, iou: 0.67718905210495
# epoch: 309, mb: 5, train cost: 0.0007, val cost: 0.0067,train acc: 0.9998, val acc: 0.9984,dice: 0.8065733909606934, iou: 0.6758466958999634
# epoch: 309, mb: 6, train cost: 0.0007, val cost: 0.0065,train acc: 0.9998, val acc: 0.9984,dice: 0.8099934458732605, iou: 0.680662989616394
# epoch: 309, mb: 7, train cost: 0.0007, val cost: 0.0062,train acc: 0.9998, val acc: 0.9984,dice: 0.8110842108726501, iou: 0.6822049617767334
# epoch: 309, mb: 8, train cost: 0.0007, val cost: 0.0063,train acc: 0.9998, val acc: 0.9984,dice: 0.8096491098403931, iou: 0.680176854133606
# epoch: 309, mb: 9, train cost: 0.0007, val cost: 0.0063,train acc: 0.9998, val acc: 0.9984,dice: 0.8062471747398376, iou: 0.6753886938095093
# epoch: 309, mb: 10, train cost: 0.0007, val cost: 0.0060,train acc: 0.9998, val acc: 0.9985,dice: 0.8078750967979431, iou: 0.6776765584945679
# epoch: 309, mb: 11, train cost: 0.0007, val cost: 0.0059,train acc: 0.9998, val acc: 0.9985,dice: 0.8077097535133362, iou: 0.6774439215660095
# epoch: 310, mb: 1, train cost: 0.0007, val cost: 0.0064,train acc: 0.9998, val acc: 0.9984,dice: 0.8104517459869385, iou: 0.6813104748725891
# epoch: 310, mb: 2, train cost: 0.0007, val cost: 0.0061,train acc: 0.9998, val acc: 0.9984,dice: 0.8115816712379456, iou: 0.6829090714454651
# epoch: 310, mb: 3, train cost: 0.0008, val cost: 0.0063,train acc: 0.9998, val acc: 0.9984,dice: 0.808925449848175, iou: 0.6791560649871826
# epoch: 310, mb: 4, train cost: 0.0008, val cost: 0.0065,train acc: 0.9997, val acc: 0.9985,dice: 0.8095667958259583, iou: 0.680060625076294
# epoch: 310, mb: 5, train cost: 0.0008, val cost: 0.0064,train acc: 0.9997, val acc: 0.9984,dice: 0.8052775263786316, iou: 0.6740289330482483
# epoch: 310, mb: 6, train cost: 0.0008, val cost: 0.0065,train acc: 0.9997, val acc: 0.9984,dice: 0.8087578415870667, iou: 0.6789197325706482
# epoch: 310, mb: 7, train cost: 0.0008, val cost: 0.0062,train acc: 0.9998, val acc: 0.9984,dice: 0.8091569542884827, iou: 0.6794824600219727
# epoch: 310, mb: 8, train cost: 0.0007, val cost: 0.0062,train acc: 0.9998, val acc: 0.9984,dice: 0.8084366321563721, iou: 0.6784671545028687
# epoch: 310, mb: 9, train cost: 0.0007, val cost: 0.0062,train acc: 0.9998, val acc: 0.9984,dice: 0.8116699457168579, iou: 0.6830340623855591
# epoch: 310, mb: 10, train cost: 0.0007, val cost: 0.0064,train acc: 0.9998, val acc: 0.9984,dice: 0.8058446049690247, iou: 0.6748238801956177
# epoch: 310, mb: 11, train cost: 0.0007, val cost: 0.0065,train acc: 0.9998, val acc: 0.9985,dice: 0.8054983019828796, iou: 0.6743383407592773
# epoch: 311, mb: 1, train cost: 0.0008, val cost: 0.0061,train acc: 0.9997, val acc: 0.9984,dice: 0.808879017829895, iou: 0.6790905594825745
# epoch: 311, mb: 2, train cost: 0.0008, val cost: 0.0065,train acc: 0.9997, val acc: 0.9984,dice: 0.8099891543388367, iou: 0.680656909942627
# epoch: 311, mb: 3, train cost: 0.0008, val cost: 0.0063,train acc: 0.9997, val acc: 0.9984,dice: 0.8087666630744934, iou: 0.6789321899414062
# epoch: 311, mb: 4, train cost: 0.0007, val cost: 0.0068,train acc: 0.9998, val acc: 0.9984,dice: 0.8098850846290588, iou: 0.6805100440979004
# epoch: 311, mb: 5, train cost: 0.0007, val cost: 0.0064,train acc: 0.9998, val acc: 0.9984,dice: 0.8069073557853699, iou: 0.6763157844543457
# epoch: 311, mb: 6, train cost: 0.0007, val cost: 0.0070,train acc: 0.9998, val acc: 0.9984,dice: 0.7889471054077148, iou: 0.6514555215835571
# epoch: 311, mb: 7, train cost: 0.0007, val cost: 0.0066,train acc: 0.9997, val acc: 0.9985,dice: 0.8038077354431152, iou: 0.6719720363616943
# epoch: 311, mb: 8, train cost: 0.0007, val cost: 0.0063,train acc: 0.9997, val acc: 0.9984,dice: 0.8089936971664429, iou: 0.6792522072792053
# epoch: 311, mb: 9, train cost: 0.0007, val cost: 0.0063,train acc: 0.9997, val acc: 0.9984,dice: 0.8128319382667542, iou: 0.6846814751625061
# epoch: 311, mb: 10, train cost: 0.0008, val cost: 0.0066,train acc: 0.9997, val acc: 0.9984,dice: 0.8069489598274231, iou: 0.6763741970062256
# epoch: 311, mb: 11, train cost: 0.0008, val cost: 0.0062,train acc: 0.9997, val acc: 0.9984,dice: 0.8095978498458862, iou: 0.6801044940948486
# epoch: 312, mb: 1, train cost: 0.0008, val cost: 0.0061,train acc: 0.9998, val acc: 0.9984,dice: 0.8084059953689575, iou: 0.6784240007400513
# epoch: 312, mb: 2, train cost: 0.0010, val cost: 0.0065,train acc: 0.9997, val acc: 0.9984,dice: 0.8080542683601379, iou: 0.6779287457466125
# epoch: 312, mb: 3, train cost: 0.0009, val cost: 0.0069,train acc: 0.9997, val acc: 0.9984,dice: 0.8048516511917114, iou: 0.6734324097633362
# epoch: 312, mb: 4, train cost: 0.0009, val cost: 0.0067,train acc: 0.9997, val acc: 0.9984,dice: 0.8022772073745728, iou: 0.6698354482650757
# epoch: 312, mb: 5, train cost: 0.0009, val cost: 0.0068,train acc: 0.9997, val acc: 0.9984,dice: 0.8030168414115906, iou: 0.6708673238754272
# epoch: 312, mb: 6, train cost: 0.0009, val cost: 0.0065,train acc: 0.9997, val acc: 0.9984,dice: 0.8042609691619873, iou: 0.6726058125495911
# epoch: 312, mb: 7, train cost: 0.0009, val cost: 0.0067,train acc: 0.9997, val acc: 0.9984,dice: 0.8072024583816528, iou: 0.6767305135726929
# epoch: 312, mb: 8, train cost: 0.0009, val cost: 0.0064,train acc: 0.9997, val acc: 0.9984,dice: 0.8079181909561157, iou: 0.6777372360229492
# epoch: 312, mb: 9, train cost: 0.0009, val cost: 0.0066,train acc: 0.9997, val acc: 0.9984,dice: 0.8078362345695496, iou: 0.6776218414306641
# epoch: 312, mb: 10, train cost: 0.0009, val cost: 0.0072,train acc: 0.9997, val acc: 0.9984,dice: 0.7955875992774963, iou: 0.6605607271194458
# epoch: 312, mb: 11, train cost: 0.0009, val cost: 0.0071,train acc: 0.9997, val acc: 0.9983,dice: 0.7826694846153259, iou: 0.6429391503334045
# epoch: 313, mb: 1, train cost: 0.0020, val cost: 0.0068,train acc: 0.9993, val acc: 0.9983,dice: 0.8068937063217163, iou: 0.6762965321540833
# epoch: 313, mb: 2, train cost: 0.0017, val cost: 0.0067,train acc: 0.9994, val acc: 0.9983,dice: 0.8043037056922913, iou: 0.672665536403656
# epoch: 313, mb: 3, train cost: 0.0016, val cost: 0.0064,train acc: 0.9994, val acc: 0.9984,dice: 0.8110439777374268, iou: 0.6821480393409729
# epoch: 313, mb: 4, train cost: 0.0014, val cost: 0.0063,train acc: 0.9995, val acc: 0.9985,dice: 0.8017621040344238, iou: 0.6691176295280457
# epoch: 313, mb: 5, train cost: 0.0014, val cost: 0.0063,train acc: 0.9995, val acc: 0.9984,dice: 0.8024606704711914, iou: 0.6700913310050964
# epoch: 313, mb: 6, train cost: 0.0014, val cost: 0.0064,train acc: 0.9995, val acc: 0.9984,dice: 0.8056507110595703, iou: 0.6745519638061523
# epoch: 313, mb: 7, train cost: 0.0013, val cost: 0.0067,train acc: 0.9995, val acc: 0.9982,dice: 0.797249436378479, iou: 0.6628551483154297
# epoch: 313, mb: 8, train cost: 0.0013, val cost: 0.0070,train acc: 0.9995, val acc: 0.9983,dice: 0.802096426486969, iou: 0.6695834994316101
# epoch: 313, mb: 9, train cost: 0.0013, val cost: 0.0062,train acc: 0.9995, val acc: 0.9984,dice: 0.807279109954834, iou: 0.676838219165802
# epoch: 313, mb: 10, train cost: 0.0013, val cost: 0.0065,train acc: 0.9995, val acc: 0.9984,dice: 0.802916407585144, iou: 0.6707270741462708
# epoch: 313, mb: 11, train cost: 0.0013, val cost: 0.0060,train acc: 0.9995, val acc: 0.9985,dice: 0.8045496940612793, iou: 0.6730096936225891
# epoch: 314, mb: 1, train cost: 0.0010, val cost: 0.0061,train acc: 0.9996, val acc: 0.9985,dice: 0.8106630444526672, iou: 0.6816092133522034
# epoch: 314, mb: 2, train cost: 0.0013, val cost: 0.0064,train acc: 0.9995, val acc: 0.9984,dice: 0.8110321164131165, iou: 0.6821312308311462
# epoch: 314, mb: 3, train cost: 0.0012, val cost: 0.0068,train acc: 0.9995, val acc: 0.9982,dice: 0.7991718649864197, iou: 0.665517270565033
# epoch: 314, mb: 4, train cost: 0.0013, val cost: 0.0069,train acc: 0.9995, val acc: 0.9983,dice: 0.7971848845481873, iou: 0.6627659797668457
# epoch: 314, mb: 5, train cost: 0.0013, val cost: 0.0067,train acc: 0.9995, val acc: 0.9984,dice: 0.8015820980072021, iou: 0.6688668727874756
# epoch: 314, mb: 6, train cost: 0.0012, val cost: 0.0064,train acc: 0.9995, val acc: 0.9984,dice: 0.8072369694709778, iou: 0.67677903175354
# epoch: 314, mb: 7, train cost: 0.0011, val cost: 0.0062,train acc: 0.9996, val acc: 0.9984,dice: 0.8057041168212891, iou: 0.674626886844635
# epoch: 314, mb: 8, train cost: 0.0011, val cost: 0.0059,train acc: 0.9996, val acc: 0.9984,dice: 0.8112589716911316, iou: 0.6824522614479065
# epoch: 314, mb: 9, train cost: 0.0011, val cost: 0.0061,train acc: 0.9996, val acc: 0.9984,dice: 0.8097412586212158, iou: 0.6803069114685059
# epoch: 314, mb: 10, train cost: 0.0011, val cost: 0.0059,train acc: 0.9996, val acc: 0.9984,dice: 0.8063293695449829, iou: 0.6755040884017944
# epoch: 314, mb: 11, train cost: 0.0011, val cost: 0.0065,train acc: 0.9996, val acc: 0.9984,dice: 0.797212541103363, iou: 0.6628041863441467
# epoch: 315, mb: 1, train cost: 0.0010, val cost: 0.0064,train acc: 0.9996, val acc: 0.9984,dice: 0.8000924587249756, iou: 0.6667950749397278
# epoch: 315, mb: 2, train cost: 0.0011, val cost: 0.0059,train acc: 0.9996, val acc: 0.9985,dice: 0.8140969276428223, iou: 0.6864784359931946
# epoch: 315, mb: 3, train cost: 0.0009, val cost: 0.0059,train acc: 0.9997, val acc: 0.9984,dice: 0.811699390411377, iou: 0.6830758452415466
# epoch: 315, mb: 4, train cost: 0.0009, val cost: 0.0057,train acc: 0.9997, val acc: 0.9984,dice: 0.8138747811317444, iou: 0.6861626505851746
# epoch: 315, mb: 5, train cost: 0.0010, val cost: 0.0057,train acc: 0.9997, val acc: 0.9984,dice: 0.8138979077339172, iou: 0.6861955523490906
# epoch: 315, mb: 6, train cost: 0.0010, val cost: 0.0059,train acc: 0.9997, val acc: 0.9985,dice: 0.8154907822608948, iou: 0.6884629726409912
# epoch: 315, mb: 7, train cost: 0.0009, val cost: 0.0058,train acc: 0.9997, val acc: 0.9985,dice: 0.8148989081382751, iou: 0.6876198053359985
# epoch: 315, mb: 8, train cost: 0.0009, val cost: 0.0060,train acc: 0.9997, val acc: 0.9985,dice: 0.8176844120025635, iou: 0.691595733165741
# epoch: 315, mb: 9, train cost: 0.0009, val cost: 0.0060,train acc: 0.9997, val acc: 0.9985,dice: 0.8171996474266052, iou: 0.6909024715423584
# epoch: 315, mb: 10, train cost: 0.0009, val cost: 0.0057,train acc: 0.9997, val acc: 0.9985,dice: 0.8164166212081909, iou: 0.6897837519645691
# epoch: 315, mb: 11, train cost: 0.0009, val cost: 0.0059,train acc: 0.9997, val acc: 0.9985,dice: 0.816127598285675, iou: 0.6893712282180786
# epoch: 316, mb: 1, train cost: 0.0008, val cost: 0.0060,train acc: 0.9997, val acc: 0.9985,dice: 0.8181818127632141, iou: 0.692307710647583
# epoch: 316, mb: 2, train cost: 0.0006, val cost: 0.0060,train acc: 0.9998, val acc: 0.9985,dice: 0.8142597675323486, iou: 0.6867100596427917
# epoch: 316, mb: 3, train cost: 0.0007, val cost: 0.0060,train acc: 0.9998, val acc: 0.9985,dice: 0.8166590929031372, iou: 0.6901300549507141
# epoch: 316, mb: 4, train cost: 0.0008, val cost: 0.0058,train acc: 0.9998, val acc: 0.9984,dice: 0.8132055401802063, iou: 0.6852117776870728
# epoch: 316, mb: 5, train cost: 0.0008, val cost: 0.0062,train acc: 0.9997, val acc: 0.9984,dice: 0.8120833039283752, iou: 0.6836197972297668
# epoch: 316, mb: 6, train cost: 0.0008, val cost: 0.0057,train acc: 0.9997, val acc: 0.9984,dice: 0.8126072287559509, iou: 0.6843625903129578
# epoch: 316, mb: 7, train cost: 0.0008, val cost: 0.0061,train acc: 0.9997, val acc: 0.9985,dice: 0.8097074031829834, iou: 0.6802591681480408
# epoch: 316, mb: 8, train cost: 0.0008, val cost: 0.0062,train acc: 0.9997, val acc: 0.9984,dice: 0.802215576171875, iou: 0.6697494983673096
# epoch: 316, mb: 9, train cost: 0.0008, val cost: 0.0060,train acc: 0.9997, val acc: 0.9984,dice: 0.8033643960952759, iou: 0.6713525652885437
# epoch: 316, mb: 10, train cost: 0.0008, val cost: 0.0063,train acc: 0.9997, val acc: 0.9984,dice: 0.8101045489311218, iou: 0.6808199286460876
# epoch: 316, mb: 11, train cost: 0.0008, val cost: 0.0060,train acc: 0.9997, val acc: 0.9984,dice: 0.815571129322052, iou: 0.6885775923728943
# epoch: 317, mb: 1, train cost: 0.0009, val cost: 0.0062,train acc: 0.9996, val acc: 0.9985,dice: 0.816641628742218, iou: 0.690105140209198
# epoch: 317, mb: 2, train cost: 0.0009, val cost: 0.0059,train acc: 0.9997, val acc: 0.9985,dice: 0.8142730593681335, iou: 0.6867289543151855
# epoch: 317, mb: 3, train cost: 0.0008, val cost: 0.0062,train acc: 0.9997, val acc: 0.9985,dice: 0.805874228477478, iou: 0.6748654842376709
# epoch: 317, mb: 4, train cost: 0.0008, val cost: 0.0062,train acc: 0.9997, val acc: 0.9984,dice: 0.797709047794342, iou: 0.6634908318519592
# epoch: 317, mb: 5, train cost: 0.0009, val cost: 0.0061,train acc: 0.9997, val acc: 0.9984,dice: 0.8090628981590271, iou: 0.6793498396873474
# epoch: 317, mb: 6, train cost: 0.0008, val cost: 0.0063,train acc: 0.9997, val acc: 0.9984,dice: 0.8090375661849976, iou: 0.679314136505127
# epoch: 317, mb: 7, train cost: 0.0008, val cost: 0.0059,train acc: 0.9997, val acc: 0.9984,dice: 0.8123525381088257, iou: 0.6840014457702637
# epoch: 317, mb: 8, train cost: 0.0008, val cost: 0.0059,train acc: 0.9997, val acc: 0.9984,dice: 0.8107276558876038, iou: 0.6817005276679993
# epoch: 317, mb: 9, train cost: 0.0008, val cost: 0.0059,train acc: 0.9997, val acc: 0.9985,dice: 0.8124301433563232, iou: 0.6841114163398743
# epoch: 317, mb: 10, train cost: 0.0008, val cost: 0.0059,train acc: 0.9997, val acc: 0.9984,dice: 0.8086419701576233, iou: 0.6787564754486084
# epoch: 317, mb: 11, train cost: 0.0008, val cost: 0.0060,train acc: 0.9997, val acc: 0.9984,dice: 0.8089538812637329, iou: 0.6791961193084717
# epoch: 318, mb: 1, train cost: 0.0007, val cost: 0.0059,train acc: 0.9998, val acc: 0.9984,dice: 0.8070718050003052, iou: 0.6765468716621399
# epoch: 318, mb: 2, train cost: 0.0007, val cost: 0.0061,train acc: 0.9998, val acc: 0.9985,dice: 0.8116582036018372, iou: 0.6830174922943115
# epoch: 318, mb: 3, train cost: 0.0008, val cost: 0.0062,train acc: 0.9997, val acc: 0.9985,dice: 0.8123077154159546, iou: 0.6839378476142883
# epoch: 318, mb: 4, train cost: 0.0008, val cost: 0.0061,train acc: 0.9997, val acc: 0.9984,dice: 0.8103851675987244, iou: 0.6812164783477783
# epoch: 318, mb: 5, train cost: 0.0008, val cost: 0.0060,train acc: 0.9997, val acc: 0.9984,dice: 0.8126984238624573, iou: 0.6844919919967651
# epoch: 318, mb: 6, train cost: 0.0008, val cost: 0.0060,train acc: 0.9997, val acc: 0.9984,dice: 0.811562716960907, iou: 0.6828822493553162
# epoch: 318, mb: 7, train cost: 0.0008, val cost: 0.0062,train acc: 0.9997, val acc: 0.9985,dice: 0.8107023239135742, iou: 0.681664764881134
# epoch: 318, mb: 8, train cost: 0.0008, val cost: 0.0062,train acc: 0.9997, val acc: 0.9984,dice: 0.8086610436439514, iou: 0.6787833571434021
# epoch: 318, mb: 9, train cost: 0.0008, val cost: 0.0061,train acc: 0.9997, val acc: 0.9984,dice: 0.8098992705345154, iou: 0.6805300116539001
# epoch: 318, mb: 10, train cost: 0.0008, val cost: 0.0066,train acc: 0.9997, val acc: 0.9984,dice: 0.8096809387207031, iou: 0.6802217960357666
# epoch: 318, mb: 11, train cost: 0.0008, val cost: 0.0062,train acc: 0.9997, val acc: 0.9984,dice: 0.8138378262519836, iou: 0.6861100792884827
# epoch: 319, mb: 1, train cost: 0.0008, val cost: 0.0062,train acc: 0.9998, val acc: 0.9984,dice: 0.810307502746582, iou: 0.681106686592102
# epoch: 319, mb: 2, train cost: 0.0009, val cost: 0.0066,train acc: 0.9996, val acc: 0.9984,dice: 0.8103298544883728, iou: 0.681138277053833
# epoch: 319, mb: 3, train cost: 0.0009, val cost: 0.0062,train acc: 0.9997, val acc: 0.9984,dice: 0.810512363910675, iou: 0.6813961863517761
# epoch: 319, mb: 4, train cost: 0.0009, val cost: 0.0064,train acc: 0.9997, val acc: 0.9984,dice: 0.8083017468452454, iou: 0.6782771348953247
# epoch: 319, mb: 5, train cost: 0.0008, val cost: 0.0060,train acc: 0.9997, val acc: 0.9985,dice: 0.8100978136062622, iou: 0.6808103919029236
# epoch: 319, mb: 6, train cost: 0.0008, val cost: 0.0057,train acc: 0.9997, val acc: 0.9985,dice: 0.817629873752594, iou: 0.69151771068573
# epoch: 319, mb: 7, train cost: 0.0008, val cost: 0.0058,train acc: 0.9997, val acc: 0.9984,dice: 0.8147668242454529, iou: 0.6874316930770874
# epoch: 319, mb: 8, train cost: 0.0008, val cost: 0.0059,train acc: 0.9997, val acc: 0.9984,dice: 0.8137728571891785, iou: 0.6860176920890808
# epoch: 319, mb: 9, train cost: 0.0008, val cost: 0.0060,train acc: 0.9997, val acc: 0.9984,dice: 0.8144834637641907, iou: 0.6870284080505371
# epoch: 319, mb: 10, train cost: 0.0008, val cost: 0.0058,train acc: 0.9997, val acc: 0.9985,dice: 0.8209684491157532, iou: 0.6963074803352356
# epoch: 319, mb: 11, train cost: 0.0008, val cost: 0.0059,train acc: 0.9997, val acc: 0.9985,dice: 0.8146950006484985, iou: 0.6873294115066528
# epoch: 320, mb: 1, train cost: 0.0008, val cost: 0.0060,train acc: 0.9997, val acc: 0.9985,dice: 0.8123249411582947, iou: 0.6839622855186462
# epoch: 320, mb: 2, train cost: 0.0009, val cost: 0.0060,train acc: 0.9997, val acc: 0.9985,dice: 0.8180227279663086, iou: 0.6920799612998962
# epoch: 320, mb: 3, train cost: 0.0009, val cost: 0.0062,train acc: 0.9997, val acc: 0.9984,dice: 0.8153077960014343, iou: 0.6882022619247437
# epoch: 320, mb: 4, train cost: 0.0009, val cost: 0.0069,train acc: 0.9997, val acc: 0.9983,dice: 0.8088597059249878, iou: 0.6790633797645569
# epoch: 320, mb: 5, train cost: 0.0009, val cost: 0.0065,train acc: 0.9997, val acc: 0.9984,dice: 0.8126957416534424, iou: 0.6844882369041443
# epoch: 320, mb: 6, train cost: 0.0010, val cost: 0.0059,train acc: 0.9996, val acc: 0.9985,dice: 0.818508505821228, iou: 0.6927756667137146
# epoch: 320, mb: 7, train cost: 0.0009, val cost: 0.0070,train acc: 0.9997, val acc: 0.9984,dice: 0.792298436164856, iou: 0.6560382843017578
# epoch: 320, mb: 8, train cost: 0.0009, val cost: 0.0067,train acc: 0.9997, val acc: 0.9984,dice: 0.7960246205329895, iou: 0.6611635088920593
# epoch: 320, mb: 9, train cost: 0.0009, val cost: 0.0062,train acc: 0.9997, val acc: 0.9985,dice: 0.8086917400360107, iou: 0.678826630115509
# epoch: 320, mb: 10, train cost: 0.0009, val cost: 0.0063,train acc: 0.9997, val acc: 0.9984,dice: 0.8123011589050293, iou: 0.6839285492897034
# epoch: 320, mb: 11, train cost: 0.0009, val cost: 0.0067,train acc: 0.9997, val acc: 0.9983,dice: 0.8068205714225769, iou: 0.6761937737464905
# epoch: 321, mb: 1, train cost: 0.0014, val cost: 0.0064,train acc: 0.9994, val acc: 0.9984,dice: 0.8139484524726868, iou: 0.6862673759460449
# epoch: 321, mb: 2, train cost: 0.0010, val cost: 0.0062,train acc: 0.9996, val acc: 0.9984,dice: 0.8007304072380066, iou: 0.6676817536354065
# epoch: 321, mb: 3, train cost: 0.0010, val cost: 0.0069,train acc: 0.9996, val acc: 0.9984,dice: 0.7977813482284546, iou: 0.6635909080505371
# epoch: 321, mb: 4, train cost: 0.0010, val cost: 0.0064,train acc: 0.9996, val acc: 0.9984,dice: 0.8016067743301392, iou: 0.6689013242721558
# epoch: 321, mb: 5, train cost: 0.0010, val cost: 0.0069,train acc: 0.9996, val acc: 0.9984,dice: 0.8035405874252319, iou: 0.6715986728668213
# epoch: 321, mb: 6, train cost: 0.0009, val cost: 0.0064,train acc: 0.9996, val acc: 0.9983,dice: 0.8030399084091187, iou: 0.6708994507789612
# epoch: 321, mb: 7, train cost: 0.0009, val cost: 0.0065,train acc: 0.9996, val acc: 0.9983,dice: 0.8075949549674988, iou: 0.6772823929786682
# epoch: 321, mb: 8, train cost: 0.0010, val cost: 0.0064,train acc: 0.9996, val acc: 0.9984,dice: 0.8094390034675598, iou: 0.6798803210258484
# epoch: 321, mb: 9, train cost: 0.0010, val cost: 0.0068,train acc: 0.9996, val acc: 0.9985,dice: 0.8050165772438049, iou: 0.6736633777618408
# epoch: 321, mb: 10, train cost: 0.0010, val cost: 0.0062,train acc: 0.9996, val acc: 0.9985,dice: 0.8119540214538574, iou: 0.6834365129470825
# epoch: 321, mb: 11, train cost: 0.0011, val cost: 0.0066,train acc: 0.9996, val acc: 0.9982,dice: 0.797950804233551, iou: 0.6638254523277283
# epoch: 322, mb: 1, train cost: 0.0014, val cost: 0.0070,train acc: 0.9994, val acc: 0.9981,dice: 0.7888320684432983, iou: 0.6512987017631531
# epoch: 322, mb: 2, train cost: 0.0016, val cost: 0.0060,train acc: 0.9993, val acc: 0.9982,dice: 0.7977527976036072, iou: 0.663551390171051
# epoch: 322, mb: 3, train cost: 0.0016, val cost: 0.0056,train acc: 0.9994, val acc: 0.9984,dice: 0.7967108488082886, iou: 0.6621108651161194
# epoch: 322, mb: 4, train cost: 0.0016, val cost: 0.0057,train acc: 0.9994, val acc: 0.9983,dice: 0.7916001081466675, iou: 0.6550812125205994
# epoch: 322, mb: 5, train cost: 0.0016, val cost: 0.0056,train acc: 0.9994, val acc: 0.9984,dice: 0.8055070042610168, iou: 0.6743505597114563
# epoch: 322, mb: 6, train cost: 0.0015, val cost: 0.0052,train acc: 0.9994, val acc: 0.9984,dice: 0.8108344078063965, iou: 0.6818515658378601
# epoch: 322, mb: 7, train cost: 0.0015, val cost: 0.0051,train acc: 0.9994, val acc: 0.9984,dice: 0.8105960488319397, iou: 0.6815145015716553
# epoch: 322, mb: 8, train cost: 0.0015, val cost: 0.0049,train acc: 0.9994, val acc: 0.9985,dice: 0.8163707256317139, iou: 0.6897182464599609
# epoch: 322, mb: 9, train cost: 0.0014, val cost: 0.0054,train acc: 0.9995, val acc: 0.9984,dice: 0.8113247156143188, iou: 0.6825453042984009
# epoch: 322, mb: 10, train cost: 0.0014, val cost: 0.0049,train acc: 0.9995, val acc: 0.9985,dice: 0.8208890557289124, iou: 0.696193277835846
# epoch: 322, mb: 11, train cost: 0.0014, val cost: 0.0049,train acc: 0.9995, val acc: 0.9986,dice: 0.825774610042572, iou: 0.7032504677772522
# epoch: 323, mb: 1, train cost: 0.0015, val cost: 0.0049,train acc: 0.9994, val acc: 0.9985,dice: 0.8185985684394836, iou: 0.6929046511650085
# epoch: 323, mb: 2, train cost: 0.0013, val cost: 0.0055,train acc: 0.9995, val acc: 0.9984,dice: 0.8115636110305786, iou: 0.6828835010528564
# epoch: 323, mb: 3, train cost: 0.0013, val cost: 0.0055,train acc: 0.9995, val acc: 0.9984,dice: 0.8079670667648315, iou: 0.67780601978302
# epoch: 323, mb: 4, train cost: 0.0012, val cost: 0.0055,train acc: 0.9996, val acc: 0.9985,dice: 0.8130261301994324, iou: 0.6849570870399475
# epoch: 323, mb: 5, train cost: 0.0011, val cost: 0.0059,train acc: 0.9996, val acc: 0.9984,dice: 0.801455557346344, iou: 0.6686906814575195
# epoch: 323, mb: 6, train cost: 0.0011, val cost: 0.0057,train acc: 0.9996, val acc: 0.9985,dice: 0.8141320943832397, iou: 0.6865285038948059
# epoch: 323, mb: 7, train cost: 0.0011, val cost: 0.0059,train acc: 0.9996, val acc: 0.9984,dice: 0.8123916983604431, iou: 0.6840569376945496
# epoch: 323, mb: 8, train cost: 0.0011, val cost: 0.0063,train acc: 0.9996, val acc: 0.9984,dice: 0.8074058294296265, iou: 0.6770164370536804
# epoch: 323, mb: 9, train cost: 0.0011, val cost: 0.0062,train acc: 0.9996, val acc: 0.9985,dice: 0.813753604888916, iou: 0.6859903335571289
# epoch: 323, mb: 10, train cost: 0.0011, val cost: 0.0065,train acc: 0.9996, val acc: 0.9985,dice: 0.8018713593482971, iou: 0.6692698001861572
# epoch: 323, mb: 11, train cost: 0.0010, val cost: 0.0071,train acc: 0.9996, val acc: 0.9984,dice: 0.7806295156478882, iou: 0.640190601348877
# epoch: 324, mb: 1, train cost: 0.0013, val cost: 0.0067,train acc: 0.9995, val acc: 0.9984,dice: 0.7941381931304932, iou: 0.6585648059844971
# epoch: 324, mb: 2, train cost: 0.0011, val cost: 0.0062,train acc: 0.9996, val acc: 0.9984,dice: 0.8071305751800537, iou: 0.6766294836997986
# epoch: 324, mb: 3, train cost: 0.0012, val cost: 0.0063,train acc: 0.9996, val acc: 0.9983,dice: 0.8097418546676636, iou: 0.6803078055381775
# epoch: 324, mb: 4, train cost: 0.0012, val cost: 0.0062,train acc: 0.9996, val acc: 0.9984,dice: 0.8122653365135193, iou: 0.6838777661323547
# epoch: 324, mb: 5, train cost: 0.0012, val cost: 0.0055,train acc: 0.9995, val acc: 0.9985,dice: 0.8170175552368164, iou: 0.6906421780586243
# epoch: 324, mb: 6, train cost: 0.0012, val cost: 0.0055,train acc: 0.9996, val acc: 0.9985,dice: 0.8132611513137817, iou: 0.6852907538414001
# epoch: 324, mb: 7, train cost: 0.0012, val cost: 0.0057,train acc: 0.9996, val acc: 0.9985,dice: 0.8138728141784668, iou: 0.6861598491668701
# epoch: 324, mb: 8, train cost: 0.0012, val cost: 0.0056,train acc: 0.9996, val acc: 0.9985,dice: 0.8216264247894287, iou: 0.6972545981407166
# epoch: 324, mb: 9, train cost: 0.0011, val cost: 0.0054,train acc: 0.9996, val acc: 0.9985,dice: 0.8189784288406372, iou: 0.6934491395950317
# epoch: 324, mb: 10, train cost: 0.0011, val cost: 0.0055,train acc: 0.9996, val acc: 0.9984,dice: 0.8166031241416931, iou: 0.6900501251220703
# epoch: 324, mb: 11, train cost: 0.0011, val cost: 0.0056,train acc: 0.9996, val acc: 0.9986,dice: 0.8236343264579773, iou: 0.7001516222953796
# epoch: 325, mb: 1, train cost: 0.0010, val cost: 0.0056,train acc: 0.9996, val acc: 0.9986,dice: 0.8206309080123901, iou: 0.6958219408988953
# epoch: 325, mb: 2, train cost: 0.0011, val cost: 0.0055,train acc: 0.9996, val acc: 0.9986,dice: 0.8236363530158997, iou: 0.7001545429229736
# epoch: 325, mb: 3, train cost: 0.0010, val cost: 0.0055,train acc: 0.9997, val acc: 0.9985,dice: 0.8192662596702576, iou: 0.6938619613647461
# epoch: 325, mb: 4, train cost: 0.0010, val cost: 0.0059,train acc: 0.9996, val acc: 0.9985,dice: 0.8179197311401367, iou: 0.6919324398040771
# epoch: 325, mb: 5, train cost: 0.0010, val cost: 0.0059,train acc: 0.9997, val acc: 0.9984,dice: 0.8163352608680725, iou: 0.6896676421165466
# epoch: 325, mb: 6, train cost: 0.0009, val cost: 0.0060,train acc: 0.9997, val acc: 0.9984,dice: 0.8105105757713318, iou: 0.6813936829566956
# epoch: 325, mb: 7, train cost: 0.0010, val cost: 0.0059,train acc: 0.9997, val acc: 0.9984,dice: 0.8129697442054749, iou: 0.6848769783973694
# epoch: 325, mb: 8, train cost: 0.0010, val cost: 0.0057,train acc: 0.9997, val acc: 0.9985,dice: 0.8135223388671875, iou: 0.685661792755127
# epoch: 325, mb: 9, train cost: 0.0009, val cost: 0.0057,train acc: 0.9997, val acc: 0.9985,dice: 0.8126259446144104, iou: 0.6843891143798828
# epoch: 325, mb: 10, train cost: 0.0009, val cost: 0.0060,train acc: 0.9997, val acc: 0.9985,dice: 0.8121128678321838, iou: 0.6836616396903992
# epoch: 325, mb: 11, train cost: 0.0010, val cost: 0.0059,train acc: 0.9997, val acc: 0.9984,dice: 0.8081650733947754, iou: 0.6780847311019897
# epoch: 326, mb: 1, train cost: 0.0010, val cost: 0.0064,train acc: 0.9996, val acc: 0.9984,dice: 0.8094319105148315, iou: 0.6798703670501709
# ...
# epoch: 739, mb: 10, train cost: 0.0002, val cost: 0.0102,train acc: 1.0000, val acc: 0.9983,dice: 0.7997362017631531, iou: 0.666300356388092
# epoch: 739, mb: 11, train cost: 0.0002, val cost: 0.0097,train acc: 1.0000, val acc: 0.9984,dice: 0.8014981150627136, iou: 0.668749988079071
# epoch: 740, mb: 1, train cost: 0.0002, val cost: 0.0098,train acc: 1.0000, val acc: 0.9983,dice: 0.7992091178894043, iou: 0.6655689477920532
# epoch: 740, mb: 2, train cost: 0.0002, val cost: 0.0102,train acc: 1.0000, val acc: 0.9984,dice: 0.8033435940742493, iou: 0.6713235378265381
# epoch: 740, mb: 3, train cost: 0.0002, val cost: 0.0097,train acc: 1.0000, val acc: 0.9983,dice: 0.7994717359542847, iou: 0.6659332513809204
# epoch: 740, mb: 4, train cost: 0.0002, val cost: 0.0102,train acc: 1.0000, val acc: 0.9984,dice: 0.8006155490875244, iou: 0.6675220131874084
# epoch: 740, mb: 5, train cost: 0.0002, val cost: 0.0102,train acc: 1.0000, val acc: 0.9984,dice: 0.8003529906272888, iou: 0.6671570539474487
# epoch: 740, mb: 6, train cost: 0.0002, val cost: 0.0103,train acc: 1.0000, val acc: 0.9984,dice: 0.8020304441452026, iou: 0.6694915294647217
# epoch: 740, mb: 7, train cost: 0.0002, val cost: 0.0098,train acc: 1.0000, val acc: 0.9984,dice: 0.8017544150352478, iou: 0.6691069006919861
# epoch: 740, mb: 8, train cost: 0.0002, val cost: 0.0098,train acc: 1.0000, val acc: 0.9984,dice: 0.8001762628555298, iou: 0.6669114828109741
# epoch: 740, mb: 9, train cost: 0.0002, val cost: 0.0098,train acc: 1.0000, val acc: 0.9984,dice: 0.800000011920929, iou: 0.6666666865348816
# epoch: 740, mb: 10, train cost: 0.0002, val cost: 0.0098,train acc: 1.0000, val acc: 0.9984,dice: 0.8011426329612732, iou: 0.6682551503181458
# epoch: 740, mb: 11, train cost: 0.0002, val cost: 0.0098,train acc: 1.0000, val acc: 0.9984,dice: 0.8007924556732178, iou: 0.6677680015563965
# epoch: 741, mb: 1, train cost: 0.0002, val cost: 0.0103,train acc: 1.0000, val acc: 0.9984,dice: 0.8032534718513489, iou: 0.6711976528167725
# epoch: 741, mb: 2, train cost: 0.0002, val cost: 0.0102,train acc: 1.0000, val acc: 0.9983,dice: 0.7997362017631531, iou: 0.666300356388092
# epoch: 741, mb: 3, train cost: 0.0002, val cost: 0.0098,train acc: 1.0000, val acc: 0.9984,dice: 0.7995589971542358, iou: 0.666054368019104
# epoch: 741, mb: 4, train cost: 0.0002, val cost: 0.0102,train acc: 1.0000, val acc: 0.9983,dice: 0.7991209030151367, iou: 0.6654465794563293
# epoch: 741, mb: 5, train cost: 0.0002, val cost: 0.0098,train acc: 1.0000, val acc: 0.9984,dice: 0.8022026419639587, iou: 0.6697314977645874
# epoch: 741, mb: 6, train cost: 0.0002, val cost: 0.0099,train acc: 1.0000, val acc: 0.9984,dice: 0.8005284070968628, iou: 0.6674008965492249
# epoch: 741, mb: 7, train cost: 0.0002, val cost: 0.0100,train acc: 1.0000, val acc: 0.9984,dice: 0.8004390597343445, iou: 0.6672767400741577
# epoch: 741, mb: 8, train cost: 0.0002, val cost: 0.0098,train acc: 1.0000, val acc: 0.9983,dice: 0.7987657189369202, iou: 0.6649541258811951
# epoch: 741, mb: 9, train cost: 0.0002, val cost: 0.0101,train acc: 1.0000, val acc: 0.9984,dice: 0.8007915616035461, iou: 0.6677667498588562
# epoch: 741, mb: 10, train cost: 0.0002, val cost: 0.0098,train acc: 1.0000, val acc: 0.9983,dice: 0.7970024347305298, iou: 0.6625137329101562
# epoch: 741, mb: 11, train cost: 0.0002, val cost: 0.0096,train acc: 1.0000, val acc: 0.9983,dice: 0.797446072101593, iou: 0.663127064704895
# epoch: 742, mb: 1, train cost: 0.0003, val cost: 0.0102,train acc: 1.0000, val acc: 0.9983,dice: 0.7993847727775574, iou: 0.665812611579895
# epoch: 742, mb: 2, train cost: 0.0003, val cost: 0.0104,train acc: 1.0000, val acc: 0.9984,dice: 0.8023793697357178, iou: 0.6699779033660889
# epoch: 742, mb: 3, train cost: 0.0002, val cost: 0.0099,train acc: 1.0000, val acc: 0.9984,dice: 0.803166925907135, iou: 0.6710768342018127
# epoch: 742, mb: 4, train cost: 0.0002, val cost: 0.0099,train acc: 1.0000, val acc: 0.9984,dice: 0.800175666809082, iou: 0.666910707950592
# epoch: 742, mb: 5, train cost: 0.0002, val cost: 0.0098,train acc: 1.0000, val acc: 0.9984,dice: 0.8021929860115051, iou: 0.6697180271148682
# epoch: 742, mb: 6, train cost: 0.0002, val cost: 0.0099,train acc: 1.0000, val acc: 0.9983,dice: 0.799736499786377, iou: 0.6663007736206055
# epoch: 742, mb: 7, train cost: 0.0002, val cost: 0.0102,train acc: 1.0000, val acc: 0.9984,dice: 0.8009697794914246, iou: 0.6680147051811218
# epoch: 742, mb: 8, train cost: 0.0002, val cost: 0.0103,train acc: 1.0000, val acc: 0.9984,dice: 0.8001760840415955, iou: 0.666911244392395
# epoch: 742, mb: 9, train cost: 0.0002, val cost: 0.0098,train acc: 1.0000, val acc: 0.9983,dice: 0.7990346550941467, iou: 0.6653270125389099
# epoch: 742, mb: 10, train cost: 0.0002, val cost: 0.0100,train acc: 1.0000, val acc: 0.9984,dice: 0.8021978139877319, iou: 0.6697247624397278
# epoch: 742, mb: 11, train cost: 0.0002, val cost: 0.0098,train acc: 1.0000, val acc: 0.9983,dice: 0.7996485233306885, iou: 0.6661786437034607
# epoch: 743, mb: 1, train cost: 0.0002, val cost: 0.0098,train acc: 1.0000, val acc: 0.9983,dice: 0.7995599508285522, iou: 0.6660557389259338
# epoch: 743, mb: 2, train cost: 0.0002, val cost: 0.0101,train acc: 1.0000, val acc: 0.9984,dice: 0.7999119758605957, iou: 0.6665443778038025
# epoch: 743, mb: 3, train cost: 0.0002, val cost: 0.0100,train acc: 1.0000, val acc: 0.9984,dice: 0.8008781671524048, iou: 0.6678872108459473
# epoch: 743, mb: 4, train cost: 0.0002, val cost: 0.0096,train acc: 1.0000, val acc: 0.9983,dice: 0.7997362017631531, iou: 0.666300356388092
# epoch: 743, mb: 5, train cost: 0.0002, val cost: 0.0099,train acc: 1.0000, val acc: 0.9983,dice: 0.7994728684425354, iou: 0.6659348607063293
# epoch: 743, mb: 6, train cost: 0.0002, val cost: 0.0105,train acc: 1.0000, val acc: 0.9984,dice: 0.8015855550765991, iou: 0.6688717603683472
# epoch: 743, mb: 7, train cost: 0.0002, val cost: 0.0102,train acc: 1.0000, val acc: 0.9984,dice: 0.8025505542755127, iou: 0.6702166795730591
# epoch: 743, mb: 8, train cost: 0.0002, val cost: 0.0102,train acc: 1.0000, val acc: 0.9984,dice: 0.8000880479812622, iou: 0.6667889952659607
# epoch: 743, mb: 9, train cost: 0.0002, val cost: 0.0103,train acc: 1.0000, val acc: 0.9983,dice: 0.7997362017631531, iou: 0.666300356388092
# epoch: 743, mb: 10, train cost: 0.0002, val cost: 0.0101,train acc: 1.0000, val acc: 0.9983,dice: 0.7994722723960876, iou: 0.6659340858459473
# epoch: 743, mb: 11, train cost: 0.0002, val cost: 0.0099,train acc: 1.0000, val acc: 0.9984,dice: 0.8024582862854004, iou: 0.670087993144989
# epoch: 744, mb: 1, train cost: 0.0002, val cost: 0.0102,train acc: 1.0000, val acc: 0.9984,dice: 0.803166925907135, iou: 0.6710768342018127
# epoch: 744, mb: 2, train cost: 0.0002, val cost: 0.0098,train acc: 1.0000, val acc: 0.9983,dice: 0.7997362017631531, iou: 0.666300356388092
# epoch: 744, mb: 3, train cost: 0.0002, val cost: 0.0099,train acc: 1.0000, val acc: 0.9984,dice: 0.801407516002655, iou: 0.6686238646507263
# epoch: 744, mb: 4, train cost: 0.0002, val cost: 0.0098,train acc: 1.0000, val acc: 0.9983,dice: 0.798502504825592, iou: 0.6645894646644592
# epoch: 744, mb: 5, train cost: 0.0002, val cost: 0.0100,train acc: 1.0000, val acc: 0.9983,dice: 0.7994722723960876, iou: 0.6659340858459473
# epoch: 744, mb: 6, train cost: 0.0002, val cost: 0.0098,train acc: 1.0000, val acc: 0.9983,dice: 0.7992957830429077, iou: 0.6656891703605652
# epoch: 744, mb: 7, train cost: 0.0002, val cost: 0.0101,train acc: 1.0000, val acc: 0.9984,dice: 0.8037012815475464, iou: 0.6718232035636902
# epoch: 744, mb: 8, train cost: 0.0002, val cost: 0.0097,train acc: 1.0000, val acc: 0.9984,dice: 0.8007039427757263, iou: 0.6676449179649353
# epoch: 744, mb: 9, train cost: 0.0002, val cost: 0.0104,train acc: 1.0000, val acc: 0.9984,dice: 0.8051090240478516, iou: 0.673792839050293
# epoch: 744, mb: 10, train cost: 0.0002, val cost: 0.0100,train acc: 1.0000, val acc: 0.9984,dice: 0.8008781671524048, iou: 0.6678872108459473
# epoch: 744, mb: 11, train cost: 0.0002, val cost: 0.0100,train acc: 1.0000, val acc: 0.9983,dice: 0.7987657189369202, iou: 0.6649541258811951
# epoch: 745, mb: 1, train cost: 0.0003, val cost: 0.0103,train acc: 1.0000, val acc: 0.9984,dice: 0.8000879883766174, iou: 0.6667888760566711
# epoch: 745, mb: 2, train cost: 0.0002, val cost: 0.0102,train acc: 1.0000, val acc: 0.9983,dice: 0.7995604276657104, iou: 0.6660563945770264
# epoch: 745, mb: 3, train cost: 0.0002, val cost: 0.0096,train acc: 1.0000, val acc: 0.9983,dice: 0.7981530427932739, iou: 0.6641053557395935
# epoch: 745, mb: 4, train cost: 0.0002, val cost: 0.0102,train acc: 1.0000, val acc: 0.9983,dice: 0.7997362017631531, iou: 0.666300356388092
# epoch: 745, mb: 5, train cost: 0.0002, val cost: 0.0101,train acc: 1.0000, val acc: 0.9984,dice: 0.803090512752533, iou: 0.6709701418876648
# epoch: 745, mb: 6, train cost: 0.0002, val cost: 0.0099,train acc: 1.0000, val acc: 0.9983,dice: 0.7991198897361755, iou: 0.6654452085494995
# epoch: 745, mb: 7, train cost: 0.0002, val cost: 0.0099,train acc: 1.0000, val acc: 0.9984,dice: 0.8007924556732178, iou: 0.6677680015563965
# epoch: 745, mb: 8, train cost: 0.0002, val cost: 0.0103,train acc: 1.0000, val acc: 0.9983,dice: 0.79876708984375, iou: 0.6649560332298279
# epoch: 745, mb: 9, train cost: 0.0002, val cost: 0.0097,train acc: 1.0000, val acc: 0.9983,dice: 0.7993840575218201, iou: 0.6658116579055786
# epoch: 745, mb: 10, train cost: 0.0002, val cost: 0.0101,train acc: 1.0000, val acc: 0.9983,dice: 0.7987697720527649, iou: 0.6649597883224487
# epoch: 745, mb: 11, train cost: 0.0002, val cost: 0.0096,train acc: 1.0000, val acc: 0.9984,dice: 0.8004405498504639, iou: 0.6672787070274353
# epoch: 746, mb: 1, train cost: 0.0002, val cost: 0.0101,train acc: 1.0000, val acc: 0.9984,dice: 0.8021131157875061, iou: 0.6696067452430725
# epoch: 746, mb: 2, train cost: 0.0002, val cost: 0.0100,train acc: 1.0000, val acc: 0.9984,dice: 0.8009655475616455, iou: 0.6680088043212891
# epoch: 746, mb: 3, train cost: 0.0002, val cost: 0.0098,train acc: 1.0000, val acc: 0.9983,dice: 0.7989417910575867, iou: 0.6651982665061951
# epoch: 746, mb: 4, train cost: 0.0002, val cost: 0.0103,train acc: 1.0000, val acc: 0.9984,dice: 0.8025505542755127, iou: 0.6702166795730591
# epoch: 746, mb: 5, train cost: 0.0002, val cost: 0.0105,train acc: 1.0000, val acc: 0.9984,dice: 0.8011451363563538, iou: 0.6682586073875427
# epoch: 746, mb: 6, train cost: 0.0002, val cost: 0.0101,train acc: 1.0000, val acc: 0.9984,dice: 0.8017544150352478, iou: 0.6691069006919861
# epoch: 746, mb: 7, train cost: 0.0002, val cost: 0.0101,train acc: 1.0000, val acc: 0.9984,dice: 0.8019366264343262, iou: 0.6693607568740845
# epoch: 746, mb: 8, train cost: 0.0002, val cost: 0.0103,train acc: 1.0000, val acc: 0.9984,dice: 0.8014997839927673, iou: 0.6687523126602173
# epoch: 746, mb: 9, train cost: 0.0002, val cost: 0.0104,train acc: 1.0000, val acc: 0.9984,dice: 0.7991150617599487, iou: 0.6654384732246399
# epoch: 746, mb: 10, train cost: 0.0002, val cost: 0.0100,train acc: 1.0000, val acc: 0.9983,dice: 0.7996485233306885, iou: 0.6661786437034607
# epoch: 746, mb: 11, train cost: 0.0002, val cost: 0.0104,train acc: 1.0000, val acc: 0.9984,dice: 0.8000880479812622, iou: 0.6667889952659607
# epoch: 747, mb: 1, train cost: 0.0002, val cost: 0.0104,train acc: 1.0000, val acc: 0.9983,dice: 0.7974488735198975, iou: 0.6631309390068054
# epoch: 747, mb: 2, train cost: 0.0002, val cost: 0.0102,train acc: 1.0000, val acc: 0.9983,dice: 0.7988543510437012, iou: 0.6650770306587219
# epoch: 747, mb: 3, train cost: 0.0002, val cost: 0.0101,train acc: 1.0000, val acc: 0.9983,dice: 0.7992973327636719, iou: 0.6656913161277771
# epoch: 747, mb: 4, train cost: 0.0002, val cost: 0.0097,train acc: 1.0000, val acc: 0.9983,dice: 0.7985912561416626, iou: 0.6647123694419861
# epoch: 747, mb: 5, train cost: 0.0002, val cost: 0.0100,train acc: 1.0000, val acc: 0.9983,dice: 0.7993847727775574, iou: 0.665812611579895
# epoch: 747, mb: 6, train cost: 0.0002, val cost: 0.0098,train acc: 1.0000, val acc: 0.9984,dice: 0.7997359037399292, iou: 0.6662999391555786
# epoch: 747, mb: 7, train cost: 0.0002, val cost: 0.0104,train acc: 1.0000, val acc: 0.9984,dice: 0.8019323945045471, iou: 0.6693548560142517
# epoch: 747, mb: 8, train cost: 0.0002, val cost: 0.0098,train acc: 1.0000, val acc: 0.9984,dice: 0.8002639412879944, iou: 0.6670333743095398
# epoch: 747, mb: 9, train cost: 0.0002, val cost: 0.0104,train acc: 1.0000, val acc: 0.9983,dice: 0.7992082834243774, iou: 0.6655677556991577
# epoch: 747, mb: 10, train cost: 0.0002, val cost: 0.0098,train acc: 1.0000, val acc: 0.9984,dice: 0.8036147356033325, iou: 0.6717022657394409
# epoch: 747, mb: 11, train cost: 0.0002, val cost: 0.0103,train acc: 1.0000, val acc: 0.9984,dice: 0.8016747236251831, iou: 0.6689959764480591
# epoch: 748, mb: 1, train cost: 0.0002, val cost: 0.0103,train acc: 1.0000, val acc: 0.9984,dice: 0.8003529906272888, iou: 0.6671570539474487
# epoch: 748, mb: 2, train cost: 0.0002, val cost: 0.0098,train acc: 1.0000, val acc: 0.9984,dice: 0.8007915616035461, iou: 0.6677667498588562
# epoch: 748, mb: 3, train cost: 0.0002, val cost: 0.0097,train acc: 1.0000, val acc: 0.9984,dice: 0.799559473991394, iou: 0.6660550236701965
# epoch: 748, mb: 4, train cost: 0.0002, val cost: 0.0099,train acc: 1.0000, val acc: 0.9984,dice: 0.8003517985343933, iou: 0.6671554446220398
# epoch: 748, mb: 5, train cost: 0.0002, val cost: 0.0104,train acc: 1.0000, val acc: 0.9983,dice: 0.7993847727775574, iou: 0.665812611579895
# epoch: 748, mb: 6, train cost: 0.0002, val cost: 0.0101,train acc: 1.0000, val acc: 0.9983,dice: 0.7985973954200745, iou: 0.664720892906189
# epoch: 748, mb: 7, train cost: 0.0002, val cost: 0.0101,train acc: 1.0000, val acc: 0.9984,dice: 0.8021131157875061, iou: 0.6696067452430725
# epoch: 748, mb: 8, train cost: 0.0002, val cost: 0.0099,train acc: 1.0000, val acc: 0.9983,dice: 0.7992957830429077, iou: 0.6656891703605652
# epoch: 748, mb: 9, train cost: 0.0002, val cost: 0.0098,train acc: 1.0000, val acc: 0.9984,dice: 0.8055130243301392, iou: 0.6743589639663696
# epoch: 748, mb: 10, train cost: 0.0002, val cost: 0.0102,train acc: 1.0000, val acc: 0.9983,dice: 0.7997370958328247, iou: 0.6663015484809875
# epoch: 748, mb: 11, train cost: 0.0002, val cost: 0.0099,train acc: 1.0000, val acc: 0.9984,dice: 0.8015820980072021, iou: 0.6688668727874756
# epoch: 749, mb: 1, train cost: 0.0003, val cost: 0.0099,train acc: 1.0000, val acc: 0.9983,dice: 0.7992957830429077, iou: 0.6656891703605652
# epoch: 749, mb: 2, train cost: 0.0002, val cost: 0.0097,train acc: 1.0000, val acc: 0.9984,dice: 0.8021953701972961, iou: 0.6697214245796204
# epoch: 749, mb: 3, train cost: 0.0003, val cost: 0.0101,train acc: 1.0000, val acc: 0.9984,dice: 0.8011413812637329, iou: 0.6682533621788025
# epoch: 749, mb: 4, train cost: 0.0003, val cost: 0.0098,train acc: 1.0000, val acc: 0.9984,dice: 0.8029903173446655, iou: 0.670830249786377
# epoch: 749, mb: 5, train cost: 0.0002, val cost: 0.0106,train acc: 1.0000, val acc: 0.9983,dice: 0.7990304231643677, iou: 0.6653211116790771
# epoch: 749, mb: 6, train cost: 0.0002, val cost: 0.0104,train acc: 1.0000, val acc: 0.9983,dice: 0.7989441156387329, iou: 0.6652014851570129
# epoch: 749, mb: 7, train cost: 0.0002, val cost: 0.0103,train acc: 1.0000, val acc: 0.9983,dice: 0.7995604276657104, iou: 0.6660563945770264
# epoch: 749, mb: 8, train cost: 0.0002, val cost: 0.0104,train acc: 1.0000, val acc: 0.9984,dice: 0.802287220954895, iou: 0.6698494553565979
# epoch: 749, mb: 9, train cost: 0.0002, val cost: 0.0101,train acc: 1.0000, val acc: 0.9983,dice: 0.7980642318725586, iou: 0.6639824509620667
# epoch: 749, mb: 10, train cost: 0.0002, val cost: 0.0100,train acc: 1.0000, val acc: 0.9983,dice: 0.7980642318725586, iou: 0.6639824509620667
# epoch: 749, mb: 11, train cost: 0.0002, val cost: 0.0098,train acc: 1.0000, val acc: 0.9983,dice: 0.7966549396514893, iou: 0.6620336771011353
# Confusion Matrix:
# [[1816, 558], [355, 549207]]
# Loss: 0.0103
# Accuracy: 0.0033
# Recall: 0.8365
# Precision: 0.7650
# F1 Score: 0.7991

# %%
torch.save(model.state_dict(), 'model_trained1.pth')

# %%
print("Confusion Matrix:")
print(confusion_matrix)
tp, fp = confusion_matrix[0]
fn, tn = confusion_matrix[1]

# Crear una lista con los nombres de las clases
class_names = ["True Positive", "False Positive", "False Negative", "True Negative"]

# Crear una figura y un eje para el gráfico de barras
fig, ax = plt.subplots()

# Crear el gráfico de barras
ax.bar(class_names, [tp, fp, fn, tn], color=["green", "red", "red", "green"])

# Configurar las etiquetas de los ejes y el título del gráfico
ax.set_xlabel("Class")
ax.set_ylabel("Number of samples")
ax.set_title("Confusion Matrix")

# Mostrar el gráfico
plt.show()
# Out:
# Confusion Matrix:
# [[1816, 558], [355, 549207]]

# %%
####CURVAS ROC
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

cm = confusion_matrix
print(cm)
cm = np.array(cm)

y_true = np.concatenate([np.zeros(cm[0, 0] + cm[0, 1]), np.ones(cm[1, 0] + cm[1, 1])])
y_scores = np.concatenate([np.zeros(cm[0, 0]), np.ones(cm[1, 0]), np.zeros(cm[0, 1]), np.ones(cm[1, 1])])

# Calcular la tasa de verdaderos positivos (TPR) y la tasa de falsos positivos (FPR) para diferentes umbrales de clasificación
fpr, tpr, thresholds = roc_curve(y_true, y_scores)

# Calcular el área bajo la curva ROC (AUC)
roc_auc = auc(fpr, tpr)

# Graficar la curva ROC
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='darkorange', lw=2, label='Curva ROC (AUC = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('Tasa de Falsos Positivos')
plt.ylabel('Tasa de Verdaderos Positivos')
plt.title('Curva ROC')
plt.legend(loc="lower right")
plt.show()
# Out:
# [[1816, 558], [355, 549207]]

# %%
fprs, tprs = lift(model, val_loader)
import matplotlib.pyplot as plt
plt.plot(fprs, tprs)
plt.xlabel('FPR')
plt.ylabel('TPR')
plt.show()

# %%
imgs_val, masks_val = next(iter(val_loader))
imgs_val = imgs_val.to(device, dtype=torch.float32)
imgs_val = torch.narrow(imgs_val, 1, 0, 3)
model = model.to(device)
with torch.no_grad():
    scores = model(imgs_val)
    preds = torch.argmax(scores, dim=1).float()

imgs_val = imgs_val.cpu()
preds = preds.cpu()
print(preds.shape)
plot_mini_batch(imgs_val, preds.unsqueeze(1))
# Out:
# torch.Size([4, 224, 224])

# %%
test_set = Car_Dataset(TEST_PATH, img_transforms=transform_data)
test_loader = DataLoader(test_set, batch_size=BATCH_SIZE, shuffle=True)

# %%
imgs_test = next(iter(test_loader))
imgs_test = imgs_test.to(device, dtype=torch.float32)
imgs_test = torch.narrow(imgs_test, 1, 0, 3)
model = model.to(device)
with torch.no_grad():
    scores = model(imgs_test)
    preds = torch.argmax(scores, dim=1).float()

imgs_test = imgs_test.cpu()
preds = preds.cpu()
print(preds.shape)
plot_mini_batch(imgs_test, preds.unsqueeze(1))
# Out:
# torch.Size([1, 224, 224])
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-42-878b85ec39d9> in <module>
#      10 preds = preds.cpu()
#      11 print(preds.shape)
# ---> 12 plot_mini_batch(imgs_test, preds.unsqueeze(1))
#
# <ipython-input-13-7ee0a7218a14> in plot_mini_batch(imgs, masks)
#       4     for i in range(BATCH_SIZE):
#       5         plt.subplot(4, 8, i+1)
# ----> 6         img=imgs[i,...].permute(1,2,0).numpy()
#       7         mask = masks[i, ...].permute(1,2,0).numpy()
#       8         plt.imshow(img)
#
# IndexError: index 1 is out of bounds for dimension 0 with size 1

# %%
model = model.to(device)
with torch.no_grad():
    for batch in test_loader:
        imgs_test = batch.to(device, dtype=torch.float32)
        print(imgs_test.shape)
        imgs_test = torch.narrow(imgs_test, 1, 0, 3)
        
        scores = model(imgs_test)
        preds = torch.argmax(scores, dim=1).float()

        imgs_test = imgs_test.cpu()
        preds = preds.cpu()
        plot_mini_batch(imgs_test, preds.unsqueeze(1))
# Out:
# torch.Size([1, 3, 224, 224])
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-33-48e024ed96e9> in <module>
#      11         imgs_test = imgs_test.cpu()
#      12         preds = preds.cpu()
# ---> 13         plot_mini_batch(imgs_test, preds.unsqueeze(1))
#
# <ipython-input-13-7ee0a7218a14> in plot_mini_batch(imgs, masks)
#       4     for i in range(BATCH_SIZE):
#       5         plt.subplot(4, 8, i+1)
# ----> 6         img=imgs[i,...].permute(1,2,0).numpy()
#       7         mask = masks[i, ...].permute(1,2,0).numpy()
#       8         plt.imshow(img)
#
# IndexError: index 1 is out of bounds for dimension 0 with size 1

# %%
###PARA validacion cruzada
